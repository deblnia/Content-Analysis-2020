# %% [markdown]
# # Week 4 - Counting Words & Phrases
#
# This week, we take text corpora that we have developed, spidered, scraped, and encoded, and we find and count words, simple and parsed phrases and explore the statistical properties of those counts (e.g., word frequency distributions). Initially, we model how to search corpora for keywords or phrases. Next, we examine the distributions of terms and phrases across a corpus, and the correlation between different words and phrase counts. In order to do this effectively, we coarsely disambiguate words based of part-of-speech (POS) tagging, and normalize them through stemming and lemmatization. Next we distinguish *important* words and phrase within the corpus, and image them with Wordls! Then we calculate word frequenceis, conditional frequences (the frequency of word *shock* conditional on the presence of word *awe*), and statistically significant collocations of lengths 2 through $n$. Finally, we calculate and visualize Differences (Divergences and Distances) between the word frequency distributions from two corpora.
#
# Then we shift to focus not simply on the *ideas* in a corpus, but also extracting precise *claims*. This process involves a sequential pipeline of classifying and structuring tokens from text, each of which generates potentially useful data for the content analyst. Steps in this process, which we examine in this notebook, include: 1) tagging words by their part of speech (POS) to reveal the linguistic role they play in the sentence (e.g., Verb, Noun, Adjective, etc.); 2) tagging words as named entities (NER) such as places or organizations; 3) structuring or "parsing" sentences into nested phrases that are local to, describe or depend on one another; and 4) extracting informational claims from those phrases.
#
# We will be introducing spaCy as a package for Computational Linguistics, and also walk you through how to use the Davies Corpora.
#
# While we wish to avoid using NLTK for heavy corpus analysis, some of its smaller functions can still be useful.
#
# Of course, for final projects that draw on these tools, we encourage you to install the software on your own machines or shared servers at the university (RCC, SSRC) in order to perform these operations on much more text.
#
# For this notebook we will be using the following packages:

# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
import lucem_illud_2020 #pip install git+git://github.com/Computational-Content-Analysis-2020/lucem_illud_2020.git

#All these packages need to be installed from pip
import requests #for http requests
import pandas as pd #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import wordcloud #Makes word clouds
import numpy as np #For divergences/distances
import scipy #For divergences/distances
import seaborn as sns #makes our plots look nicer
import sklearn.manifold #For a manifold plot
import json #For API responses
import urllib.parse #For joining urls
import csv
import nltk

# comp-linguistics
import spacy

#Displays the graphs
import graphviz #You also need to install the command line graphviz

#These are from the standard library
import os.path
import zipfile
import subprocess
import io
import tempfile

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook
# %matplotlib inline

# %% [markdown]
# # Retrieving exemplary corpora
#
# To get started we will need some examples. Let's start by downloading one of the corpuses from the Davies set purchased for this class and developed by a computational linguist at Brigham Young University. We can get a list of works available from the [corpora here](https://www.english-corpora.org/).
#
# In this notebook, I will be accessing the data locally - you also have access to this data through the Dropbox download link. The same code can be modified slighlty to access the rest of the corpora on RCC.
# There is a notebook describing this process in the same repository, as well as in the same directory on RCC.

# %%
corpus_name = "/Users/deblina/Downloads/Movies"
# corpus_name = "Movies"

# %% [markdown]
# This method extracts the text from the zip files and stroes the raw data.

# %%
def loadcorpus(corpus_name, corpus_style="text"):
    texts_raw = {}
    for file in os.listdir(corpus_name + "/"):
        if corpus_style in file:
            print(file)
            zfile = zipfile.ZipFile(corpus_name + "/" + file)
            for file in zfile.namelist():
                texts_raw[file] = []
                with zfile.open(file) as f:
                    for line in f:
                        texts_raw[file].append(line)
    return texts_raw

# %%
movie_raw = loadcorpus(corpus_name)

# %%
movie_raw['11.txt'][0:3]

# %% [markdown]
# It seems messy, but nothing we can't clean. This basic method replaces some of the issues with the formatting, and prints the errors if any for debugging. Let us clean one of the raw text files.
#
# We ignore the non-unicode data for convenience in our first pass.

# %%
def clean_raw_text(raw_texts):
    clean_texts = []
    for text in raw_texts:
        try:
            text = text.decode("utf-8")
            clean_text = text.replace(" \'m", "'m").replace(" \'ll", "'ll").replace(" \'re", "'re").replace(" \'s", "'s").replace(" \'re", "'re").replace(" n\'t", "n't").replace(" \'ve", "'ve").replace(" /'d", "'d")
            clean_texts.append(clean_text)
        except AttributeError:
            # print("ERROR CLEANING")
            # print(text)
            continue
        except UnicodeDecodeError:
            # print("Unicode Error, Skip")
            continue
    return clean_texts

# %%
clean_11 = clean_raw_text(movie_raw['11.txt'])

# %%
clean_11[1]

# %% [markdown]
# This method cleaned a few basic formatting errors. You are welcome to experiment and add your own code to expand on cleaning the text. Once it begins to look the way you want it to, we can start using spaCy to do some heavier cleaning. spaCy does this through the use of language models. Make sure you have the spaCy english language model loaded.

# %%
nlp = spacy.load("en")

# %% [markdown]
# This model is going to be the basis of most of the tasks which NLTK (the Natural Language Tool Kit) might have done otherwise. While NLTK uses a bunch of clunky models from multiple places, spacy neatly packs all functionality in one model. This deep trained model will start by doing our word tokenizing and normalising. These methods are already included in lucem illud, and here we will just demonstrate them outside the package so to explain what goes on under the hood.
#
# When we run text through a spacy model, it performs a lot of computation on each of the tokens. Each token is given certain attributes, such as a part of speech, information whether it is a number, a stop word, and so on.
#
# To perform a tokenization, we check if the string includes punctuation and add this token.

# %%
def word_tokenize(word_list):
    tokenized = []
    # pass word list through language model.
    doc = nlp(word_list)
    for token in doc:
        if not token.is_punct and len(token.text.strip()) > 0:
            tokenized.append(token.text)
    return tokenized

# %%
word_tokenize(clean_11[1])

# %% [markdown]
# You can see how the sentence is broken into its constituent words. We can then do some analysis with this.
#
# Note: we still don't know which movie this is, just that it is raw movie text data. Maybe in the process of our text cleaning and counting we will come across something!

# %% [markdown]
# # Counting words
#
# If we want to do some analysis we can start by simply counting the number of times each word occurs within the corpus.

# %%
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        #We usually need to normalize the case
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

# %%
countedWords = wordCounter(word_tokenize(clean_11[1]))
countedWords[:10]

# %% [markdown]
# Lets sort and plot our counts to investigate the shape of our word frequency distribution.
#
# First we need to sort the words by count.

# %%
#Doing this in place (changing the original DataFrame) as we don't need the unsorted DataFrame
countedWords.sort_values('count', ascending=False, inplace=True)
countedWords[:100]

# %% [markdown]
# Punctuation and very common words (articles 'a' and 'the'; prepositions 'of' and 'to') make up the most common values, but this isn't very interesting and can actually get in the way of our analysis. We may remove these 'function words' by removing according to a stopword list, setting some frequency threshold, or using a weighting scheme (like tf.idf) to decrease their influence - we will look at these methods in more detail as we go through this tutorial.

# %%
#Creating a figure and axis lets us do things like change the scaling or add a title
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
plt.show()

# %% [markdown]
# This shows that likelihood of a word occurring is inversely proportional to its rank. This effect is called [Zipf's Law](https://en.wikipedia.org/wiki/Zipf%27s_law), and suggests that the most frequent word will occur approximately twice as often as the second most frequent word, three times as often as the third most frequent word, etc. Zipf's law is most easily observed by plotting the data on a log-log graph, with the axes being log (rank order) and log (frequency) resulting in a linear relationship.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %% [markdown]
# (The same relationship occurs in many other rankings, such as population ranks of cities, corporation sizes, income rankings, etc.)
#
# The distribution was imagined by Zipf to be driven by a principle of 'least effort' where speakers did not work any harder than necessary to communicate a given idea, but the basis for this relationship is still not well understood and conforms at least as well to a process of [preferential attachment](https://en.wikipedia.org/wiki/Preferential_attachment) whereby people disproportionately attend to popular words.

# %% [markdown]
# # Getting and working with raw text
#
# First, we will retrieve a collection of press releases from a *GitHub API* that archived them, based on a number of analyses by Justin Grimmer, a political scientist whose work we will read in two weeks!
#
# GitHub API requests are made to `'https://api.github.com/'` and responses are in JSON, similar to Tumblr's API.
#
# We will get the information on [github.com/lintool/GrimmerSenatePressReleases](https://github.com/lintool/GrimmerSenatePressReleases) as it contains a nice set documents.

# %%
r = requests.get('https://api.github.com/repos/lintool/GrimmerSenatePressReleases')
senateReleasesData = json.loads(r.text)
print(senateReleasesData.keys())
print(senateReleasesData['description'])

# %% [markdown]
# What we are interested in here is the `'contents_url'`

# %%
print(senateReleasesData['contents_url'])

# %% [markdown]
# We can use this to get any or all of the files from the repo.

# %%
r = requests.get('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse')
whitehouseLinks = json.loads(r.text)
whitehouseLinks[0]

# %% [markdown]
# Now we have a list of information about Whitehouse press releases. Let's look at one of them.

# %%
r = requests.get(whitehouseLinks[0]['download_url'])
whitehouseRelease = r.text
print(whitehouseRelease[:1000])
len(whitehouseRelease)

# %% [markdown]
# Now we have a string of correctly encoded text. For analysis of its words, next we need to tokenize it, or split it into a sequence of tokens or word instances.

# %%
whTokens = word_tokenize(whitehouseRelease)
whTokens[10:30]

# %% [markdown]
# Previous iterations of the course used `nltk`s tokenizer, but as we saw before, we used spaCy's model (https://spacy.io/api/tokenizer). We intend to avoid using NLTK when we can - for production level code, it is a lot faster and cleaner to use spaCy.
#
# That being said, `nltk` does have some useful methods for quick analysis of small corpora. We will explore a few here, and encourage you to figure out for yourself which other ones might be useful.
#
# To use the list of tokens in `nltk`, and take advantage of functions like `concordance`, shown above, we can convert it into a `Text`.

# %%
import nltk

# %%
whText = nltk.Text(whTokens)

whitehouseIndex = nltk.text.ConcordanceIndex(whText) 
whitehouseIndex.print_concordance('Whitehouse')

# %% [markdown]
# *Note* that the `Text` class is for doing rapid, exploratory analysis. It provides an easy interface to many of the operations we want to do, but it does not allow us much control over the particular operations it glosses. When you are doing a more complete analysis, you should be using the module specifically designed for that task instead of the shortcut method `Text` provides, e.g. use  [`collocations` Module](http://www.nltk.org/api/nltk.html#module-nltk.collocations) instead of `.collocations()`.
#
# Now that we have gotten this loaded, let's glance at few features we will delve into more deeply later.
#
# For example, we can find words that statistically tend to occur together and typically have a composite, idiomatic meaning irreducible to the semantics of its component words. We will do this later with more control over exactly how these are identified.

# %% [markdown]
# Or we can pick a word (or words) and find what words tend to occur around it.

# %%
whText.common_contexts(['stem'])

# %% [markdown]
# We can also just count the number of times the word occurs.

# %%
whText.count('cell')

# %% [markdown]
# We can also plot each time a set of words occurs.

# %%
sns.reset_orig() #Seaborn messes with this plot, disabling it
whText.dispersion_plot(['Sen.','stem', 'cell', 'federal' ,'Lila', 'Barber', 'Whitehouse'])
sns.set() #Re-enabling seaborn

# %% [markdown]
# If we want to do an analysis of all the Whitehouse press releases we will first need to obtain them. By looking at the API we can see the the URL we want is [https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse](https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse), so we can create a function to scrape the individual files.
#
# If you want to know more about downloading from APIs, refer back to the 1st notebook.

# %%
def getGithubFiles(target, maxFiles = 100):
    #We are setting a max so our examples don't take too long to run
    #For converting to a DataFrame
    releasesDict = {
        'name' : [], #The name of the file
        'text' : [], #The text of the file, watch out for binary files
        'path' : [], #The path in the git repo to the file
        'html_url' : [], #The url to see the file on Github
        'download_url' : [], #The url to download the file
    }

    #Get the directory information from Github
    r = requests.get(target)
    filesLst = json.loads(r.text)

    for fileDict in filesLst[:maxFiles]:
        #These are provided by the directory
        releasesDict['name'].append(fileDict['name'])
        releasesDict['path'].append(fileDict['path'])
        releasesDict['html_url'].append(fileDict['html_url'])
        releasesDict['download_url'].append(fileDict['download_url'])

        #We need to download the text though
        text = requests.get(fileDict['download_url']).text
        releasesDict['text'].append(text)

    return pandas.DataFrame(releasesDict)

whReleases = getGithubFiles('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse', maxFiles = 10)
whReleases[:5]

# %% [markdown]
# If you are having trouble downloading the data uncomment this next cell

# %%
#whReleases = pandas.read_csv('../data/whReleases.csv')

# %% [markdown]
# Now we have all the texts in a DataFrame we can look at a few things.
#
# First let's tokenize the texts with the same tokenizer as we used before. We will just save the tokens as a list for now; no need to convert to `Text`s.

# %%
whReleases['tokenized_text'] = whReleases['text'].apply(lambda x: word_tokenize(x))

# %% [markdown]
# Now lets see how long each of the press releases is:

# %%
whReleases['word_counts'] = whReleases['tokenized_text'].apply(lambda x: len(x))
whReleases['word_counts']

# %% [markdown]
# ## <span style="color:red">*Exercise 1*</span>
#
# <span style="color:red">Construct cells immediately below this that input and interrogate a corpus relating to your anticipated final project. This could include one of the Davies corpora or some other you have constructed. Turn your text into an nltk `Text` object, and explore all of the features examined above, and others that relate to better understanding your corpus in relation to your research question. </span>

# %%
df = pd.read_csv("../final-project/data_full.csv")
df = df.dropna()
df
# Out:
#           pmid                                              title  \
# 20    30474576  The current practice and care of paediatric pa...
# 21    30449211  Current pharmacological treatment guidelines f...
# 24    29580902  Early life trauma: An exploratory study of eff...
# 41    30917518  Telomerase Impinges on the Cellular Response t...
# 55    29118206  Social Origins of Developmental Risk for Menta...
# ...        ...                                                ...
# 4033  30519450  Breaking point: the genesis and impact of stru...
# 4035  28468917  The circadian dynamics of small nucleolar RNA ...
# 4036  28414085  Lost in space? Generalising subtree prune and ...
# 4038  28358245  Changes in the demographics of intravenous dru...
# 4039  28087420  On the quirks of maximum parsimony and likelih...
#
#                                                abstract  \
# 20    BACKGROUND: Literature is lacking to guide sta...
# 21    INTRODUCTION: Psoriasis is a common chronic sk...
# 24    BACKGROUND: In animals, adverse early experien...
# 41    Telomerase has cellular functions beyond telom...
# 55    Adversity in early childhood exerts an endurin...
# ...                                                 ...
# 4033  Somatic structural variants undoubtedly play i...
# 4035  The circadian regulation of gene expression al...
# 4036  Over the last fifteen years, phylogenetic netw...
# 4038  Objectives The reported annual incidence of my...
# 4039  Maximum parsimony is one of the most frequentl...
#
#                                                   major  \
# 20    ['CHD', 'paediatric cardiac catheterisation', ...
# 21    ['Psoriasis', 'arthritis', 'biologics', 'guide...
# 24    ['*Early childhood trauma', '*Gene expression'...
# 41    ['autophagy', 'mitochondria', 'oxidative stres...
# 55    ['*EEG', '*foster care', '*limbic', '*neglect'...
# ...                                                 ...
# 4033  ['*DNA double-strand breaks', '*Structural var...
# 4035  ['*RNA dynamics', '*circadian rhythms', '*non-...
# 4036  ['*Phylogenetic networks', '*Reticulation-visi...
# 4038  ['Vascular', 'demographics', 'femoral', 'intra...
# 4039  ['*Hardwired', '*Likelihood', '*Parsimony', '*...
#
#                                                    mesh
# 20    ['*Cardiac Care Facilities', 'Cardiac Catheter...
# 21    ['Antirheumatic Agents/administration & dosage...
# 24    ['Adult', '*Adverse Childhood Experiences', 'F...
# 41    ['*Autophagy', 'Cell Line', 'Fibroblasts/metab...
# 55    ['Adult', 'Child', 'Child Abuse/*psychology', ...
# ...                                                 ...
# 4033  ['Cell Transformation, Neoplastic/genetics', '...
# 4035  ['Animals', 'Circadian Rhythm/*physiology', 'G...
# 4036  ['*Algorithms', 'Computational Biology/methods...
# 4038  ['Adult', 'Age Factors', 'Amputation', 'Aneury...
# 4039  ['Animals', '*Biological Evolution', 'Gene Reg...
#
# [952 rows x 5 columns]

# %%
def word_tokenize(word_list):
    tokenized = []
    # pass word list through language model.
    doc = nlp(word_list)
    for token in doc:
        if not token.is_punct and len(token.text.strip()) > 0:
            tokenized.append(token.text)
    return tokenized

# %%
# Tokenize
df['cleaned_title']=df['title'].apply(lambda x: x.lower())
df['tokenized_title'] = df['cleaned_title'].apply(lambda x: word_tokenize(x))
df[:5]
# Out:
#         pmid                                              title  \
# 20  30474576  The current practice and care of paediatric pa...
# 21  30449211  Current pharmacological treatment guidelines f...
# 24  29580902  Early life trauma: An exploratory study of eff...
# 41  30917518  Telomerase Impinges on the Cellular Response t...
# 55  29118206  Social Origins of Developmental Risk for Menta...
#
#                                              abstract  \
# 20  BACKGROUND: Literature is lacking to guide sta...
# 21  INTRODUCTION: Psoriasis is a common chronic sk...
# 24  BACKGROUND: In animals, adverse early experien...
# 41  Telomerase has cellular functions beyond telom...
# 55  Adversity in early childhood exerts an endurin...
#
#                                                 major  \
# 20  ['CHD', 'paediatric cardiac catheterisation', ...
# 21  ['Psoriasis', 'arthritis', 'biologics', 'guide...
# 24  ['*Early childhood trauma', '*Gene expression'...
# 41  ['autophagy', 'mitochondria', 'oxidative stres...
# 55  ['*EEG', '*foster care', '*limbic', '*neglect'...
#
#                                                  mesh  \
# 20  ['*Cardiac Care Facilities', 'Cardiac Catheter...
# 21  ['Antirheumatic Agents/administration & dosage...
# 24  ['Adult', '*Adverse Childhood Experiences', 'F...
# 41  ['*Autophagy', 'Cell Line', 'Fibroblasts/metab...
# 55  ['Adult', 'Child', 'Child Abuse/*psychology', ...
#
#                                         cleaned_title  \
# 20  the current practice and care of paediatric pa...
# 21  current pharmacological treatment guidelines f...
# 24  early life trauma: an exploratory study of eff...
# 41  telomerase impinges on the cellular response t...
# 55  social origins of developmental risk for menta...
#
#                                       tokenized_title
# 20  [the, current, practice, and, care, of, paedia...
# 21  [current, pharmacological, treatment, guidelin...
# 24  [early, life, trauma, an, exploratory, study, ...
# 41  [telomerase, impinges, on, the, cellular, resp...
# 55  [social, origins, of, developmental, risk, for...

# %%
df['word_counts'] = df['tokenized_title'].apply(lambda x: len(x))
df[:5]
# Out:
#         pmid                                              title  \
# 20  30474576  The current practice and care of paediatric pa...
# 21  30449211  Current pharmacological treatment guidelines f...
# 24  29580902  Early life trauma: An exploratory study of eff...
# 41  30917518  Telomerase Impinges on the Cellular Response t...
# 55  29118206  Social Origins of Developmental Risk for Menta...
#
#                                              abstract  \
# 20  BACKGROUND: Literature is lacking to guide sta...
# 21  INTRODUCTION: Psoriasis is a common chronic sk...
# 24  BACKGROUND: In animals, adverse early experien...
# 41  Telomerase has cellular functions beyond telom...
# 55  Adversity in early childhood exerts an endurin...
#
#                                                 major  \
# 20  ['CHD', 'paediatric cardiac catheterisation', ...
# 21  ['Psoriasis', 'arthritis', 'biologics', 'guide...
# 24  ['*Early childhood trauma', '*Gene expression'...
# 41  ['autophagy', 'mitochondria', 'oxidative stres...
# 55  ['*EEG', '*foster care', '*limbic', '*neglect'...
#
#                                                  mesh  \
# 20  ['*Cardiac Care Facilities', 'Cardiac Catheter...
# 21  ['Antirheumatic Agents/administration & dosage...
# 24  ['Adult', '*Adverse Childhood Experiences', 'F...
# 41  ['*Autophagy', 'Cell Line', 'Fibroblasts/metab...
# 55  ['Adult', 'Child', 'Child Abuse/*psychology', ...
#
#                                         cleaned_title  \
# 20  the current practice and care of paediatric pa...
# 21  current pharmacological treatment guidelines f...
# 24  early life trauma: an exploratory study of eff...
# 41  telomerase impinges on the cellular response t...
# 55  social origins of developmental risk for menta...
#
#                                       tokenized_title  word_counts
# 20  [the, current, practice, and, care, of, paedia...           11
# 21  [current, pharmacological, treatment, guidelin...            9
# 24  [early, life, trauma, an, exploratory, study, ...           22
# 41  [telomerase, impinges, on, the, cellular, resp...           16
# 55  [social, origins, of, developmental, risk, for...           10

# %%
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        #We usually need to normalize the case
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

# %%
df['word_counts'] = df['tokenized_title'].apply(lambda x: len(x))
df[:5]
# Out:
#         pmid                                              title  \
# 20  30474576  The current practice and care of paediatric pa...
# 21  30449211  Current pharmacological treatment guidelines f...
# 24  29580902  Early life trauma: An exploratory study of eff...
# 41  30917518  Telomerase Impinges on the Cellular Response t...
# 55  29118206  Social Origins of Developmental Risk for Menta...
#
#                                              abstract  \
# 20  BACKGROUND: Literature is lacking to guide sta...
# 21  INTRODUCTION: Psoriasis is a common chronic sk...
# 24  BACKGROUND: In animals, adverse early experien...
# 41  Telomerase has cellular functions beyond telom...
# 55  Adversity in early childhood exerts an endurin...
#
#                                                 major  \
# 20  ['CHD', 'paediatric cardiac catheterisation', ...
# 21  ['Psoriasis', 'arthritis', 'biologics', 'guide...
# 24  ['*Early childhood trauma', '*Gene expression'...
# 41  ['autophagy', 'mitochondria', 'oxidative stres...
# 55  ['*EEG', '*foster care', '*limbic', '*neglect'...
#
#                                                  mesh  \
# 20  ['*Cardiac Care Facilities', 'Cardiac Catheter...
# 21  ['Antirheumatic Agents/administration & dosage...
# 24  ['Adult', '*Adverse Childhood Experiences', 'F...
# 41  ['*Autophagy', 'Cell Line', 'Fibroblasts/metab...
# 55  ['Adult', 'Child', 'Child Abuse/*psychology', ...
#
#                                         cleaned_title  \
# 20  the current practice and care of paediatric pa...
# 21  current pharmacological treatment guidelines f...
# 24  early life trauma: an exploratory study of eff...
# 41  telomerase impinges on the cellular response t...
# 55  social origins of developmental risk for menta...
#
#                                       tokenized_title  word_counts
# 20  [the, current, practice, and, care, of, paedia...           11
# 21  [current, pharmacological, treatment, guidelin...            9
# 24  [early, life, trauma, an, exploratory, study, ...           22
# 41  [telomerase, impinges, on, the, cellular, resp...           16
# 55  [social, origins, of, developmental, risk, for...           10

# %%
post_tokens = df['tokenized_title'][100]
post_tokens[:20]
# Out:
# ['effect',
#  'of',
#  'nitric',
#  'oxide',
#  'and',
#  'calpastatin',
#  'on',
#  'the',
#  'inhibition',
#  'of',
#  'micro',
#  'calpain',
#  'activity',
#  'autolysis',
#  'and',
#  'proteolysis',
#  'of',
#  'myofibrillar',
#  'proteins']

# %%
# Word Frequency in titles 
countedWords = wordCounter(post_tokens)
countedWords.sort_values('count', ascending=False, inplace=True)
countedWords[:20]
# Out:
#             word  count
# 1             of      3
# 4            and      2
# 0         effect      1
# 2         nitric      1
# 3          oxide      1
# 5    calpastatin      1
# 6             on      1
# 7            the      1
# 8     inhibition      1
# 9          micro      1
# 10       calpain      1
# 11      activity      1
# 12     autolysis      1
# 13   proteolysis      1
# 14  myofibrillar      1
# 15      proteins      1

# %%
# Explore NLTK functions
post_text = nltk.Text(post_tokens)

index = nltk.text.ConcordanceIndex(post_text) 
index.print_concordance('proteins')
# Out:
# Displaying 1 of 1 matches:
# sis and proteolysis of myofibrillar proteins

# %%
from nltk.collocations import *
finder=BigramCollocationFinder.from_words(post_text)
sorted(finder.ngram_fd.items(), key=lambda t: (-t[1], t[0]))[:10]
# Out:
# [(('activity', 'autolysis'), 1),
#  (('and', 'calpastatin'), 1),
#  (('and', 'proteolysis'), 1),
#  (('autolysis', 'and'), 1),
#  (('calpain', 'activity'), 1),
#  (('calpastatin', 'on'), 1),
#  (('effect', 'of'), 1),
#  (('inhibition', 'of'), 1),
#  (('micro', 'calpain'), 1),
#  (('myofibrillar', 'proteins'), 1)]

# %%
#Lexical Dispersion Plot
sns.reset_orig() #something confusing happenens w seaborn 
post_text.dispersion_plot(['activity','and','micro'])
sns.set() #Re-enabling seaborn

# %% [markdown]
# # Filtering and normalizing text
#
# As we want to start comparing the different releases we may choose to do a bit of filtering and normalizing that will allow us to focus on what we most care about. We can first make all of the words lower case, then drop the non-word tokens. Next, we can remove some 'stop words', stem the remaining words to remove suffixes, prefixes and (in some languages) infixes, or lemmatize tokens by intelligently grouping inflected or variant forms of the same word (e.g., with a stemmer and a dictionary).
#
# To begin this process, we will first define a function to work over the tokenized lists, then another to add normalized tokens to a new column.

# %% [markdown]
# We will be using spaCy's built in stop words identifying capacity. When we run text through spaCy's language pipeline, it automatically tags it as a stop word.

# %% [markdown]
# We can remove these stopwords from the analysis by fiat, but we could also take a more principled approach by looking at the frequency distribution of words and selecting a specific cut-off associated with the preservation of 'meaningful words' identified upon inspection. Alternatively, we could automatically set a cut-off by rule, such as removal of all words more frequent then the most frequent verb, or the most frequent noun (not pronoun), or some term of central interest.

# %%
countsDict = {}
for word in whReleases['tokenized_text'].sum():
    if word in countsDict:
        countsDict[word] += 1
    else:
        countsDict[word] = 1
word_counts = sorted(countsDict.items(), key = lambda x : x[1], reverse = True)
word_counts[:20]

# %% [markdown]
# We can look at this and pick the cutoff, often at the first noun. So we will cut all words before `'Whitehouse'`.

# %%
#The stop list is then all words that occur before the first noun
stop_words_freq = []
for word, count in word_counts:
    if word == 'Whitehouse':
        break
    else:
        stop_words_freq.append(word)
stop_words_freq

# %% [markdown]
# If we did have any extra words to add as stop words apart from those normally considered as stop words, we would add it to our stop words by passing it to the normalize tokens method.

# %% [markdown]
# Now we can create our function to normalize the tokens

# %%
def normalizeTokens(word_list, extra_stop=[]):
    #We can use a generator here as we just need to iterate over it
    normalized = []
    if type(word_list) == list and len(word_list) == 1:
        word_list = word_list[0]

    if type(word_list) == list:
        word_list = ' '.join([str(elem) for elem in word_list]) 

    doc = nlp(word_list.lower())
    
    # add the property of stop word to words considered as stop words
    if len(extra_stop) > 0:
        for stopword in extra_stop:
            lexeme = nlp.vocab[stopword]
            lexeme.is_stop = True

    for w in doc:
        # if it's not a stop word or punctuation mark, add it to our article
        if w.text != '\n' and not w.is_stop and not w.is_punct and not w.like_num and len(w.text.strip()) > 0:
            # we add the lematized version of the word
            normalized.append(str(w.lemma_))

    return normalized

# %%
whReleases['normalized_tokens'] = whReleases['tokenized_text'].apply(lambda x: normalizeTokens(x))

whReleases['normalized_tokens_count'] = whReleases['normalized_tokens'].apply(lambda x: len(x))

whReleases

# %% [markdown]
# You can see that in the final step of normalizing, we add the lemmatized form of the word. spaCy's built in lemmatizer does this (https://spacy.io/api/lemmatizer). Lemmatization can be thought of as finding the root or the base of the word after removing inflections and other variations of words. Another possible way of finding the roots of words is using NLTK's porting or stemming functionalities, but we will not be getting into them.
#
# Now that it is cleaned we start analyzing the dataset. We can start by finding frequency distributions for the dataset. Lets start looking at all the press releases together. The [`ConditionalFreqDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ConditionalProbDist) class reads in an iterable of tuples, the first element is the condition and the second the focal word. For starters, we will use word lengths as the conditions, but tags or clusters will provide more useful results.

# %%
#.sum() adds together the lists from each row into a single list
whcfdist = nltk.ConditionalFreqDist(((len(w), w) for w in whReleases['normalized_tokens'].sum()))

#print the number of words
print(whcfdist.N())

# %% [markdown]
# From this we can lookup the distributions of different word lengths

# %%
whcfdist[3].plot()

# %% [markdown]
# We can also create a Conditional Probability Distribution or [`ConditionalProbDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ConditionalProbDist) from the `ConditionalFreqDist`. To do this, however, we need a model for the probability distribution. A simple model is [`ELEProbDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ELEProbDist) which gives the expected likelihood estimate for the probability distribution of the experiment used to generate the observed frequency distribution.

# %%
whcpdist = nltk.ConditionalProbDist(whcfdist, nltk.ELEProbDist)

#print the most common 2 letter word
print(whcpdist[2].max())

#And its probability
print(whcpdist[2].prob(whcpdist[2].max()))

# %% [markdown]
# Length is one feature of a word, but there are many more important features we care about. Another critical feature is a word's role in the sentence, or its part of speech (POS).
#
# The method below works similarly to ```nltk.pos_text```, and can work with the conditional frequency distributions it provides.

# %%
def spacy_pos(word_list):
    tags = []
    doc = nlp(word_list.lower())
    for w in doc:
        tags.append((w.text, w.tag_))
    return tags

# %%
whReleases['normalized_tokens_POS'] = [spacy_pos(t) for t in whReleases['text']]

# %% [markdown]
# This gives us a new column with the part of speech as a short initialism and the word in a tuple, exactly how the `nltk.ConditionalFreqDist()` function wants them. We can now construct another conditional frequency distribution.

# %%
whcfdist_WordtoPOS = nltk.ConditionalFreqDist(whReleases['normalized_tokens_POS'].sum())
list(whcfdist_WordtoPOS.items())[:10]

# %% [markdown]
# This gives the frequency of each word as each part of speech...which can be uninformative and boring. What we want is the converse; the frequency of each part of speech for each word.

# %%
whcfdist_POStoWord = nltk.ConditionalFreqDist((p, w) for w, p in whReleases['normalized_tokens_POS'].sum())

# %% [markdown]
# We can now identify and collect all of the superlative adjectives

# %%
whcfdist_POStoWord['JJ']

# %% [markdown]
# Or look at the most common nouns

# %%
whcfdist_POStoWord['NN'].most_common(5)

# %% [markdown]
# Or plot the base form verbs against their number of occurrences

# %%
whcfdist_POStoWord['VB'].plot()

# %% [markdown]
# We can then do a similar analysis of the word probabilities

# %%
whcpdist_POStoWord = nltk.ConditionalProbDist(whcfdist_POStoWord, nltk.ELEProbDist)

#print the most common nouns
print(whcpdist_POStoWord['NN'].max())

#And its probability
print(whcpdist_POStoWord['NN'].prob(whcpdist_POStoWord['NN'].max()))

# %% [markdown]
# We can even create a...wait for it...*WORD CLOUD* or Wordl to gaze at and draw mystical, approximate inferences about important nouns and verbs in our corpus:

# %%
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 1000, height = 1000, mode ='RGBA', scale=.5).generate(' '.join(whReleases['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
plt.savefig("whitehouse_word_cloud.pdf", format = 'pdf')

# %% [markdown]
# ## <span style="color:red">*Exercise 2*</span>
#
# <span style="color:red">Construct cells immediately below this that filter, stem and lemmatize the tokens in your corpus, and then creates plots (with titles and labels) that map the word frequency distribution, word probability distribution, and at least two conditional probability distributions that help us better understand the social and cultural game underlying the production of your corpus. Create a wordl of words (or normalized words) and add a few vague comments about what mysteries are revealed through it.</span>

# %%
countsDict = {}
for word in df['tokenized_title'].sum():
    if word in countsDict:
        countsDict[word] += 1
    else:
        countsDict[word] = 1
word_counts = sorted(countsDict.items(), key = lambda x : x[1], reverse = True)

# %%
def normalizeTokens(word_list, extra_stop=[]):
    #We can use a generator here as we just need to iterate over it
    normalized = []
    if type(word_list) == list and len(word_list) == 1:
        word_list = word_list[0]

    if type(word_list) == list:
        word_list = ' '.join([str(elem) for elem in word_list]) 

    doc = nlp(word_list.lower())
    
    # add the property of stop word to words considered as stop words
    if len(extra_stop) > 0:
        for stopword in extra_stop:
            lexeme = nlp.vocab[stopword]
            lexeme.is_stop = True

    for w in doc:
        # if it's not a stop word or punctuation mark, add it to our article
        if w.text != '\n' and not w.is_stop and not w.is_punct and not w.like_num and len(w.text.strip()) > 0:
            # we add the lematized version of the word
            normalized.append(str(w.lemma_))

    return normalized

# %%
df['normalized_tokens'] = df['tokenized_title'].apply(lambda x: normalizeTokens(x))
df['normalized_tokens_count'] = df['normalized_tokens'].apply(lambda x: len(x))
fdist = nltk.FreqDist([w for w in df['normalized_tokens'].sum()])
fdist
# Out:
# FreqDist({'cell': 88, 'study': 74, 'patient': 73, 'analysis': 70, 'gene': 62, 'disease': 58, 'cancer': 49, 'genome': 48, 'human': 47, 'model': 40, ...})

# %%
freqdist = nltk.ConditionalFreqDist(((len(w), w) for w in df['normalized_tokens'].sum() if fdist[w]>0))

# %%
# frequency plot for words of 10 characters
plt.title("Frequency plot of words that have frequencies in the title corpus")
freqdist[2].plot()

# %%
freqdist = nltk.ConditionalFreqDist(((len(w), w) for w in df['normalized_tokens'].sum()))
print(freqdist.N())

condprobdist = nltk.ConditionalProbDist(freqdist, nltk.ELEProbDist)

#print the most common n letter word
print("The most common 2 letter word is {}, probability: {}".format(condprobdist[2].max(), condprobdist[2].prob(condprobdist[2].max())))
# Out:
# 10193
# The most common 2 letter word is uk, probability: 0.10087719298245613

# %%
#POS
df['normalized_tokens_POS'] = [lucem_illud_2020.spacy_pos(t) for t in df['title']]

# %%
freqdist_POStoWord = nltk.ConditionalFreqDist((p, w) for w, p in df['normalized_tokens_POS'].sum())
freqdist_POStoWord['NN'].most_common(10)
# Out:
# [('analysis', 60),
#  ('study', 54),
#  ('cell', 47),
#  ('cancer', 46),
#  ('gene', 40),
#  ('expression', 38),
#  ('disease', 38),
#  ('brain', 27),
#  ('treatment', 25),
#  ('development', 25)]

# %%
freqdist_POStoWord['NN'].plot(title="Frequency Distribution of Nouns in corpus")

# %%
#Word Cloud
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 1000, height = 1000, mode ='RGBA', scale=.5).generate(' '.join(df['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 499.5, 499.5, -0.5)

# %% [markdown]
# ## Davies Corpora
#
# Now that we have our basic cleaning down, we can arrange our Davies Corpora. Let us try this with the movies corpora we have already loaded.
#
# We'll use a smaller corpus of a 1000 movies for this demonstration.

# %%
zfile = zipfile.ZipFile(corpus_name + "/sources_movies.zip")
source = []

# %%
for file in zfile.namelist():
    with zfile.open(file) as f:
        for line in f:
            source.append(line)

# %%
source[0:20]

# %% [markdown]
# It looks dirty because the file is encoded as bytes, but we can certainly see the information there. The file id is also present in the original raw text data: as the first "word". Look back at the normalized/tokenized words to confirm that. We're going to use this to create a dataframe with: Fileid, movie name, genre, year, and country.
#
# It is advised that you run a similar check of the source file before you do other extraction.
#
# First, let us create a dictionary mapping file-id to all the text. Each movie will be mapped to a list of the tokenized words.
#
# In this example, I only use it to load 100 movies. You can comment this out or increase/decrease the number as you see fit.

# %%
movie_texts = {}

# %%
for files in movie_raw:
    if len(movie_texts) > 100:
        break
    movies = clean_raw_text(movie_raw[files][1:])
    for movie in movies:
        txts = lucem_illud_2020.word_tokenize(movie)
        try:
            movie_texts[txts[0][2:]] = txts[1:]
        except IndexError:
            continue

# %%
import pandas as pd

# %%
movie_df = pd.DataFrame(columns=["Movie Name", "Genre", "Year", "Country", "Tokenized Texts"])

# %%
for movie in source[3:]:
    try:
        tid, fileid, total_words, genre, year, lang, country, imdb, title = movie.decode("utf-8").split("\t")
    except UnicodeDecodeError:
        continue
    try:
        movie_df.loc[fileid.strip()] = [title.strip(), genre.strip(), year.strip(), country.strip(), movie_texts[fileid.strip()]]
    except KeyError:
        continue

# %%
movie_df.head()

# %% [markdown]
# # Part-of-Speech (POS) tagging

# %% [markdown]
# In POS tagging, we classify each word by its semantic role in a sentence. We will be using the in-built spaCy pos-tagging.
#
# https://spacy.io/usage/linguistic-features
#
# |#. |Tag |Description |
# |---|----|------------|
# |1.	|CC	|Coordinating conjunction
# |2.	|CD	|Cardinal number
# |3.	|DT	|Determiner
# |4.	|EX	|Existential there
# |5.	|FW	|Foreign word
# |6.	|IN	|Preposition or subordinating conjunction
# |7.	|JJ	|Adjective
# |8.	|JJR|	Adjective, comparative
# |9.	|JJS|	Adjective, superlative
# |10.|	LS	|List item marker
# |11.|	MD	|Modal
# |12.|	NN	|Noun, singular or mass
# |13.|	NNS	|Noun, plural
# |14.|	NNP	|Proper noun, singular
# |15.|	NNPS|	Proper noun, plural
# |16.|	PDT	|Predeterminer
# |17.|	POS	|Possessive ending
# |18.|	PRP	|Personal pronoun
# |19.|	PRP\$|	Possessive pronoun
# |20.|	RB	|Adverb
# |21.|	RBR	|Adverb, comparative
# |22.|	RBS	|Adverb, superlative
# |23.|	RP	|Particle
# |24.|	SYM	|Symbol
# |25.|	TO	|to
# |26.|	UH	|Interjection
# |27.|	VB	|Verb, base form
# |28.|	VBD	|Verb, past tense
# |29.|	VBG	|Verb, gerund or present participle
# |30.|	VBN	|Verb, past participle
# |31.|	VBP	|Verb, non-3rd person singular present
# |32.|	VBZ	|Verb, 3rd person singular present
# |33.|	WDT	|Wh-determiner
# |34.|	WP	|Wh-pronoun
# |35.|	WP$	|Possessive wh-pronoun
# |36.|	WRB	|Wh-adverb
#
# spaCy pos-tags word as we run it through the english language model. A small example:

# %%
sent = nlp(u"Tom went to IKEA to get some of those delicious Swedish meatballs.")

# %%
for token in sent:
    print(token.text, token.pos_, token.tag_)

# %% [markdown]
# This looks quite good. Now we will try POS tagging with a somewhat larger corpus. We consider a few of the top posts from the reddit data we used last week.

# %%
redditDF = pandas.read_csv('../data/reddit.csv')

# %% [markdown]
# Grabbing the 10 highest scoring posts and tokenizing the sentences. Once again, notice that we aren't going to do any kind of stemming this week (although *semantic* normalization may be performed where we translate synonyms into the same focal word). Here, we will use sentences tokenized by spaCy. Like before, these methods can also be found in lucem_illud.

# %%
def sent_tokenize(word_list):
    doc = nlp(word_list)
    sentences = [sent.string.strip() for sent in doc.sents]
    return sentences

# %%
redditTopScores = redditDF.sort_values('score')[-10:]
redditTopScores['sentences'] = redditTopScores['text'].apply(lambda x: [word_tokenize(s) for s in sent_tokenize(x)])
redditTopScores.index = range(len(redditTopScores) - 1, -1,-1) #Reindex to make things nice in the future
redditTopScores

# %%
def tag_sents_pos(sentences):
    """
    function which replicates NLTK pos tagging on sentences.
    """
    new_sents = []
    for sentence in sentences:
        new_sent = ' '.join(sentence)
        new_sents.append(new_sent)
    final_string = ' '.join(new_sents)
    doc = nlp(final_string)
    
    pos_sents = []
    for sent in doc.sents:
        pos_sent = []
        for token in sent:
            pos_sent.append((token.text, token.tag_))
        pos_sents.append(pos_sent)
    
    return pos_sents

# %%
redditTopScores['POS_sents'] = redditTopScores['sentences'].apply(lambda x: tag_sents_pos(x))

# %%
redditTopScores['POS_sents']

# %% [markdown]
# And count the number of `NN` (nouns)

# %%
countTarget = 'NN'
targetCounts = {}
for entry in redditTopScores['POS_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind != countTarget:
                continue
            elif ent in targetCounts:
                targetCounts[ent] += 1
            else:
                targetCounts[ent] = 1
sortedTargets = sorted(targetCounts.items(), key = lambda x: x[1], reverse = True)
sortedTargets[:20]

# %% [markdown]
# What about the adjectives that modify the word, "computer"?

# %%
NTarget = 'JJ'
Word = 'computer'
NResults = set()
for entry in redditTopScores['POS_sents']:
    for sentence in entry:
        for (ent1, kind1),(ent2,kind2) in zip(sentence[:-1], sentence[1:]):
            if (kind1,ent2.lower())==(NTarget,Word):
                NResults.add(ent1)
            else:
                continue

print(NResults)

# %% [markdown]
# ## <span style="color:red">*Your turn*</span>
#
# <span style="color:red">In the cells immediately following, perform POS tagging on a meaningful (but modest) subset of a corpus associated with your final project. Examine the list of words associated with at least three different parts of speech. Consider conditional associations (e.g., adjectives associated with nouns or adverbs with verbs of interest). What do these distributions suggest about your corpus?

# %%
df_small = df[:100]
df_small['sentences'] = df_small['abstract'].apply(lambda x: [word_tokenize(s) for s in lucem_illud_2020.sent_tokenize(x)])
# Out:
# <ipython-input-78-06dc1bf4797e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['sentences'] = df_small['abstract'].apply(lambda x: [word_tokenize(s) for s in lucem_illud_2020.sent_tokenize(x)])

# %%
df_small['POS_sents'] = df_small['sentences'].apply(lambda x: lucem_illud_2020.tag_sents_pos(x))
# Out:
# <ipython-input-81-418059b90dcc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['POS_sents'] = df_small['sentences'].apply(lambda x: lucem_illud_2020.tag_sents_pos(x))

# %%
def POS_count(countTarget,n,data):
    targetCounts = {}
    for entry in data['POS_sents']:
        for sentence in entry:
            for ent, kind in sentence:
                if kind != countTarget:
                    continue
                elif ent in targetCounts:
                    targetCounts[ent] += 1
                else:
                    targetCounts[ent] = 1
    sortedTargets = sorted(targetCounts.items(), key = lambda x: x[1], reverse = True)
    return sortedTargets[:n]

# %%
POS_count('NN',20,df_small) # Nouns
# Out:
# [('cancer', 72),
#  ('study', 45),
#  ('health', 42),
#  ('treatment', 40),
#  ('expression', 40),
#  ('analysis', 39),
#  ('gene', 38),
#  ('group', 30),
#  ('response', 29),
#  ('DNA', 29),
#  ('breast', 29),
#  ('time', 28),
#  ('care', 25),
#  ('research', 25),
#  ('model', 25),
#  ('blood', 24),
#  ('drug', 24),
#  ('activity', 23),
#  ('risk', 23),
#  ('tumor', 23)]

# %%
def cond_assoc(NTarget, Word, data):
    NResults = set()
    for entry in data['POS_sents']:
        for sentence in entry:
            for (ent1, kind1),(ent2,kind2) in zip(sentence[:-1], sentence[1:]):
                if (kind1,ent2.lower())==(NTarget,Word):
                    NResults.add(ent1)
                else:
                    continue

    return NResults

# %%
cond_assoc('NN', 'gene', df_small)
# Out:
# {'candidate',
#  'disease',
#  'host',
#  'liver',
#  'pathway',
#  'resistance',
#  'response',
#  'susceptibility',
#  'target'}

# %% [markdown]
# # Collocations

# %% [markdown]
# As illustrated above, we might want to find significant bigrams (two-word phrases), trigrams (three-word phrases), n-grams (*n*-word phrases) or skip-grams (noncontinguous 'phrases' with skip-length *n*).
#
# We will begin with the [`nltk.collocations.BigramCollocationFinder`](http://www.nltk.org/api/nltk.html?highlight=bigramcollocationfinder#nltk.collocations.BigramCollocationFinder) class, which can be given raw lists of strings with the `from_words()` method. By default it only looks at continuous bigrams but there is an option (`window_size`) to allow skip-grams.

# %%
whBigrams = nltk.collocations.BigramCollocationFinder.from_words(whReleases['normalized_tokens'].sum())
print("There are {} bigrams in the finder".format(whBigrams.N))

# %% [markdown]
# To compare the bigrams we need to tell nltk what our score function is. Initially, we will look at the raw counts.

# %%
def bigramScoring(count, wordsTuple, total):
    return count

print(whBigrams.nbest(bigramScoring, 10))

# %% [markdown]
# One note about how `BigramCollocationFinder` works. It doesn't use the strings internally.

# %%
birgramScores = []

def bigramPrinting(count, wordsTuple, total):
    global birgramScores
    birgramScores.append("The first word is:  {}, The second word is: {}".format(*wordsTuple))
    #Returns None so all the tuples are considered to have the same rank

whBigrams.nbest(bigramPrinting, 10)
print('\n'.join(birgramScores[:10]))

# %% [markdown]
# The words are each given numeric IDs and there is a dictionary that maps the IDs to the words they represent. This is a common performance optimization.
#
# Two words can appear together by chance. Recall from  Manning and Schütze's textbook that a t-value can be computed for each bigram to see how significant the association is. You may also want to try computing the $\chi^2$, likelihood ratio, and pointwise mutual information statistics.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
whBigrams.score_ngrams(bigram_measures.likelihood_ratio)[:40]
# other options include student_t, chi_sq, likelihood_ratio, pmi

# %% [markdown]
# There are a few other available measures

# %%
[s for s in dir(bigram_measures) if s[0] != '_']

# %% [markdown]
# We can also look at trigrams

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
whTrigrams = nltk.collocations.TrigramCollocationFinder.from_words(whReleases['normalized_tokens'].sum())
whTrigrams.score_ngrams(trigram_measures.student_t)[:20]

# %% [markdown]
# Or n-grams (for any number n)

# %%
Ngrams = nltk.ngrams(whReleases['normalized_tokens'].sum(), 4)
Counts = {}
for ngram in list(Ngrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 2:
        pass
    else:
        Filtered[key] = Counts[key]
print(Filtered)

# %% [markdown]
# Gensim is another important python text processing package which allows us to use collocations, among other cool methods (which we will explore later weeks).

# %%
import gensim

# %%
bigram = gensim.models.Phrases(whReleases['normalized_tokens'])

# %%
texts = [bigram[line] for line in whReleases['normalized_tokens']]

# %%
texts[0]

# %% [markdown]
# ## <span style="color:red">*Exercise 3*</span>
#
# <span style="color:red">Construct cells immediately below this that identify statistically significant bigrams, trigrams, quadgrams, higher-order *n*grams and skipgrams. Explore whether these collocations are idiomatic and so irreducible to the semantic sum of their component words. You can do this by examination of conditional frequencies (e.g., what else is 'united' besides the 'United States'). If these phrases are idiomatic, what do they suggest about the culture of the world producing them?
#
# <span style="color:red">**Stretch**: In Manning and Schütze's textbook, there Section 5.3.2 explores how to use the *t*-test to find words whose co-occurance patterns best distinguish two words. Implement that and use it to explore phrases in your corpus. For instance, you could tell what words come after "America" much more often than after "Iraq"?</span>

# %%
dataBigrams = nltk.collocations.BigramCollocationFinder.from_words(df_small['normalized_tokens'].sum())
print("There are {} bigrams in the finder".format(dataBigrams.N))
# Out:
# There are 1016 bigrams in the finder

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
dataBigrams.score_ngrams(bigram_measures.likelihood_ratio)[:10]
# Out:
# [(('fish', 'porichthys'), 28.91798619655577),
#  (('larval', 'zebrafish'), 28.91798619655577),
#  (('midshipman', 'fish'), 28.91798619655577),
#  (('nitric', 'oxide'), 28.91798619655577),
#  (('plainfin', 'midshipman'), 28.91798619655577),
#  (('porichthys', 'notatus'), 28.91798619655577),
#  (('gene', 'expression'), 28.130718436712463),
#  (('cross', 'sectional'), 25.098901186786893),
#  (('sectional', 'survey'), 25.098901186786893),
#  (('effect', 'nitric'), 22.187869526463206)]

# %%
# finding ngrams that appread at least 2 times
def get_ngrams_count(n, count_min=2):
    dataNgrams = nltk.ngrams(df['normalized_tokens'].sum(), n)
    Counts = {}
    for ngram in list(dataNgrams):
        if ngram in Counts.keys():
            Counts[ngram] += 1
        else:
            Counts[ngram] = 1
    Filtered = {}
    for key in Counts.keys():
        if Counts[key] < count_min:
            pass
        else:
            Filtered[key] = Counts[key]
    return pd.DataFrame.from_dict(Filtered, orient='index', columns=['count'])

# %%
ngrams4_df = get_ngrams_count(2)
ngrams4_df.sort_values(by='count', ascending=False)[:10]
# Out:
#                       count
# (gene, expression)       19
# (long, term)             15
# (systematic, review)     13
# (t, cell)                13
# (stem, cell)             12
# (meta, analysis)         12
# (genome, wide)           10
# (breast, cancer)         10
# (control, trial)          9
# (mouse, model)            9

# %%
def get_collocations(word1, word2, n=10, before=True):
    bigrams = nltk.ngrams(df['normalized_tokens'].sum(), 2)
    pairs = list(bigrams)
    word_count = {word1:{},
                  word2:{}}
    words = [] # find all the relevant words before word1/word2
    for (k1,k2) in pairs:
        if before:
            if k2==word1 or k2==word2:
                if k1 in word_count[k2].keys():
                    word_count[k2][k1] += 1
                else:
                    word_count[k2][k1] = 1
        else:
            if k1==word1 or k1==word2:
                if k2 in word_count[k1].keys():
                    word_count[k1][k2] += 1
                else:
                    word_count[k1][k2] = 1
    
    for word in [word1, word2]:
        for k,v in word_count[word].items():
            maximum = sorted(list(word_count[word].values()), reverse=True)[:n][-1]
            if v >= maximum:
                words.append(k)
    
    counts_1 = {}
    counts_2 = {}
    for w in words:
        counts_1[w] = 0
        counts_2[w] = 0 
    
    for (k1,k2) in pairs:
        if before:
            if k1 in words and k2==word1:
                counts_1[k1] += 1
            elif k1 in words and k2==word2:
                counts_2[k1] += 1
        else:
            if k2 in words and k1==word1:
                counts_1[k2] += 1
            elif k2 in words and k1==word2:
                counts_2[k2] += 1
        
    dic = {}
    dic[word1] = counts_1
    dic[word2] = counts_2
    return dic

# %%
counts = get_collocations('human','gene')
distinguish_df1 = pd.DataFrame.from_dict(counts['human'], orient='index', columns=['count of gene'])
distinguish_df2 = pd.DataFrame.from_dict(counts['gene'], orient='index', columns=['count of human'])
distinguish_df = distinguish_df1.merge(distinguish_df2, left_index=True, right_index=True)

# %%
distinguish_df.reset_index().rename({'index':'word'}, axis='columns')
# Out:
#             word  count of gene  count of human
# 0        healthy              1               0
# 1   polarization              1               0
# 2         target              1               2
# 3          model              4               0
# 4         allele              2               0
# ..           ...            ...             ...
# 85       isoform              0               1
# 86  excitability              0               1
# 87      activate              0               1
# 88       plastid              0               1
# 89        factor              0               1
#
# [90 rows x 3 columns]

# %%
def t(row):
    numerator = row['count of gene']-row['count of human']
    denominator = (row['count of human']+row['count of gene'])**(1/2)
    return numerator/denominator

# %%
distinguish_df['t'] = distinguish_df.apply(lambda x: t(x), axis=1)
distinguish_df
# Out:
#               count of gene  count of human         t
# healthy                   1               0  1.000000
# polarization              1               0  1.000000
# target                    1               2 -0.577350
# model                     4               0  2.000000
# allele                    2               0  1.414214
# ...                     ...             ...       ...
# isoform                   0               1 -1.000000
# excitability              0               1 -1.000000
# activate                  0               1 -1.000000
# plastid                   0               1 -1.000000
# factor                    0               1 -1.000000
#
# [90 rows x 3 columns]

# %% [markdown]
# # Named-Entity Recognition
#
# Named Entity Recognition (NER) is also a classification task, which identifies named objects.
# Like every other part of the pipeline, spaCy also tags words with their tagged entity (https://spacy.io/api/entityrecognizer). You can see the full capacity of what spaCy does by checking out: https://spacy.io/usage/linguistic-features.
#
# For training the identification of such entities, spaCy uses a deep learning model.

# %% [markdown]
# Let's try it on a basic sentence:

# %%
sent = nlp(u"Tom went to IKEA to get some of those delicious Swedish meatballs.")

# %%
for token in sent:
    print(token.text, token.ent_type_)

# %% [markdown]
# For only finding ents-

# %%
for ent in sent.ents:
    print(ent.text, ent.label_)

# %%
def tag_sents_ner(sentences):
    """
    function which replicates NLTK ner tagging on sentences.
    """
    new_sents = []
    for sentence in sentences:
        new_sent = ' '.join(sentence)
        new_sents.append(new_sent)
    final_string = ' '.join(new_sents)
    doc = nlp(final_string)
    
    pos_sents = []
    for sent in doc.sents:
        pos_sent = []
        for ent in sent.ents:
            pos_sent.append((ent.text, ent.label_))
        pos_sents.append(pos_sent)
    
    return pos_sents

# %% [markdown]
# We can also run NER over our entire corpus:

# %%
redditTopScores['classified_sents'] = redditTopScores['sentences'].apply(lambda x: tag_sents_ner(x))

# %%
redditTopScores['classified_sents']

# %% [markdown]
# Find the most common entities (which are, of course, boring):

# %%
entityCounts = {}
for entry in redditTopScores['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if ent in entityCounts:
                entityCounts[ent] += 1
            else:
                entityCounts[ent] = 1
sortedEntities = sorted(entityCounts.items(), key = lambda x: x[1], reverse = True)
sortedEntities[:10]

# %% [markdown]
# Or those occurring only twice:

# %%
[x[0] for x in sortedEntities if x[1] == 2]

# %% [markdown]
# We could also list the most common "non-objects". (We note that we're not graphing these because there are so few here.)

# %%
nonObjCounts = {}
for entry in redditTopScores['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind == 'ORG':
                continue
            elif ent in nonObjCounts:
                nonObjCounts[ent] += 1
            else:
                nonObjCounts[ent] = 1
sortedNonObj = sorted(nonObjCounts.items(), key = lambda x: x[1], reverse = True)
sortedNonObj[:10]

# %% [markdown]
# What about the Organizations?

# %%
OrgCounts = {}
for entry in redditTopScores['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind == 'ORG':
                print(ent)

# %% [markdown]
# These, of course, have much smaller counts.
#
# In this particular example we didn't find the most interesting entities - you can remedy that in exercise 4!

# %% [markdown]
# ## <span style="color:red">*Exercise 4*</span>
#
# <span style="color:red">In the cells immediately following, perform NER on a (modest) subset of your corpus of interest. List all of the different kinds of entities tagged? What does their distribution suggest about the focus of your corpus? For a subset of your corpus, tally at least one type of named entity and calculate the Precision, Recall and F-score for the NER classification just performed.

# %%
def tag_sents_ner(sentences):
    """
    function which replicates NLTK ner tagging on sentences.
    """
    new_sents = []
    for sentence in sentences:
        new_sent = ' '.join(sentence)
        new_sents.append(new_sent)
    final_string = ' '.join(new_sents)
    doc = nlp(final_string)
    
    pos_sents = []
    for sent in doc.sents:
        pos_sent = []
        for ent in sent.ents:
            pos_sent.append((ent.text, ent.label_))
        pos_sents.append(pos_sent)
    
    return pos_sents

# %%
df_small['classified_sents'] = df_small['abstract'].apply(lambda x: tag_sents_ner(x))
entityCounts = {}
for entry in df_small['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if ent in entityCounts:
                entityCounts[(ent)] += 1
            else:
                entityCounts[(ent)] = 1
sortedEntities = sorted(entityCounts.items(), key = lambda x: x[1], reverse = True)
sortedEntities[:10]
# Out:
# <ipython-input-102-15628a42ec56>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['classified_sents'] = df_small['abstract'].apply(lambda x: tag_sents_ner(x))
# [('a s s', 102),
#  ('2', 62),
#  ('1', 47),
#  ('0', 43),
#  ('a s', 36),
#  ('s   ', 35),
#  ('3', 28),
#  ('5', 24),
#  ('9', 23),
#  ('6', 23)]

# %%
# Find the most common entities
tagCounts = {}
for entry in df_small['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind in tagCounts:
                tagCounts[kind] += 1
            else:
                tagCounts[kind] = 1
sortedTags = sorted(tagCounts.items(), key = lambda x: x[1], reverse = True)

# %%
x = [tag for tag,v in sortedTags]
y = [v for tag,v in sortedTags]
plt.plot(x, y)
plt.xticks(rotation=90)
plt.show()

# %%
# Find Orgs
for entry in df_small['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind == 'ORG':
                print(ent)
# Out:
# y
# N R 3
# N R 3 C 1
# N R 3 C 1   (
# N R 3 C 1
# N H F
# n
# G l o b
# G F R
# N
# N G S
# n u c l e u s
# N O R - 3
# N O R - 3
# N O
# G S N O
# u
# G u a t e m a l
# N D M - G E - U
# U N L
# n
# n s
# N D P
# N D P
# G A
# N a C
# N F - k
# u s a g
# n s
# L C N
# L C N
# N
# G L U D 1
# C R P
# U C
# N R P S
# h
# N A
# N
# N o m u
# N e m
# F u
# F u
# G C T
# N A A
# N A A
# G l u )
# g l u t
# n
# n
# g l u t
# g u
# N G S
# N G S
# G e n
# N F 1
# G e n
# G e n e
# N f k
# n
# G C
# G C
# G C
# G C
# G C
# G C
# G C
# N
# n
# n
# N R P
# N
# N
# N
# n
# c u l t
# D N P

# %%
# Find persons
for entry in df_small['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind == 'PERSON':
                print(ent)
# Out:
# A q
# A q
# A U D
# A U D
# F D R
# G H - d

# %%
for entry in df_small[:5]['classified_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind == 'GPE':
                print(ent)
# Out:
# u m
# u m
# u m
# U s

# %%
precision = 4/4
recall = 4/4
fscore = 2*(precision*recall)/(precision+recall)
print(precision, recall, fscore)
# Out:
# 1.0 1.0 1.0

# %% [markdown]
# ## Dependency parsing and graph representations
#
# Dependency parsing was developed to robustly capture linguistic dependencies from text. The complex tags associated with these parses are detailed [here]('http://universaldependencies.org/u/overview/syntax.html'). When parsing with the dependency parser, we will work directly from the untokenized text. Note that no *processing* takes place before parsing sentences--we do not remove so-called stop words or anything that plays a syntactic role in the sentence, although anaphora resolution and related normalization may be performed before or after parsing to enhance the value of information extraction.

# %% [markdown]
# We will be using spaCy's built in dependancy parser to go about exploring the tree.
# Note that unlike previous examples, large corpuses or collections of sentences don't give us as much information, so we will be navigating smaller sentences.
#
# Let us start by exploring noun chunks. Noun chunks are “base noun phrases” – flat phrases that have a noun as their head. You can think of noun chunks as a noun plus the words describing the noun – for example, “the lavish green grass” or “the world’s largest tech fund”. To get the noun chunks in a document, simply iterate over the sentences noun chunks.

# %%
from spacy import displacy

# %%
doc = nlp("Autonomous cars shift insurance liability toward manufacturers")

# %%
displacy.render(doc, style='dep')

# %%
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text)

# %% [markdown]
# spaCy uses the terms head and child to describe the words connected by a single arc in the dependency tree. The term dep is used for the arc label, which describes the type of syntactic relation that connects the child to the head. As with other attributes, the value of .dep is a hash value. You can get the string value with .dep_.
#
# For your reference:
#
# Text: The original token text.
#
# Dep: The syntactic relation connecting child to head.
#
# Head text: The original text of the token head.
#
# Head POS: The part-of-speech tag of the token head.
#
# Children: The immediate syntactic dependents of the token.

# %%
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])

# %% [markdown]
# Because the syntactic relations form a tree, every word has exactly one head. You can therefore iterate over the arcs in the tree by iterating over the words in the sentence. This is usually the best way to match an arc of interest — from below:

# %%
from spacy.symbols import nsubj, VERB

# %%
verbs = set()
for possible_subject in doc:
    if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
        verbs.add(possible_subject.head)
print(verbs)

# %% [markdown]
# You can *also* navigate from above. It isn't as efficient though.

# %%
verbs = []
for possible_verb in doc:
    if possible_verb.pos == VERB:
        for possible_subject in possible_verb.children:
            if possible_subject.dep == nsubj:
                verbs.append(possible_verb)
                break

# %%
print(verbs)

# %% [markdown]
# ### Iterating around the local tree
# A few more convenience attributes are provided for iterating around the local tree from the token. Token.lefts and Token.rights attributes provide sequences of syntactic children that occur before and after the token. Both sequences are in sentence order. There are also two integer-typed attributes, Token.n_lefts and Token.n_rights that give the number of left and right children.

# %%
doc = nlp("bright red apples on the tree")
print([token.text for token in doc[2].lefts])  # ['bright', 'red']
print([token.text for token in doc[2].rights])  # ['on']
print(doc[2].n_lefts)  # 2
print(doc[2].n_rights)  # 1

# %% [markdown]
# You can get a whole phrase by its syntactic head using the Token.subtree attribute. This returns an ordered sequence of tokens. You can walk up the tree with the Token.ancestors attribute, and check dominance with Token.is_ancestor

# %%
doc = nlp("Credit and mortgage account holders must submit their requests")

root = [token for token in doc if token.head == token][0]
subject = list(root.lefts)[0]
for descendant in subject.subtree:
    assert subject is descendant or subject.is_ancestor(descendant)
    print(descendant.text, descendant.dep_, descendant.n_lefts,
            descendant.n_rights,
            [ancestor.text for ancestor in descendant.ancestors])

# %% [markdown]
# Finally, the .left_edge and .right_edge attributes can be especially useful, because they give you the first and last token of the subtree. This is the easiest way to create a Span object for a syntactic phrase. Note that .right_edge gives a token within the subtree — so if you use it as the end-point of a range, don’t forget to +1!

# %%
span = doc[doc[4].left_edge.i : doc[4].right_edge.i+1]
with doc.retokenize() as retokenizer:
    retokenizer.merge(span)
for token in doc:
    print(token.text, token.pos_, token.dep_, token.head.text)

# %%
displacy.render(doc, style='dep')

# %% [markdown]
# ### Information Extraction
#
# How can dependancy graphs be useful? We can extract information from the sentences based on relationships between words within parsed phrases. Let us see if we can do this to glean any information, from, say, our movies dataset.
#
# How violent are the movies? Who is killing who?

# %%
movie_violences = {}

# %%
for index, row in movie_df.iterrows():
    text = ' '.join(row['Tokenized Texts'])
    movie_violences[row['Movie Name']] = ([], [])
    doc = nlp(text)
    for chunk in doc.noun_chunks:
        subject = 0
        object_ = 0
        # if the verb or the root of the sentence is kill
        if chunk.root.head.text == 'kill':
            # we find the subjects and objects around the word, and if it does exist, add it to the tuple
            if chunk.root.dep_ == 'nsubj':
                subject = chunk.root.text
            if chunk.root.dep_ == 'dobj':
                object_ = chunk.root.text
            if subject is not 0:
                movie_violences[row['Movie Name']][0].append(subject)
            if object_ is not 0:
                movie_violences[row['Movie Name']][1].append(object_)

# %%
movie_violences

# %% [markdown]
# That's pretty neat: we can see who tried to kill who, or at least talked about it. A lot of 'I' killing 'you', as we'd imagine. What else can we see?
#
# The movie, about time, which is about time travel, funnily enough has:
# `'About Time': (['I'], ['Hitler'])`

# %% [markdown]
# ## <span style="color:red">*Your turn*</span>
#
# <span style="color:red">In the cells immediately following, parse a (modest) subset of your corpus of interest. How deep are the phrase structure and dependency parse trees nested? How does parse depth relate to perceived sentence complexity? What are five things you can extract from these parses for subsequent analysis? (e.g., nouns collocated in a noun phrase; adjectives that modify a noun; etc.) Capture these sets of things for a focal set of words (e.g., "Bush", "Obama", "Trump"). What do they reveal about the roles that these entities are perceive to play in the social world inscribed by your texts?

# %%
df.head(5)
# Out:
#         pmid                                              title  \
# 20  30474576  The current practice and care of paediatric pa...
# 21  30449211  Current pharmacological treatment guidelines f...
# 24  29580902  Early life trauma: An exploratory study of eff...
# 41  30917518  Telomerase Impinges on the Cellular Response t...
# 55  29118206  Social Origins of Developmental Risk for Menta...
#
#                                              abstract  \
# 20  BACKGROUND: Literature is lacking to guide sta...
# 21  INTRODUCTION: Psoriasis is a common chronic sk...
# 24  BACKGROUND: In animals, adverse early experien...
# 41  Telomerase has cellular functions beyond telom...
# 55  Adversity in early childhood exerts an endurin...
#
#                                                 major  \
# 20  ['CHD', 'paediatric cardiac catheterisation', ...
# 21  ['Psoriasis', 'arthritis', 'biologics', 'guide...
# 24  ['*Early childhood trauma', '*Gene expression'...
# 41  ['autophagy', 'mitochondria', 'oxidative stres...
# 55  ['*EEG', '*foster care', '*limbic', '*neglect'...
#
#                                                  mesh  \
# 20  ['*Cardiac Care Facilities', 'Cardiac Catheter...
# 21  ['Antirheumatic Agents/administration & dosage...
# 24  ['Adult', '*Adverse Childhood Experiences', 'F...
# 41  ['*Autophagy', 'Cell Line', 'Fibroblasts/metab...
# 55  ['Adult', 'Child', 'Child Abuse/*psychology', ...
#
#                                         cleaned_title  \
# 20  the current practice and care of paediatric pa...
# 21  current pharmacological treatment guidelines f...
# 24  early life trauma: an exploratory study of eff...
# 41  telomerase impinges on the cellular response t...
# 55  social origins of developmental risk for menta...
#
#                                       tokenized_title  word_counts  \
# 20  [the, current, practice, and, care, of, paedia...           11
# 21  [current, pharmacological, treatment, guidelin...            9
# 24  [early, life, trauma, an, exploratory, study, ...           22
# 41  [telomerase, impinges, on, the, cellular, resp...           16
# 55  [social, origins, of, developmental, risk, for...           10
#
#                                     normalized_tokens  \
# 20  [current, practice, care, paediatric, patient,...
# 21  [current, pharmacological, treatment, guidelin...
# 24  [early, life, trauma, exploratory, study, effe...
# 41  [telomerase, impinge, cellular, response, oxid...
# 55  [social, origin, developmental, risk, mental, ...
#
#     normalized_tokens_count                              normalized_tokens_POS
# 20                        8  [(the, DT), (current, JJ), (practice, NN), (an...
# 21                        7  [(current, JJ), (pharmacological, JJ), (treatm...
# 24                       15  [(early, JJ), (life, NN), (trauma, NN), (:, :)...
# 41                       11  [(telomerase, NNP), (impinges, NNS), (on, IN),...
# 55                        7  [(social, JJ), (origins, NNS), (of, IN), (deve...

# %%
sentence = df['title'].iloc[0]
print(sentence)
# Out:
# The current practice and care of paediatric patients post cardiac catheterisation.

# %%
doc = nlp(sentence)

# %%
displacy.render(doc, style='dep')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fa92030c31244f90b15fa51be28f74d8-0" class="displacy" width="1975" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">current</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">practice</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">care</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">paediatric</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">patients</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">post</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">cardiac</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">catheterisation.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fa92030c31244f90b15fa51be28f74d8-0-0" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fa92030c31244f90b15fa51be28f74d8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fa92030c31244f90b15fa51be28f74d8-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fa92030c31244f90b15fa51be28f74d8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fa92030c31244f90b15fa51be28f74d8-0-2" stroke-width="2px" d="M420,352.0 C420,2.0 1450.0,2.0 1450.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fa92030c31244f90b15fa51be28f74d8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fa92030c31244f90b15fa51be28f74d8-0-3" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fa92030c31244f90b15fa51be28f74d8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,354.0 L568.0,342.0 552.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fa92030c31244f90b15fa51be28f74d8-0-4" stroke-width="2px" d="M420,352.0 C420,177.0 740.0,177.0 740.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fa92030c31244f90b15fa51be28f74d8-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,354.0 L748.0,342.0 732.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fa92030c31244f90b15fa51be28f74d8-0-5" stroke-width="2px" d="M420,352.0 C420,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fa92030c31244f90b15fa51be28f74d8-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,354.0 L928.0,342.0 912.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fa92030c31244f90b15fa51be28f74d8-0-6" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fa92030c31244f90b15fa51be28f74d8-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fa92030c31244f90b15fa51be28f74d8-0-7" stroke-width="2px" d="M945,352.0 C945,177.0 1265.0,177.0 1265.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fa92030c31244f90b15fa51be28f74d8-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,354.0 L1273.0,342.0 1257.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fa92030c31244f90b15fa51be28f74d8-0-8" stroke-width="2px" d="M1645,352.0 C1645,264.5 1785.0,264.5 1785.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPat

# %%
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text)
# Out:
# The current practice practice nsubj post
# care care conj practice
# paediatric patients patients pobj of
# cardiac catheterisation catheterisation dobj post

# %%
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
# Out:
# The det practice NOUN []
# current amod practice NOUN []
# practice nsubj post VERB [The, current, and, care, of]
# and cc practice NOUN []
# care conj practice NOUN []
# of prep practice NOUN [patients]
# paediatric amod patients NOUN []
# patients pobj of ADP [paediatric]
# post ROOT post VERB [practice, catheterisation, .]
# cardiac amod catheterisation NOUN []
# catheterisation dobj post VERB [cardiac]
# . punct post VERB []

# %%
need = {}
for index, row in df.iterrows():
    text = ' '.join(row['tokenized_title'])
    need[row['title']] = ([], [])
    doc = nlp(text)
    for chunk in doc.noun_chunks:
        subject = 0
        object_ = 0
        # if the verb or the root of the sentence is need
        if chunk.root.head.text == 'need':
            # we find the subjects and objects around the word, and if it does exist, add it to the tuple
            if chunk.root.dep_ == 'nsubj':
                subject = chunk.text
            if chunk.root.dep_ == 'dobj':
                object_ = chunk.text
            if subject is not 0:
                need[row['title']][0].append(subject)
            if object_ is not 0:
                need[row['title']][1].append(object_)
# Out:
# <>:16: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:18: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:16: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:18: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-123-4bc461d20cbb>:16: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if subject is not 0:
# <ipython-input-123-4bc461d20cbb>:18: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if object_ is not 0:

# %%
need
# Out:
# {'The current practice and care of paediatric patients post cardiac catheterisation.': ([],
#   []),
#  'Current pharmacological treatment guidelines for psoriasis and psoriatic arthritis.': ([],
#   []),
#  'Early life trauma: An exploratory study of effects on OXTR and NR3C1 gene expression and nurturing self-efficacy in mothers of infants.': ([],
#   []),
#  'Telomerase Impinges on the Cellular Response to Oxidative Stress Through Mitochondrial ROS-Mediated Regulation of Autophagy.': ([],
#   []),
#  'Social Origins of Developmental Risk for Mental and Physical Illness.': ([],
#   []),
#  'Dissecting the Causal Mechanism of X-Linked Dystonia-Parkinsonism by Integrating Genome and Transcriptome Assembly.': ([],
#   []),
#  'Differential alveolar bone modeling after orthodontic retraction.': ([], []),
#  'Intraoperative hypotension is a risk factor for postoperative acute kidney injury after femoral neck fracture surgery: a retrospective study.': ([],
#   []),
#  'Hereditary spherocytosis caused by copy number variation in SPTB gene identified through targeted next-generation sequencing.': ([],
#   []),
#  'Hepatic serum amyloid A1 upregulates interleukin-17 (IL-17) in gammadelta T cells through Toll-like receptor 2 and is associated with psoriatic symptoms in transgenic mice.': ([],
#   []),
#  'Characterization of tanning behavior assessed via online survey: Attitudes, habits, and preventive measures with focus on sunscreen use.': ([],
#   []),
#  'Eosinophil-cationic protein - a novel liquid prognostic biomarker in melanoma.': ([],
#   []),
#  'Larval Zebrafish Lateral Line as a Model for Acoustic Trauma.': ([], []),
#  'Noise-Induced Hypersensitization of the Acoustic Startle Response in Larval Zebrafish.': ([],
#   []),
#  'Brain Activation Patterns in Response to Conspecific and Heterospecific Social Acoustic Signals in Female Plainfin Midshipman Fish, Porichthys notatus.': ([],
#   []),
#  'Seasonal plasticity of auditory saccular sensitivity in "sneaker" type II male plainfin midshipman fish, Porichthys notatus.': ([],
#   []),
#  'Effect of nitric oxide and calpastatin on the inhibition of micro-calpain activity, autolysis and proteolysis of myofibrillar proteins.': ([],
#   []),
#  'Effect of nitric oxide on myofibrillar proteins and the susceptibility to calpain-1 proteolysis.': ([],
#   []),
#  'Metabolomics in the clinic: A review of the shared and unique features of untargeted metabolomics for clinical research and clinical testing.': ([],
#   []),
#  'Identification of S-nitrosylated proteins in postmortem pork muscle using modified biotin switch method coupled with isobaric tags.': ([],
#   []),
#  'Predicting aged pork quality using a portable Raman device.': ([], []),
#  'Rapid Replacement of Acinetobacter baumannii Strains Accompanied by Changes in Lipooligosaccharide Loci and Resistance Gene Repertoire.': ([],
#   []),
#  'DNA assembly with error correction on a droplet digital microfluidics platform.': ([],
#   []),
#  'Genomic Epidemiology of Global Carbapenemase-Producing Enterobacter spp., 2008-2014.': ([],
#   []),
#  'Synthesis and Preliminary Evaluation of 5-[18F]fluoroleucine.': ([], []),
#  'Intraarterial Microdosing: A Novel Drug Development Approach, Proof-of-Concept PET Study in Rats.': ([],
#   []),
#  'Discovery of Novel Conotoxin Candidates Using Machine Learning.': ([], []),
#  'Introgression of regulatory alleles and a missense coding mutation drive plumage pattern diversity in the rock pigeon.': ([],
#   []),
#  'Synthesis of superabsorbent polymers based on chitosan derivative graft acrylic acid-co-acrylamide and its property testing.': ([],
#   []),
#  'Novel hyaluronic acid-modified temperature-sensitive nanoparticles for synergistic chemo-photothermal therapy.': ([],
#   []),
#  'Shenfu Injection Attenuates Bile Duct Injury in Rats with Acute Obstructive Cholangitis.': ([],
#   []),
#  'The relative resistance of children to sepsis mortality: from pathways to drug candidates.': ([],
#   []),
#  'Relatively frequent switching of transcription start sites during cerebellar development.': ([],
#   []),
#  'Lipid phenotyping of lung epithelial lining fluid in healthy human volunteers.': ([],
#   []),
#  'Three Major Efforts to Phenotype Asthma: Severe Asthma Research Program, Asthma Disease Endotyping for Personalized Therapeutics, and Unbiased Biomarkers for the Prediction of Respiratory Disease Outcome.': ([],
#   []),
#  'Results and Implications of Routine HIV Testing in the Inpatient Setting: A Descriptive Analysis.': ([],
#   []),
#  'Identification of Organ-Enriched Protein Biomarkers of Acute Liver Injury by Targeted Quantitative Proteomics of Blood in Acetaminophen- and Carbon-Tetrachloride-Treated Mouse Models and Acetaminophen Overdose Patients.': ([],
#   []),
#  'Differentiating bipolar disorder from borderline personality disorder: Diagnostic accuracy of the difficulty in emotion regulation scale and personality inventory for DSM-5.': ([],
#   []),
#  'Phase 1b trial of nintedanib in combination with bevacizumab in patients with advanced solid tumors.': ([],
#   []),
#  'Comparative genome analysis provides novel insight into the interaction of Aquimarina sp. AD1, BL5 and AD10 with their macroalgal host.': ([],
#   []),
#  'In vitro accuracy and inter-observer reliability of CT angiography in detecting intracranial aneurysm enlargement.': ([],
#   []),
#  'Medical student wellbeing - a consensus statement from Australia and New Zealand.': ([],
#   []),
#  'Neurophysiological, neuropsychological, and cognitive effects of 30 days of isolation.': ([],
#   []),
#  "The genome of the giant Nomura's jellyfish sheds light on the early evolution of active predation.": ([],
#   []),
#  'Influences of Age, Sex, and Moderate Alcohol Drinking on the Intrinsic Functional Architecture of Adolescent Brains.': ([],
#   []),
#  'Transient CNS responses to repeated binge ethanol treatment.': ([], []),
#  'Cabazitaxel overcomes cisplatin resistance in germ cell tumour cells.': ([],
#   []),
#  'Concomitants of alcoholism: differential effects of thiamine deficiency, liver damage, and food deprivation on the rat brain in vivo.': ([],
#   []),
#  'Brain metabolite levels in recently sober individuals with alcohol use disorder: Relation to drinking variables and relapse.': ([],
#   []),
#  'Circuit-theory applications to connectivity science and conservation.': ([],
#   []),
#  'Five fraction accelerated partial breast irradiation using noninvasive image-guided breast brachytherapy: Feasibility and acute toxicity.': ([],
#   []),
#  'A Systematic Review of the Risks and Benefits of Venous Thromboembolism Prophylaxis in Traumatic Brain Injury.': ([],
#   []),
#  'Chronic Hypoxia Enhances beta-Oxidation-Dependent Electron Transport via Electron Transferring Flavoproteins.': ([],
#   []),
#  'Polarization of Human Macrophages by Interleukin-4 Does Not Require ATP-Citrate Lyase.': ([],
#   []),
#  'Strong and specific associations between cardiovascular risk factors and white matter micro- and macrostructure in healthy aging.': ([],
#   []),
#  'TMEM126B deficiency reduces mitochondrial SDH oxidation by LPS, attenuating HIF-1alpha stabilization and IL-1beta expression.': ([],
#   []),
#  'Integrative omics analyses broaden treatment targets in human cancer.': ([],
#   []),
#  'Comprehensive Characterization of Cancer Driver Genes and Mutations.': ([],
#   []),
#  'Pathogenic Germline Variants in 10,389 Adult Cancers.': ([], []),
#  'Perspective on Oncogenic Processes at the End of the Beginning of Cancer Genomics.': ([],
#   []),
#  'Drosophila Histone Demethylase KDM5 Regulates Social Behavior through Immune Control and Gut Microbiota Maintenance.': ([],
#   []),
#  'Diverse tumour susceptibility in Collaborative Cross mice: identification of a new mouse model for human gastric tumourigenesis.': ([],
#   []),
#  'No difference in 4-nitroquinoline induced tumorigenesis between germ-free and colonized mice.': ([],
#   []),
#  'Exploiting regulatory heterogeneity to systematically identify enhancers with high accuracy.': ([],
#   []),
#  'A feasibility study of breast cancer genetic risk assessment in a federally qualified health center.': ([],
#   []),
#  'Descriptive characteristics of prostate cancer in patients with a history of primary male breast cancer - a SEER analysis.': ([],
#   []),
#  'Literature-based automated discovery of tumor suppressor p53 phosphorylation and inhibition by NEK2.': ([],
#   []),
#  'FARS2 deficiency; new cases, review of clinical, biochemical, and molecular spectra, and variants interpretation based on structural, functional, and evolutionary significance.': ([],
#   []),
#  'A high-throughput protocol for isolating cell-free circulating tumor DNA from peripheral blood.': ([],
#   []),
#  'Dietary Nutrients Involved in One-Carbon Metabolism and Colonic Mucosa-Associated Gut Microbiome in Individuals with an Endoscopically Normal Colon.': ([],
#   []),
#  'Transdermal lidocaine as treatment for chronic subjective tinnitus: A pilot study.': ([],
#   []),
#  'Consensus guidelines for the use of ultrasound for diving research.': ([],
#   []),
#  'Variation of bone acquisition during growth hormone treatment in children can be explained by proteomic biomarkers, bone formation markers, body composition and nutritional factors.': ([],
#   []),
#  '[Application of DNA metabarcoding in species identification of Chinese herbal medicines].': ([],
#   []),
#  'Comprehensive benchmarking and ensemble approaches for metagenomic classifiers.': ([],
#   []),
#  'The development of large-scale de-identified biomedical databases in the age of genomics-principles and challenges.': ([],
#   []),
#  'The role of alternative Polyadenylation in regulation of rhythmic gene expression.': ([],
#   []),
#  'Gene expression profiles at different stages for formation of pearl sac and pearl in the pearl oyster Pinctada fucata.': ([],
#   []),
#  'Limits of long-term selection against Neandertal introgression.': ([], []),
#  '"A Gay Man and a Doctor are Just like, a Recipe for Destruction": How Racism and Homonegativity in Healthcare Settings Influence PrEP Uptake Among Young Black MSM.': ([],
#   []),
#  'Lessons from Outside and Within: Exploring Advancements in Methodology for Naturopathic Medicine Clinical Research.': ([],
#   []),
#  'Consultations with Naturopaths and Western Herbalists: Prevalence of Use and Characteristics of Users in Australia.': ([],
#   []),
#  'The Bioavailability of Various Oral Forms of Folate Supplementation in Healthy Populations and Animal Models: A Systematic Review.': ([],
#   []),
#  'Associations Between Cancer Screening Behavior and Complementary Medicine Use: Results of a National Cross-Sectional Survey of 9151 Australian Women.': ([],
#   []),
#  "Investigation into complementary and integrative medicine practitioners' clinical experience of intestinal permeability: A cross-sectional survey.": ([],
#   []),
#  'How should we treat uncomplicated subacute type B aortic dissection in octogenarians?': ([],
#   []),
#  'Benefits of Outdoor Sports for Society. A Systematic Literature Review and Reflections on Evidence.': ([],
#   []),
#  'Antimicrobial susceptibility patterns of blood culture isolates from foals in Switzerland.': ([],
#   []),
#  'The role of genetics and genomics in clinical psychiatry.': ([], []),
#  'A Fosmid Pool-Based Next Generation Sequencing Approach to Haplotype-Resolve Whole Genomes.': ([],
#   []),
#  '[Beyond actinic keratoses: Field cancerization of the skin].': ([], []),
#  'Cardiac R2* values are independent of the image analysis approach employed.': ([],
#   []),
#  'A mutation in TGFB3 associated with a syndrome of low muscle mass, growth retardation, distal arthrogryposis and clinical features overlapping with Marfan and Loeys-Dietz syndrome.': ([],
#   []),
#  'A High-Quality De novo Genome Assembly from a Single Mosquito Using PacBio Sequencing.': ([],
#   []),
#  'Studies of the chloride transport in the gastric mucosa of the frog.': ([],
#   []),
#  'Water flow through frog gastric mucosa.': ([], []),
#  'Survival benefit of first-generation epidermal growth factor receptor-tyrosine kinase inhibitors in female with advanced lung cancer.': ([],
#   []),
#  'Raising awareness, screening and prevention of chronic kidney disease: It takes more than a village.': ([],
#   []),
#  'JBrowse: a dynamic web platform for genome visualization and analysis.': ([],
#   []),
#  'Non-invasive imaging techniques for the differentiation of acute and chronic thrombosis.': ([],
#   []),
#  'Targeting Mechanosensitive Transcription Factors in Atherosclerosis.': ([],
#   []),
#  'Endothelin-1 increases CHSY-1 expression in aortic endothelial cells via transactivation of transforming growth factor beta type I receptor induced by type B receptor endothelin-1.': ([],
#   []),
#  'In vivo quantification of mechanical properties of caudal fins in adult zebrafish.': ([],
#   []),
#  'Influenece of the CPRmeter on angular position of elbows and generated forces during cardiopulmonary resuscitation.': ([],
#   []),
#  'Dynamics of actinotrichia regeneration in the adult zebrafish fin.': ([],
#   []),
#  'Increased CD4(+) T cell lineage commitment determined by CpG methylation correlates with better prognosis in urinary bladder cancer patients.': ([],
#   []),
#  'Running with injury: A study of UK novice and recreational runners and factors associated with running related injury.': ([],
#   []),
#  'Optimal-Transport Analysis of Single-Cell Gene Expression Identifies Developmental Trajectories in Reprogramming.': ([],
#   []),
#  'Hypofractionated versus standard radiation therapy in combination with temozolomide for glioblastoma in the elderly: a meta-analysis.': ([],
#   []),
#  'Long-term anatomic and functional results of laparoscopic sacrocolpopexy: a prospective study.': ([],
#   []),
#  'Characterizing the Major Structural Variant Alleles of the Human Genome.': ([],
#   []),
#  'Establishing Cerebral Organoids as Models of Human-Specific Brain Evolution.': ([],
#   []),
#  'The role of the operating department practitioner on board Role 2 Afloat.': ([],
#   []),
#  'A systematic review of 3251 emergency department thoracotomies: is it time for a national database?': ([],
#   []),
#  'Integrating Family Planning and HIV Services at the Community Level: Formative Assessment with Village Health Teams in Uganda.': ([],
#   []),
#  'Development and validation of a noncompetitive electrochemiluminescence-based immunoassay (ECLIA) for specific determination of insulin lispro (Humalog(R)) in human serum to support pharmacokinetic assessments.': ([],
#   []),
#  'The Evolution of Oncology Companion Diagnostics from Signal Transduction to Immuno-Oncology.': ([],
#   []),
#  'DNA Commission of the International Society for Forensic Genetics: Recommendations on the validation of software programs performing biostatistical calculations for forensic genetics applications.': ([],
#   []),
#  'Clonal Deletion of Tumor-Specific T Cells by Interferon-gamma Confers Therapeutic Resistance to Combination Immune Checkpoint Blockade.': ([],
#   []),
#  'Comparison between broadband and monochromatic photopic negative response in full-field electroretinogram in controls and subjects with primary open-angle glaucoma.': ([],
#   []),
#  'Exonuclease Domain-Containing 1 Enhances MIWI2 piRNA Biogenesis via Its Interaction with TDRD12.': ([],
#   []),
#  'Randomized controlled multicentre study comparing short dental implants (6 mm) versus longer dental implants (11-15 mm) in combination with sinus floor elevation procedures: 5-Year data.': ([],
#   []),
#  'Number of implants placed for complete-arch fixed prostheses: A systematic review and meta-analysis.': ([],
#   []),
#  'An integrative study on biologically recovered polyhydroxyalkanoates (PHAs) and simultaneous assessment of gut microbiome in yellow mealworm.': ([],
#   []),
#  'Perspectives on Genetic Testing and Return of Results from the First Cohort of Presymptomatically Tested Individuals At Risk of Huntington Disease.': ([],
#   []),
#  'Enhancing Autonomy in Biobank Decisions: Too Much of a Good Thing?': ([],
#   []),
#  'The Therapeutic "Mis"conception: An Examination of its Normative Assumptions and a Call for its Revision.': ([],
#   []),
#  'Helium CT: Monte Carlo simulation results for an ideal source and detector with comparison to proton CT.': ([],
#   []),
#  'Validation of the radiobiology toolkit TOPAS-nBio in simple DNA geometries.': ([],
#   []),
#  'MEG Assessment of Expressive Language in Children Evaluated for Epilepsy Surgery.': ([],
#   []),
#  'Incarcerating Pregnant and Parenting Women, the New Witch Hunt: A Policy Analysis.': ([],
#   []),
#  'Drug consumption rooms in Catalonia: A comprehensive evaluation of social, health and harm reduction benefits.': ([],
#   []),
#  'Multiancestry Genome-Wide Association Study of Lipid Levels Incorporating Gene-Alcohol Interactions.': ([],
#   []),
#  'Cosmetic benefit of a biomimetic lamellar cream formulation on barrier function or the appearance of fine lines and wrinkles in randomized proof-of-concept clinical studies.': ([],
#   []),
#  'Breastfeeding prevalence among six-week-old infants at University Hospital of the West Indies.': ([],
#   []),
#  'The value of maintaining normokalaemia and enabling RAASi therapy in chronic kidney disease.': ([],
#   []),
#  'Cohort versus patient level simulation for the economic evaluation of single versus combination immuno-oncology therapies in metastatic melanoma.': ([],
#   []),
#  'Serum potassium and clinical outcomes in heart failure patients: results of risk calculations in 21 334 patients in the UK.': ([],
#   []),
#  'Cost-effectiveness of fluocinolone acetonide implant (ILUVIEN(R)) in UK patients with chronic diabetic macular oedema considered insufficiently responsive to available therapies.': ([],
#   []),
#  'Characterizing genetic variants for clinical action.': ([], []),
#  'Studies on coccidioides immitis. II. Physiological studies on in vitro spherulation.': ([],
#   []),
#  'Studies on Coccidioides immitis. I. A simple medium for in vitro spherulation.': ([],
#   []),
#  'In vitro conversion of Histoplasma capsulatum.': ([], []),
#  'Disease Progression After Lateral and Medial Unicondylar Knee Arthroplasty.': ([],
#   []),
#  'Impact of insurance type on eligibility for advanced heart failure therapies and survival.': ([],
#   []),
#  'Medical Child Abuse: An Unusual "Source" of Vaginal Bleeding.': ([], []),
#  'Quantitative Early Auxin Root Proteomics Identifies GAUT10, a Galacturonosyltransferase, as a Novel Regulator of Root Meristem Maintenance.': ([],
#   []),
#  'Spatial and temporal studies of metabolic activity: contrasting biochemical kinetics in tissues and pathways during fasted and fed states.': ([],
#   []),
#  'Transcranial optical imaging reveals a pathway for optimizing the delivery of immunotherapeutics to the brain.': ([],
#   []),
#  'Recurrent Noncoding Mutations in Skin Cancers: UV Damage Susceptibility or Repair Inhibition as Primary Driver?': ([],
#   []),
#  'Cholesterol increases protein levels of the E3 ligase MARCH6 and thereby stimulates protein degradation.': ([],
#   []),
#  'Murine Models of Intraperitoneal Perfusion for Disseminated Colorectal Cancer.': ([],
#   []),
#  'Hypoxia Promotes Immune Evasion by Triggering beta-Glucan Masking on the Candida albicans Cell Surface via Mitochondrial and cAMP-Protein Kinase A Signaling.': ([],
#   []),
#  'SMN deficiency in severe models of spinal muscular atrophy causes widespread intron retention and DNA damage.': ([],
#   []),
#  'Rescue of gene-expression changes in an induced mouse model of spinal muscular atrophy by an antisense oligonucleotide that promotes inclusion of SMN2 exon 7.': ([],
#   []),
#  'Testing the effects of four urbanization filters on forest plant taxonomic, functional, and phylogenetic diversity.': ([],
#   []),
#  'Novel phenotype-disease matching tool for rare genetic diseases.': ([], []),
#  'The Roles of Compensatory Evolution and Constraint in Aminoacyl tRNA Synthetase Evolution.': ([],
#   []),
#  'Increased frequency of de novo copy number variants in congenital heart disease by integrative analysis of single nucleotide polymorphism array and exome sequence data.': ([],
#   []),
#  'Analysis of chromosomal structural variation in patients with congenital left-sided cardiac lesions.': ([],
#   []),
#  'The use of alteration analysis in supercritical fluid chromatography to monitor changes in a series of chromatograms.': ([],
#   []),
#  'Spinal Intradural Escherichia coli Abscess Masquerading as a Neoplasm in a Pediatric Patient with History of Neonatal E. coli Meningitis: A Case Report and Literature Review.': ([],
#   []),
#  'Acquired, Comitant, Non-Accommodative Esotropia (ANAET): Evaluation, Treatment, and Prognosis.': ([],
#   []),
#  'Scaffold proteins LACK and TRACK as potential drug targets in kinetoplastid parasites: Development of inhibitors.': ([],
#   []),
#  'DAtA: database of Arabidopsis thaliana annotation.': ([], []),
#  'Genome-wide mapping with biallelic markers in Arabidopsis thaliana.': ([],
#   []),
#  'Randomised placebo-controlled trial of combination ACE inhibitor and beta-blocker therapy to prevent cardiomyopathy in children with Duchenne muscular dystrophy? (DMD Heart Protection Study): a protocol study.': ([],
#   []),
#  'Target (MexB)- and Efflux-Based Mechanisms Decreasing the Effectiveness of the Efflux Pump Inhibitor D13-9001 in Pseudomonas aeruginosa PAO1: Uncovering a New Role for MexMN-OprM in Efflux of beta-Lactams and a Novel Regulatory Circuit (MmnRS) Controlling MexMN Expression.': ([],
#   []),
#  'Charcot Marie Tooth disease type 2S with late onset diaphragmatic weakness: An atypical case.': ([],
#   []),
#  'Negative relationships between species richness and temporal variability are common but weak in natural systems.': ([],
#   []),
#  'Chronic pain has a strong impact on quality of life in facioscapulohumeral muscular dystrophy.': ([],
#   []),
#  'Accumulation of autophagosomes confers cytotoxicity.': ([], []),
#  'Prevalence and impact of obesity in people with haemophilia: Review of literature and expert discussion around implementing weight management guidelines.': ([],
#   []),
#  'Dynamics of an experimental microbial invasion.': ([], []),
#  'Fluorescence in situ hybridization and optical mapping to correct scaffold arrangement in the tomato genome.': ([],
#   []),
#  "Blood-Derived DNA Methylation Signatures of Crohn's Disease and Severity of Intestinal Inflammation.": ([],
#   []),
#  'Restoration of pyrethroid susceptibility in a highly resistant Aedes aegypti population.': ([],
#   []),
#  "A double-blind placebo-controlled cross-over clinical trial of DONepezil In Posterior cortical atrophy due to underlying Alzheimer's Disease: DONIPAD study.": ([],
#   []),
#  'Antibodies to Peptides in Semiconserved Domains of RIFINs and STEVORs Correlate with Malaria Exposure.': ([],
#   []),
#  'Barriers and enablers to implementing a virtual tertiary-regional Telemedicine Rounding and Consultation (TRAC) model of inpatient pediatric care using the Theoretical Domains Framework (TDF) approach: a study protocol.': ([],
#   []),
#  "Exploring residents' interest and career aspirations in global surgery.": ([],
#   []),
#  'Perioperative self-reflection among surgical residents.': ([], []),
#  'Do female surgeons learn or teach differently?': ([], []),
#  'A taxonomy of perioperative surgical learning: Trending resident skill acquisition.': ([],
#   []),
#  'Effects of vertebroplasty on endplate subsidence in elderly female spines.': ([],
#   []),
#  'Optimized GC-MS metabolomics for the analysis of kidney tissue metabolites.': ([],
#   []),
#  'Limited genetic variability of Cytauxzoon felis apical membrane antigen-1 (ama1) from domestic cats and bobcats.': ([],
#   []),
#  "Prospective study of the sensitivity of the Wood's lamp for common eye abnormalities.": ([],
#   []),
#  'Prevalence and correlates of psychological distress among 13-14 year old adolescent girls in North Karnataka, South India: a cross-sectional study.': ([],
#   []),
#  'Serum levels of insulin-like growth factor-1 and brain-derived neurotrophic factor as potential recovery biomarkers in stroke.': ([],
#   []),
#  'Gemcitabine Induces Microvesicle Particle Release in a Platelet-Activating Factor-Receptor-Dependent Manner via Modulation of the MAPK Pathway in Pancreatic Cancer Cells.': ([],
#   []),
#  'Associations of Mitochondrial and Nuclear Mitochondrial Variants and Genes with Seven Metabolic Traits.': ([],
#   []),
#  'HLA-DQA1 & DQB1 variants associated with hepatitis B virus-related chronic hepatitis, cirrhosis & hepatocellular carcinoma.': ([],
#   []),
#  'Intraosseous lipoma of the maxillary tuberosity: A rare entity with diagnostic challenge.': ([],
#   []),
#  'Efficacy of topically administered fluralaner or imidacloprid/moxidectin on dogs with generalised demodicosis.': ([],
#   []),
#  'Good Cell Culture Practice for stem cells and stem-cell-derived models.': ([],
#   []),
#  'Multidrug resistant Mannheimia haemolytica isolated from high-risk beef stocker cattle after antimicrobial metaphylaxis and treatment for bovine respiratory disease.': ([],
#   []),
#  'Construction and evaluation of type III secretion system mutants of the catfish pathogen Edwardsiella piscicida.': ([],
#   []),
#  'Covalent Structure and Bioactivity of the Type AII Lantibiotic Salivaricin A2.': ([],
#   []),
#  'Synonymous mutation in TP53 results in a cryptic splice site affecting its DNA-binding site in an adolescent with two primary sarcomas.': ([],
#   []),
#  'Allele-Specific Methylation of SPDEF: A Novel Moderator of Psychosocial Stress and Substance Abuse.': ([],
#   []),
#  'Transcriptome sequencing in pediatric acute lymphoblastic leukemia identifies fusion genes associated with distinct DNA methylation profiles.': ([],
#   []),
#  'Ramucirumab and Paclitaxel Administered Every 2 Weeks (mRAINBOW Regimen) in Advanced Gastroesophageal Adenocarcinoma.': ([],
#   []),
#  'Current synthetic pharmacotherapy for treatment-resistant colorectal cancer: when urgent action is required.': ([],
#   []),
#  'Sexual Assault Examination of the Unconscious Patient: A Legal, Ethical and Professional Grey-area for the Forensic Physician.': ([],
#   []),
#  'Parent and Provider Experience and Shared Understanding After a Family-Centered Nighttime Communication Intervention.': ([],
#   []),
#  'A Platform for Generation of Chamber-Specific Cardiac Tissues and Disease Modeling.': ([],
#   []),
#  'The ENTPD1 promoter polymorphism -860 A > G (rs3814159) is associated with increased gene transcription, protein expression, CD39/NTPDase1 enzymatic activity, and thromboembolism risk.': ([],
#   []),
#  'The impact of the UGT1A1*60 allele on bilirubin serum concentrations.': ([],
#   []),
#  'Genome-wide survey in African Americans demonstrates potential epistasis of fitness in the human genome.': ([],
#   []),
#  'Gene expression analyses of mouse aortic endothelium in response to atherogenic stimuli.': ([],
#   []),
#  'Mechanisms of silver nanoparticles-induced cytotoxicity and apoptosis in rat tracheal epithelial cells.': ([],
#   []),
#  'Investigating the impact of tumour motion on TomoTherapy stereotactic ablative body radiotherapy (SABR) deliveries on 3-dimensional and 4-dimensional computed tomography.': ([],
#   []),
#  'Hepatoprotective effect of alpha-mangostin against lipopolysaccharide/d-galactosamine-induced acute liver failure in mice.': ([],
#   []),
#  'Protective Effects of Sesquiterpenoids from the Root of Panax ginseng on Fulminant Liver Injury Induced by Lipopolysaccharide/d-Galactosamine.': ([],
#   []),
#  'Mouse Idh3a mutations cause retinal degeneration and reduced mitochondrial function.': ([],
#   []),
#  'Patient, Caregiver, and Taxpayer Knowledge of Palliative Care and Views on a Model of Community-Based Palliative Care.': ([],
#   []),
#  'The goya mouse mutant reveals distinct newly identified roles for MAP3K1 in the development and survival of cochlear sensory hair cells.': ([],
#   []),
#  'Clustering analysis of proteins from microbial genomes at multiple levels of resolution.': ([],
#   []),
#  'Update on Genomic Databases and Resources at the National Center for Biotechnology Information.': ([],
#   []),
#  'Carbon dots stabilized silver-lipid nano hybrids for sensitive label free DNA detection.': ([],
#   []),
#  'Array atomic force microscopy for real-time multiparametric analysis.': ([],
#   []),
#  'Water-soluble MoS2 quantum dots as effective fluorescence probe for the determination of bilirubin in human fluids.': ([],
#   []),
#  'Inhibition of monocyte-like cell extravasation protects from neurodegeneration in DBA/2J glaucoma.': ([],
#   []),
#  'Light-absorbing impurities in snow of the Indian Western Himalayas: impact on snow albedo, radiative forcing, and enhanced melting.': ([],
#   []),
#  'Decisional Balance and Contemplation Ladder to Support Interventions for HIV Pre-Exposure Prophylaxis Uptake and Persistence.': ([],
#   []),
#  'Methods for high-dimensional analysis of cells dissociated from cryopreserved synovial tissue': ([],
#   []),
#  'Early Epstein-Barr Virus Genomic Diversity and Convergence toward the B95.8 Genome in Primary Infection.': ([],
#   []),
#  'Acquiring nutrients from tree leaves: effects of leaf maturity and development type on a generalist caterpillar.': ([],
#   []),
#  'Evolvix BEST Names for semantic reproducibility across code2brain interfaces.': ([],
#   []),
#  'Mimicking biological membranes with programmable glycan ligands self-assembled from amphiphilic Janus glycodendrimers.': ([],
#   []),
#  'Rich and cold: diversity, distribution and drivers of fungal communities in patterned-ground ecosystems of the North American Arctic.': ([],
#   []),
#  'Regulated aggregative multicellularity in a close unicellular relative of metazoa.': ([],
#   []),
#  'The Embase UK filter: validation of a geographic search filter to retrieve research about the UK from OVID Embase.': ([],
#   []),
#  'The effect of linguistic background on rapid number naming: implications for native versus non-native English speakers on sideline-focused concussion assessments.': ([],
#   []),
#  'Gender- and region-specific changes in estrogen signaling in aging rat brain mitochondria.': ([],
#   []),
#  'Recombinant Listeria promotes tumor rejection by CD8(+) T cell-dependent remodeling of the tumor microenvironment.': ([],
#   []),
#  'Frequency and predictors of health services use by Native Hawaiians and Pacific Islanders: evidence from the U.S. National Health Interview Survey.': ([],
#   []),
#  'Genome sequencing identifies multiple deleterious variants in autism patients with more severe phenotypes.': ([],
#   []),
#  'Whole genome pyrosequencing of rare hepatitis C virus genotypes enhances subtype classification and identification of naturally occurring drug resistance variants.': ([],
#   []),
#  'Thyroid and reproductive hormones in relation to pesticide use in an agricultural population in Southern Brazil.': ([],
#   []),
#  'Characterisation and anti-biofilm activity of glycerol monolaurate nanocapsules against Pseudomonas aeruginosa.': ([],
#   []),
#  'Cortical and spinal excitability changes after repetitive transcranial magnetic stimulation combined to physiotherapy in stroke spastic patients.': ([],
#   []),
#  'DLL4 and Jagged1 are angiogenic targets of orphan nuclear receptor TR3/Nur77.': ([],
#   []),
#  'Identifying Selection Signatures for Backfat Thickness in Yorkshire Pigs Highlights New Regions Affecting Fat Metabolism.': ([],
#   []),
#  'Elevated Circulating CD4(+)CD25(-)Foxp3(+) Regulatory T Cells in Patients with Nonsmall Cell Lung Cancer.': ([],
#   []),
#  'Changes in Nanoscale Chain Assembly in Sweet Potato Starch Lamellae by Downregulation of Biosynthesis Enzymes.': ([],
#   []),
#  'Structure of the germline genome of Tetrahymena thermophila and relationship to the massively rearranged somatic genome.': ([],
#   []),
#  'Diet during Pregnancy and Infancy and the Infant Intestinal Microbiome.': ([],
#   []),
#  'An Analysis of the Epidemic of Klebsiella pneumoniae Carbapenemase-Producing K. pneumoniae: Convergence of Two Evolutionary Mechanisms Creates the "Perfect Storm".': ([],
#   []),
#  'Community characteristics of the gut microbiomes of competitive cyclists.': ([],
#   []),
#  'Frankenstein or a Submarine Alkaline Vent: Who is Responsible for Abiogenesis?: Part 2: As life is now, so it must have been in the beginning.': ([],
#   []),
#  'Frankenstein or a Submarine Alkaline Vent: Who Is Responsible for Abiogenesis?: Part 1: What is life-that it might create itself?': ([],
#   []),
#  'Honey bee neurogenomic responses to affiliative and agonistic social interactions.': ([],
#   []),
#  'Cross-species systems analysis of evolutionary toolkits of neurogenomic response to social challenge.': ([],
#   []),
#  'Neuromolecular responses to social challenge: common mechanisms across mouse, stickleback fish, and honey bee.': ([],
#   []),
#  'A distant downstream enhancer directs essential expression of Tbx18 in urogenital tissues.': ([],
#   []),
#  'Deep vertebrate roots for mammalian zinc finger transcription factor subfamilies.': ([],
#   []),
#  'Contemporary (2009-2014) clinical outcomes after femoropopliteal bypass surgery for chronic limb threatening ischemia are inferior to those reported in the UK Bypass versus Angioplasty for Severe Ischaemia of the Leg (BASIL) trial (1999-2004).': ([],
#   []),
#  'Survival prediction in patients with chronic limb-threatening ischemia who undergo infrainguinal revascularization.': ([],
#   []),
#  'Publication of UK NICE Clinical Guidelines 168 has not significantly changed the management of leg ulcers in primary care: An analysis of The Health Improvement Network database.': ([],
#   []),
#  'Obesity and lower limb venous disease - The epidemic of phlebesity.': ([],
#   []),
#  'The impact of 2013 UK NICE guidelines on the management of varicose veins at the Heart of England NHS Foundation Trust, Birmingham, UK.': ([],
#   []),
#  'A review of randomised controlled trials comparing ultrasound-guided foam sclerotherapy with endothermal ablation for the treatment of great saphenous varicose veins.': ([],
#   []),
#  'Vertical flow constructed wetlands for decentralized wastewater treatment in Jordan: Optimization of total nitrogen removal.': ([],
#   []),
#  'The Scalability of Wet Ball Milling for The Production of Nanosuspensions.': ([],
#   []),
#  'Modelling seasonal dynamics, population stability, and pest control in Aedes japonicus japonicus (Diptera: Culicidae).': ([],
#   []),
#  'smartPearls((R)) for dermal bioavailability enhancement - Long-term stabilization of suspensions by viscoelasticity.': ([],
#   []),
#  'Effects of a long-term home-based exercise training programme using minimal equipment vs. usual care in COPD patients: a study protocol for two multicentre randomised controlled trials (HOMEX-1 and HOMEX-2 trials).': ([],
#   []),
#  'Long-term effects of the fungicide pyrimethanil on aquatic primary producers in macrophyte-dominated outdoor mesocosms in two European ecoregions.': ([],
#   []),
#  'Particulate matter emissions of four types of one cigarette brand with and without additives: a laser spectrometric particulate matter analysis of secondhand smoke.': ([],
#   []),
#  'Patient care and paternalism: dilemmas of family practice.': ([], []),
#  'Standardized residency training in China: the new internal medicine curriculum.': ([],
#   []),
#  'A Randomized Controlled Trial using iTClamp, Direct Pressure, and Balloon Catheter Tamponade to Control Neck Hemorrhage in a Perfused Human Cadaver Model.': ([],
#   []),
#  'Eco-friendly synthesized spherical ZnO materials: Effect of the core-shell to solid morphology transition on antimicrobial activity.': ([],
#   []),
#  'SERIAL transmit - parallel receive (STxPRx) MR imaging produces acceptable proton image uniformity without compromising field of view or SAR guidelines for human neuroimaging at 9.4 Tesla.': ([],
#   []),
#  'Feasibility of 39-potassium MR imaging of a human brain at 9.4 Tesla.': ([],
#   []),
#  'Decreased serum TRAIL is associated with increased mortality in smokers with comorbid emphysema and coronary artery disease.': ([],
#   []),
#  'Computational modelling of internally cooled wet (ICW) electrodes for radiofrequency ablation: impact of rehydration, thermal convection and electrical conductivity.': ([],
#   []),
#  "Beyond aphasia: Altered EEG connectivity in Broca's patients during working memory task.": ([],
#   []),
#  'Corticospinal and transcallosal modulation of unilateral and bilateral contractions of lower limbs.': ([],
#   []),
#  'Interventions to improve vaccine acceptance among rheumatoid arthritis patients: a systematic review.': ([],
#   []),
#  'Spore Germination Requires Ferrichrome Biosynthesis and the Siderophore Transporter Str1 in Schizosaccharomyces pombe.': ([],
#   []),
#  'Loss of hepatic DEPTOR alters the metabolic transition to fasting.': ([],
#   []),
#  'Heme Assimilation in Schizosaccharomyces pombe Requires Cell-surface-anchored Protein Shu1 and Vacuolar Transporter Abc3.': ([],
#   []),
#  'Loss of UCP2 impairs cold-induced non-shivering thermogenesis by promoting a shift toward glucose utilization in brown adipose tissue.': ([],
#   []),
#  '[Relationship of distribution frequency of HLA antigen/antibody and PIRCHE score with DSA production and AMR occurrence].': ([],
#   []),
#  'Personalized oncogenomic analysis of metastatic adenoid cystic carcinoma: using whole-genome sequencing to inform clinical decision-making.': ([],
#   []),
#  'Application of genomics to identify therapeutic targets in recurrent pediatric papillary thyroid carcinoma.': ([],
#   []),
#  'The epidemiology of HIV and other sexually transmitted infections in African, Caribbean and Black men in Toronto, Canada.': ([],
#   []),
#  'Integrated epigenomic profiling reveals endogenous retrovirus reactivation in renal cell carcinoma.': ([],
#   []),
#  'Spatio-temporal spillover risk of yellow fever in Brazil.': ([], []),
#  'Stable isotope labeling methods for DNA.': ([], []),
#  'Protein Synthesis in Coupled and Uncoupled Cell-Free Prokaryotic Gene Expression Systems.': ([],
#   []),
#  'TLR4, TRIF, and MyD88 are essential for myelopoiesis and CD11c(+) adipose tissue macrophage production in obese mice.': ([],
#   []),
#  'A study of pedestrian compliance with traffic signals for exclusive and concurrent phasing.': ([],
#   []),
#  'Polymorphism discovery in high-throughput resequenced microarray-enriched human genomic loci.': ([],
#   []),
#  'Establishment of a rapid and footprint-free protocol for differentiation of human embryonic stem cells into pancreatic endocrine cells with synthetic mRNAs encoding transcription factors.': ([],
#   []),
#  'Artificial neural network models for prediction of daily fine particulate matter concentrations in Algiers.': ([],
#   []),
#  'Forecasting PM10 in Algiers: efficacy of multilayer perceptron networks.': ([],
#   []),
#  'A Common Type 2 Diabetes Risk Variant Potentiates Activity of an Evolutionarily Conserved Islet Stretch Enhancer and Increases C2CD4A and C2CD4B Expression.': ([],
#   []),
#  'Everolimus rescues multiple cellular defects in laminopathy-patient fibroblasts.': ([],
#   []),
#  'Patient organ doses from megavoltage computed tomography delivery with a helical tomotherapy unit using a general treatment planning system.': ([],
#   []),
#  'Focal traumatic brain injury induces neuroplastic molecular responses in lumbar spinal cord.': ([],
#   []),
#  'Lateral thoracoaxillar dermal-fat flap for breast conserving surgery: the changes of the indication and long-term results.': ([],
#   []),
#  'On the feasibility of transperineal 3D ultrasound image guidance for robotic radical prostatectomy.': ([],
#   []),
#  'Dominance of international high-risk clones in carbapenemase-producing Pseudomonas aeruginosa: Multicentric molecular epidemiology report from India.': ([],
#   []),
#  'Microenvironment-Mediated Mechanisms of Resistance to HER2 Inhibitors Differ between HER2+ Breast Cancer Subtypes.': ([],
#   []),
#  'The Library of Integrated Network-Based Cellular Signatures NIH Program: System-Level Cataloging of Human Cells Response to Perturbations.': ([],
#   []),
#  'Early Experience with Laparoscopic Frey Procedure for Chronic Pancreatitis: a Case Series and Review of Literature.': ([],
#   []),
#  'Investigation of Optimal Afferent Feedback Modality for Inducing Neural Plasticity with A Self-Paced Brain-Computer Interface.': ([],
#   []),
#  'Pathophysiological central nervous system changes in a porcine model of acetaminophen-induced acute liver failure.': ([],
#   []),
#  'Early weaning completely eliminates porcine cytomegalovirus from a newly established pig donor facility for xenotransplantation.': ([],
#   []),
#  'Porcine endogenous retroviruses: Quantification of the copy number in cell lines, pig breeds, and organs.': ([],
#   []),
#  'The normal trachea is cleaned by MUC5B mucin bundles from the submucosal glands coated with the MUC5AC mucin.': ([],
#   []),
#  'Unusual retinopathy in a child with severe combined immune deficiency.': ([],
#   []),
#  'The Munich MIDY Pig Biobank - A unique resource for studying organ crosstalk in diabetes.': ([],
#   []),
#  'The dNTP triphosphohydrolase activity of SAMHD1 persists during S-phase when the enzyme is phosphorylated at T592.': ([],
#   []),
#  'Cryo-EM structure of Mcm2-7 double hexamer on DNA suggests a lagging-strand DNA extrusion model.': ([],
#   []),
#  'Structural and mechanistic insights into Mcm2-7 double-hexamer assembly and function.': ([],
#   []),
#  'Development of antibodies to and PCR detection of Ehrlichia spp. in dogs following natural tick exposure.': ([],
#   []),
#  'Domain within the helicase subunit Mcm4 integrates multiple kinase signals to control DNA replication initiation and fork progression.': ([],
#   []),
#  'A cluster randomised controlled trial of an intervention to increase the implementation of school physical activity policies and guidelines: study protocol for the physically active children in education (PACE) study.': ([],
#   []),
#  'Agreement between telehealth and face-to-face assessment of intellectual ability in children with specific learning disorder.': ([],
#   []),
#  'Typology of new psychoactive substance use among the general Australian population.': ([],
#   []),
#  'Implant Survival and Patient-Reported Outcomes After Total Hip Arthroplasty in Young Patients.': ([],
#   []),
#  'Dietary intake of energy-dense, nutrient-poor and nutrient-dense food sources in children with cystic fibrosis.': ([],
#   []),
#  'Health-related quality of life burden in severe asthma.': ([], []),
#  'Multidimensional assessment of severe asthma: A systematic review and meta-analysis.': ([],
#   []),
#  'Genomic profiling in advanced stage non-small-cell lung cancer patients with platinum-based chemotherapy identifies germline variants with prognostic value in SMYD2.': ([],
#   []),
#  'Multitrait genome association analysis identifies new susceptibility genes for human anthropometric variation in the GCAT cohort.': ([],
#   []),
#  'Large-scale screening of circulating microRNAs in individuals with HIV-1 mono-infections reveals specific liver damage signatures.': ([],
#   []),
#  'GCAT|Genomes for life: a prospective cohort study of the genomes of Catalonia.': ([],
#   []),
#  'Gene expression changes in blood RNA after swimming in a chlorinated pool.': ([],
#   []),
#  'T cells in IgA nephropathy: role in pathogenesis, clinical significance and potential therapeutic target.': ([],
#   []),
#  'The integration of inflammaging in age-related diseases.': ([], []),
#  'Naturally occurring xanthone and benzophenone derivatives exert significant anti-proliferative and proapoptotic effects in vitro on synovial fibroblasts and macrophages from rheumatoid arthritis patients.': ([],
#   []),
#  'Heterogeneity of the cytokinome in undifferentiated arthritis progressing to rheumatoid arthritis and its change in the course of therapy. Move toward personalized medicine.': ([],
#   []),
#  'Influence of oxygen concentration on T cell proliferation and susceptibility to apoptosis in healthy men and women.': ([],
#   []),
#  'Inhibitory Effects of Danshen components on CYP2C8 and CYP2J2.': ([], []),
#  '[Screen astragalosides from Huangqi injections by LC-TOF-MS-based mass defect filtering approach].': ([],
#   []),
#  'Clinical tolerability and pharmacokinetics of Erigerontis hydroxybenzene injection: results of a randomized phase I study in healthy Chinese volunteers.': ([],
#   []),
#  'In silico target fishing for the potential bioactive components contained in Huanglian Jiedu Tang (HLJDD) and elucidating molecular mechanisms for the treatment of sepsis.': ([],
#   []),
#  'No Effect of Polystyrene Microplastics on Foraging Activity and Survival in a Post-larvae Coral-Reef Fish, Acanthurus triostegus.': ([],
#   []),
#  'Evaluation of microplastic ingestion by tropical fish from Moorea Island, French Polynesia.': ([],
#   []),
#  'Tooth movement rate and anchorage lost during canine retraction: A maxillary and mandibular comparison.': ([],
#   []),
#  'Nox4 genetic inhibition in experimental hypertension and metabolic syndrome.': ([],
#   []),
#  'Fibulocalcaneal Impingement in a Growing Child With Otherwise Asymptomatic Talocalcaneal Coalition.': ([],
#   []),
#  'A Wars2 Mutant Mouse Model Displays OXPHOS Deficiencies and Activation of Tissue-Specific Stress Response Pathways.': ([],
#   []),
#  'A mouse model for inherited renal fibrosis associated with endoplasmic reticulum stress.': ([],
#   []),
#  'The Relationship Between Tobacco Smoke Exposure and Airflow Obstruction in US Children: Analysis of the National Health and Nutrition Examination Survey (2007-2012).': ([],
#   []),
#  'Trunk peak torque, muscle activation pattern and sudden loading compensation in adolescent athletes with back pain.': ([],
#   []),
#  'Effectiveness of an interactive telerehabilitation system with home-based exercise training in patients after total hip or knee replacement: study protocol for a multicenter, superiority, no-blinded randomized controlled trial.': ([],
#   []),
#  'Fishing for leadership: The role diversification plays in facilitating change agents.': ([],
#   []),
#  'High Plasma sRAGE (Soluble Receptor for Advanced Glycation End Products) Is Associated With Slower Carotid Intima-Media Thickness Progression and Lower Risk for First-Time Coronary Events and Mortality.': ([],
#   []),
#  'Prevention of Cardiovascular Disease and Cancer Mortality by Achieving Healthy Dietary Goals for the Swedish Population: A Macro-Simulation Modelling Study.': ([],
#   []),
#  'Physical activity may compensate for prolonged TV time regarding pulse rate-a cross-sectional study.': ([],
#   []),
#  'Conceptualizing multiple drug use in patients with comorbidity and multimorbidity: proposal for standard definitions beyond the term polypharmacy.': ([],
#   []),
#  'The Therapeutic Impact of New Migraine Discoveries.': ([], []),
#  'Migraine, Neurogenic Inflammation, Drug Development - Pharmacochemical Aspects.': ([],
#   []),
#  'Topical dura mater application of CFA induces enhanced expression of c-fos and glutamate in rat trigeminal nucleus caudalis: attenuated by KYNA derivate (SZR72).': ([],
#   []),
#  'Tamoxifen inhibits the biosynthesis of inositolphosphorylceramide in Leishmania.': ([],
#   []),
#  'Yeast: bridging the gap between phenotypic and biochemical assays for high-throughput screening.': ([],
#   []),
#  'Investigating the anti-leishmanial effects of linear peptoids.': ([], []),
#  'Yeast as a potential vehicle for neglected tropical disease drug discovery.': ([],
#   []),
#  'A Novel Eukaryotic Denitrification Pathway in Foraminifera.': ([], []),
#  'A Synthetic Alternative to Canonical One-Carbon Metabolism.': ([], []),
#  'Reformatted images improve the detection rate of acute traumatic subdural hematomas on brain CT compared with axial images alone.': ([],
#   []),
#  'Longitudinal genomic surveillance of Plasmodium falciparum malaria parasites reveals complex genomic architecture of emerging artemisinin resistance.': ([],
#   []),
#  'Multi-institute analysis of carbapenem resistance reveals remarkable diversity, unexplained mechanisms, and limited clonal outbreaks.': ([],
#   []),
#  'Slowing down glioblastoma progression in mice by running or the anti-malarial drug dihydroartemisinin? Induction of oxidative stress in murine glioblastoma therapy.': ([],
#   []),
#  'Recent Selection Changes in Human Genes under Long-Term Balancing Selection.': ([],
#   []),
#  'CRISPR/Cas9-mediated gene knockin in the hydroid Hydractinia symbiolongicarpus.': ([],
#   []),
#  'The maternal-zygotic transition and zygotic activation of the Mnemiopsis leidyi genome occurs within the first three cleavage cycles.': ([],
#   []),
#  'Functional studies on the role of Notch signaling in Hydractinia development.': ([],
#   []),
# ...
#   []),
#  'Tuberculosis and other bacterial co-infection in Cambodia: a single center retrospective cross-sectional study.': ([],
#   []),
#  'Exonic sequencing identifies TLR1 genetic variation associated with mortality in Thais with melioidosis.': ([],
#   []),
#  'Entry, Intracellular Survival, and Multinucleated-Giant-Cell-Forming Activity of Burkholderia pseudomallei in Human Primary Phagocytic and Nonphagocytic Cells.': ([],
#   []),
#  'Heterozygous genotype at codon 129 correlates with prolonged disease course in Heidenhain variant sporadic CJD: case report.': ([],
#   []),
#  'Localised cutaneous microvascular adaptation to exercise training in humans.': ([],
#   []),
#  'Biopsychosocial Distress in Young Adult Oncology Patients: Examining Sex Differences in Sources of High Distress and Requests for Assistance.': ([],
#   []),
#  'Work-life integration in neuropsychology: a review of the existing literature and preliminary recommendations.': ([],
#   []),
#  'Emerging applications of genome-editing technology to examine functionality of GWAS-associated variants for complex traits.': ([],
#   []),
#  'Proteolytic shedding of the prion protein via activation of metallopeptidase ADAM10 reduces cellular binding and toxicity of amyloid-beta oligomers.': ([],
#   []),
#  'Extracellular and Luminal pH Regulation by Vacuolar H+-ATPase Isoform Expression and Targeting to the Plasma Membrane and Endosomes.': ([],
#   []),
#  'Comparative genome analyses of novel Mangrovimonas-like strains isolated from estuarine mangrove sediments reveal xylan and arabinan utilization genes.': ([],
#   []),
#  'Association between Two Common Missense Substitutions, Thr6Lys and Val81Ile, in MC3R Gene and Childhood Obesity: A Meta-Analysis.': ([],
#   []),
#  'Clinical versus patient-reported measures of depression in bariatric surgery.': ([],
#   []),
#  'A Defective Pentose Phosphate Pathway Reduces Inflammatory Macrophage Responses during Hypercholesterolemia.': ([],
#   []),
#  'Myeloid Kdm6b deficiency results in advanced atherosclerosis.': ([], []),
#  'Vaccine-Induced Protection from Homologous Tier 2 SHIV Challenge in Nonhuman Primates Depends on Serum-Neutralizing Antibody Titers.': ([],
#   []),
#  'Molecular Diversity and Specializations among the Cells of the Adult Mouse Brain.': ([],
#   []),
#  'A guide to genome-wide association analysis and post-analytic interrogation.': ([],
#   []),
#  'Sensory neuropathy with bone destruction due to a mutation in the membrane-shaping atlastin GTPase 3.': ([],
#   []),
#  'Proper development of the outer longitudinal smooth muscle of the mouse pylorus requires Nkx2-5 and Gata3.': ([],
#   []),
#  'Multiple spotty lesions of the spinal cord in a Chinese patient with human T-lymphotropic virus type 1-associated myelopathy/tropical spastic paraparesis.': ([],
#   []),
#  'Simian Immunodeficiency Virus Targeting of CXCR3(+) CD4(+) T Cells in Secondary Lymphoid Organs Is Associated with Robust CXCL10 Expression in Monocyte/Macrophage Subsets.': ([],
#   []),
#  'Effects of host restriction factors and the HTLV-1 subtype on susceptibility to HTLV-1-associated myelopathy/tropical spastic paraparesis.': ([],
#   []),
#  'Menin mediates Tat-induced neuronal apoptosis in brain frontal cortex of SIV-infected macaques and in Tat-treated cells.': ([],
#   []),
#  'Depletion of Nesprin-2 is associated with an embryonic lethal phenotype in mice.': ([],
#   []),
#  'The Chara Genome: Secondary Complexity and Implications for Plant Terrestrialization.': ([],
#   []),
#  'Multiple Roots of Fruiting Body Formation in Amoebozoa.': ([], []),
#  'Transcriptomic profiling of Alexandrium fundyense during physical interaction with or exposure to chemical signals from the parasite Amoebophrya.': ([],
#   []),
#  'The Physarum polycephalum Genome Reveals Extensive Use of Prokaryotic Two-Component and Metazoan-Type Tyrosine Kinase Signaling.': ([],
#   []),
#  'The butterfly plant arms-race escalated by gene and genome duplications.': ([],
#   []),
#  'Genome size shifts: karyotype evolution in Crepis section Neglectoides (Asteraceae).': ([],
#   []),
#  'Evaluation of Recipients of Positive and Negative Secondary Findings Evaluations in a Hybrid CLIA-Research Sequencing Pilot.': ([],
#   []),
#  'Assessing the spectrum of germline variation in Fanconi anemia genes among patients with head and neck carcinoma before age 50.': ([],
#   []),
#  'Somatic mutation profiles of clear cell endometrial tumors revealed by whole exome and targeted gene sequencing.': ([],
#   []),
#  'Clinical and molecular phenotyping of a child with Hermansky-Pudlak syndrome-7, an uncommon genetic type of HPS.': ([],
#   []),
#  'Clinical Application of Genomic Profiling With Circulating Tumor DNA for Management of Advanced Non-Small-cell Lung Cancer in Asia.': ([],
#   []),
#  'Evolution of chloroplast retrograde signaling facilitates green plant adaptation to land.': ([],
#   []),
#  'Divergent gene expression levels between diploid and autotetraploid Tolmiea relative to the total transcriptome, the cell, and biomass.': ([],
#   []),
#  'Plastid phylogenomic analysis of green plants: A billion years of evolutionary history.': ([],
#   []),
#  'Origin and evolution of the nuclear auxin response system.': ([], []),
#  'Awake craniotomy for excision of arteriovenous malformations? A qualitative comparison study with stereotactic radiosurgery.': ([],
#   []),
#  'Cognitive Outcomes of Patients with Traumatic Bifrontal Contusions.': ([],
#   []),
#  'Identification of an algal xylan synthase indicates that there is functional orthology between algal and plant cell wall biosynthesis.': ([],
#   []),
#  'Targeting promiscuous heterodimerization overcomes innate resistance to ERBB2 dimerization inhibitors in breast cancer.': ([],
#   []),
#  'Pre-clinical endodontic education outcomes between artificial versus extracted natural teeth: a systematic review.': ([],
#   []),
#  'The Proliferative and Apoptotic Landscape of Basal-like Breast Cancer.': ([],
#   []),
#  'Longitudinal analysis of Voice Handicap Index in early glottic cancer patients treated with transoral laser microsurgery: age, gender, stage and time dependence.': ([],
#   []),
#  'Comparison of the firefighter candidate physical ability test to weight lifting exercises using electromyography.': ([],
#   []),
#  'Recruitment tolerance to increased temperature present across multiple kelp clades.': ([],
#   []),
#  'Using a birth cohort to study brain health and preclinical dementia: recruitment and participation rates in Insight 46.': ([],
#   []),
#  'Efficacy and safety of alemtuzumab in Korean multiple sclerosis patients.': ([],
#   []),
#  'Evaluation of pulmonary toxicity of benzalkonium chloride and triethylene glycol mixtures using in vitro and in vivo systems.': ([],
#   []),
#  'Association between premature ovarian insufficiency, early menopause, socioeconomic status in a nationally representative sample from Korea.': ([],
#   []),
#  'Factors predicting remission in thymectomized patients with acetylcholine receptor antibody-positive myasthenia gravis.': ([],
#   []),
#  "Alzheimer's Disease Model System Using Drosophila.": ([], []),
#  'Preparation and evaluation of beta-glucan hydrogel prepared by the radiation technique for drug carrier applications.': ([],
#   []),
#  'Insights into genetics, human biology and disease gleaned from family based genomic studies.': ([],
#   []),
#  'Transethnic insight into the genetics of glycaemic traits: fine-mapping results from the Population Architecture using Genomics and Epidemiology (PAGE) consortium.': ([],
#   []),
#  'Regression of solid breast tumours in mice by Newcastle disease virus is associated with production of apoptosis related-cytokines.': ([],
#   []),
#  'T-Cell Exhaustion in Chronic Infections: Reversing the State of Exhaustion and Reinvigorating Optimal Protective Immune Responses.': ([],
#   []),
#  'Aberrant monocyte responses predict and characterize dengue virus infection in individuals with severe disease.': ([],
#   []),
#  'Prevalence of pathogenic/likely pathogenic variants in the 24 cancer genes of the ACMG Secondary Findings v2.0 list in a large cancer cohort and ethnicity-matched controls.': ([],
#   []),
#  'Untangling Flavobacterium johnsoniae Gliding Motility and Protein Secretion.': ([],
#   []),
#  'Compound heterozygous alterations in intraflagellar transport protein CLUAP1 in a child with a novel Joubert and oral-facial-digital overlap syndrome.': ([],
#   []),
#  'Neutralization of Bactericidal Activity Related to Antimicrobial Carryover in Broiler Carcass Rinse Samples.': ([],
#   []),
#  'Hypothalamic mechanisms associated with corticotropin-releasing factor-induced anorexia in chicks.': ([],
#   []),
#  'Alpha-melanocyte stimulating hormone-induced anorexia in Japanese quail (Coturnix japonica) likely involves the ventromedial hypothalamus and paraventricular nucleus of the hypothalamus.': ([],
#   []),
#  'Central injection of a synthetic chicken partial leptin peptide does not affect food intake in chicks.': ([],
#   []),
#  'Differential expression of appetite-regulating genes in avian models of anorexia and obesity.': ([],
#   []),
#  'A high fat diet enhances the sensitivity of chick adipose tissue to the effects of centrally injected neuropeptide Y on gene expression of adipogenesis-associated factors.': ([],
#   []),
#  'The central anorexigenic mechanism of amylin in Japanese quail (Coturnix japonica) involves pro-opiomelanocortin, calcitonin receptor, and the arcuate nucleus of the hypothalamus.': ([],
#   []),
#  'Broad spectrum triazoles for invasive mould infections in adults: Which drug and when?': ([],
#   []),
#  'Rationale, design and baseline characteristics of the effect of ticagrelor on health outcomes in diabetes mellitus patients Intervention study.': ([],
#   []),
#  'Rare mould infections caused by Mucorales, Lomentospora prolificans and Fusarium, in San Diego, CA: the role of antifungal combination therapy.': ([],
#   []),
#  'Activated Clotting Time to Guide Heparin Dosing in Non-ST-Segment-Elevation Acute Coronary Syndrome Patients Undergoing Percutaneous Coronary Intervention and Treated With IIb/IIIa Inhibitors: Impact on Ischemic and Bleeding Outcomes: Insights From the TAO Trial.': ([],
#   []),
#  'Smarcal1-Mediated Fork Reversal Triggers Mre11-Dependent Degradation of Nascent DNA in the Absence of Brca2 and Stable Rad51 Nucleofilaments.': ([],
#   []),
#  'Moonlighting at replication forks - a new life for homologous recombination proteins BRCA1, BRCA2 and RAD51.': ([],
#   []),
#  'The pseudo GTPase CENP-M drives human kinetochore assembly.': ([], []),
#  'Comparative assessment of efficacy and safety potential of multifarious lipid based Tacrolimus loaded nanoformulations.': ([],
#   []),
#  'Development of strategy for simultaneous enhanced production of alkaline xylanase-pectinase enzymes by a bacterial isolate in short submerged fermentation cycle.': ([],
#   []),
#  'Electroanatomical Remodeling of the Atria in Obesity: Impact of Adjacent Epicardial Fat.': ([],
#   []),
#  'Clinical trial in healthy malaria-naive adults to evaluate the safety, tolerability, immunogenicity and efficacy of MuStDO5, a five-gene, sporozoite/hepatic stage Plasmodium falciparum DNA vaccine combined with escalating dose human GM-CSF DNA.': ([],
#   []),
#  'Analysis of 1508 Plasma Samples by Capillary-Flow Data-Independent Acquisition Profiles Proteomics of Weight Loss and Maintenance.': ([],
#   []),
#  'Plasma Proteomics for Epidemiology: Increasing Throughput With Standard-Flow Rates.': ([],
#   []),
#  'Miles to go (mtgo) encodes FNDC3 proteins that interact with the chaperonin subunit CCT3 and are required for NMJ branching and growth in Drosophila.': ([],
#   []),
#  'Cell-specific deletion of C1qa identifies microglia as the dominant source of C1q in mouse brain.': ([],
#   []),
#  'Deficiency in the mouse mitochondrial adenine nucleotide translocator isoform 2 gene is associated with cardiac noncompaction.': ([],
#   []),
#  'An Integrated Genome-wide CRISPRa Approach to Functionalize lncRNAs in Drug Resistance.': ([],
#   []),
#  'Fatty acid synthase mediates EGFR palmitoylation in EGFR mutated non-small cell lung cancer.': ([],
#   []),
#  'Mapping Molecular Datasets Back to the Brain Regions They are Extracted from: Remembering the Native Countries of Hypothalamic Expatriates and Refugees.': ([],
#   []),
#  'Ontogeny of white matter, toll-like receptor expression, and motor skills in the neonatal ferret.': ([],
#   []),
#  'Genomic and molecular characterization of preterm birth.': ([], []),
#  'Rare variants in neuronal excitability genes influence risk for bipolar disorder.': ([],
#   []),
#  'Peri-arterial specification of vascular mural cells from naive mesenchyme requires Notch signaling.': ([],
#   []),
#  'Immune responses in cardiac repair and regeneration: a comparative point of view.': ([],
#   []),
#  'In vivo analysis of cardiomyocyte proliferation during trabeculation.': ([],
#   []),
#  'Hyperprolactinemia-inducing antipsychotics increase breast cancer risk by activating JAK-STAT5 in precancerous lesions.': ([],
#   []),
#  'Essential role for centromeric factors following p53 loss and oncogenic transformation.': ([],
#   []),
#  'Biophysical models reveal the relative importance of transporter proteins and impermeant anions in chloride homeostasis.': ([],
#   []),
#  'Reproducibility of Molecular Phenotypes after Long-Term Differentiation to Human iPSC-Derived Neurons: A Multi-Site Omics Study.': ([],
#   []),
#  'Neuronal Chloride Regulation via KCC2 Is Modulated through a GABAB Receptor Protein Complex.': ([],
#   []),
#  'Impact of UV-B radiation on the photosystem II activity, pro-/antioxidant balance and expression of light-activated genes in Arabidopsis thaliana hy4 mutants grown under light of different spectral composition.': ([],
#   []),
#  'Long-term impact of cement plant emissions on the elemental composition of both soils and pine stands and on the formation of Scots pine seeds.': ([],
#   []),
#  'Effects of 24-epibrassinolide and green light on plastid gene transcription and cytokinin content of barley leaves.': ([],
#   []),
#  'Effects of copper deficiency and copper toxicity on organogenesis and some physiological and biochemical responses of Scots pine (Pinus sylvestris L.) seedlings grown in hydroculture.': ([],
#   []),
#  'Blue light alters miR167 expression and microRNA-targeted auxin response factor genes in Arabidopsis thaliana plants.': ([],
#   []),
#  'Effects of zinc on Scots pine (Pinus sylvestris L.) seedlings grown in hydroculture.': ([],
#   []),
#  'Mutations in MAST1 Cause Mega-Corpus-Callosum Syndrome with Cerebellar Hypoplasia and Cortical Malformations.': ([],
#   []),
#  'Diversity and regulatory impact of copy number variation in the primate Macaca fascicularis.': ([],
#   []),
#  'Inflammatory myopathy in a patient with Aicardi-Goutieres syndrome.': ([],
#   []),
#  'Identification of a RAI1-associated disease network through integration of exome sequencing, transcriptomics, and 3D genomics.': ([],
#   []),
#  'Cartilage-Targeted IGF-1 Treatment to Promote Longitudinal Bone Growth.': ([],
#   []),
#  'In-line monitoring of Ibuprofen during and after tablet compression using near-infrared spectroscopy.': ([],
#   []),
#  'HCV Broadly Neutralizing Antibodies Use a CDRH3 Disulfide Motif to Recognize an E2 Glycoprotein Site that Can Be Targeted for Vaccine Design.': ([],
#   []),
#  'Modeling double strand break susceptibility to interrogate structural variation in cancer.': ([],
#   []),
#  'The experience among patients with multiple dental loss as a consequence of treatment for head and neck cancer: A qualitative study.': ([],
#   []),
#  'Breaking point: the genesis and impact of structural variation in tumours.': ([],
#   []),
#  'The circadian dynamics of small nucleolar RNA in the mouse liver.': ([], []),
#  'Lost in space? Generalising subtree prune and regraft to spaces of phylogenetic networks.': ([],
#   []),
#  'Changes in the demographics of intravenous drug users with mycotic common femoral artery pseudoaneurysm as a consequence of self-injection does not influence outcome following emergency ligation.': ([],
#   []),
#  'On the quirks of maximum parsimony and likelihood on phylogenetic networks.': ([],
#   [])}

# %%
# Identify Roots of each sentence to summarize title content
roots = {}

for index, row in df.iterrows():
    text = ' '.join(row['tokenized_title'])
    roots[row['title']] = []
    doc = nlp(text)
    for chunk in doc.noun_chunks:
        subject = 0
        object_ = 0
        if chunk.root.dep_ == 'ROOT':
            roots[row['title']].append(chunk.text)

# %%
roots
# Out:
# {'The current practice and care of paediatric patients post cardiac catheterisation.': [],
#  'Current pharmacological treatment guidelines for psoriasis and psoriatic arthritis.': ['current pharmacological treatment guidelines'],
#  'Early life trauma: An exploratory study of effects on OXTR and NR3C1 gene expression and nurturing self-efficacy in mothers of infants.': [],
#  'Telomerase Impinges on the Cellular Response to Oxidative Stress Through Mitochondrial ROS-Mediated Regulation of Autophagy.': ['telomerase impinges'],
#  'Social Origins of Developmental Risk for Mental and Physical Illness.': ['social origins'],
#  'Dissecting the Causal Mechanism of X-Linked Dystonia-Parkinsonism by Integrating Genome and Transcriptome Assembly.': [],
#  'Differential alveolar bone modeling after orthodontic retraction.': ['differential alveolar bone modeling'],
#  'Intraoperative hypotension is a risk factor for postoperative acute kidney injury after femoral neck fracture surgery: a retrospective study.': [],
#  'Hereditary spherocytosis caused by copy number variation in SPTB gene identified through targeted next-generation sequencing.': [],
#  'Hepatic serum amyloid A1 upregulates interleukin-17 (IL-17) in gammadelta T cells through Toll-like receptor 2 and is associated with psoriatic symptoms in transgenic mice.': ['interleukin-17 il-17'],
#  'Characterization of tanning behavior assessed via online survey: Attitudes, habits, and preventive measures with focus on sunscreen use.': ['characterization'],
#  'Eosinophil-cationic protein - a novel liquid prognostic biomarker in melanoma.': [],
#  'Larval Zebrafish Lateral Line as a Model for Acoustic Trauma.': ['larval zebrafish lateral line'],
#  'Noise-Induced Hypersensitization of the Acoustic Startle Response in Larval Zebrafish.': ['noise'],
#  'Brain Activation Patterns in Response to Conspecific and Heterospecific Social Acoustic Signals in Female Plainfin Midshipman Fish, Porichthys notatus.': ['brain activation patterns',
#   'female plainfin midshipman fish porichthys notatus'],
#  'Seasonal plasticity of auditory saccular sensitivity in "sneaker" type II male plainfin midshipman fish, Porichthys notatus.': ['seasonal plasticity'],
#  'Effect of nitric oxide and calpastatin on the inhibition of micro-calpain activity, autolysis and proteolysis of myofibrillar proteins.': ['effect'],
#  'Effect of nitric oxide on myofibrillar proteins and the susceptibility to calpain-1 proteolysis.': ['effect'],
#  'Metabolomics in the clinic: A review of the shared and unique features of untargeted metabolomics for clinical research and clinical testing.': [],
#  'Identification of S-nitrosylated proteins in postmortem pork muscle using modified biotin switch method coupled with isobaric tags.': ['identification'],
#  'Predicting aged pork quality using a portable Raman device.': [],
#  'Rapid Replacement of Acinetobacter baumannii Strains Accompanied by Changes in Lipooligosaccharide Loci and Resistance Gene Repertoire.': ['rapid replacement'],
#  'DNA assembly with error correction on a droplet digital microfluidics platform.': ['dna assembly'],
#  'Genomic Epidemiology of Global Carbapenemase-Producing Enterobacter spp., 2008-2014.': ['genomic epidemiology'],
#  'Synthesis and Preliminary Evaluation of 5-[18F]fluoroleucine.': ['synthesis'],
#  'Intraarterial Microdosing: A Novel Drug Development Approach, Proof-of-Concept PET Study in Rats.': ['intraarterial microdosing'],
#  'Discovery of Novel Conotoxin Candidates Using Machine Learning.': ['discovery'],
#  'Introgression of regulatory alleles and a missense coding mutation drive plumage pattern diversity in the rock pigeon.': ['introgression'],
#  'Synthesis of superabsorbent polymers based on chitosan derivative graft acrylic acid-co-acrylamide and its property testing.': ['synthesis'],
#  'Novel hyaluronic acid-modified temperature-sensitive nanoparticles for synergistic chemo-photothermal therapy.': ['novel hyaluronic acid modified temperature sensitive nanoparticles'],
#  'Shenfu Injection Attenuates Bile Duct Injury in Rats with Acute Obstructive Cholangitis.': [],
#  'The relative resistance of children to sepsis mortality: from pathways to drug candidates.': [],
#  'Relatively frequent switching of transcription start sites during cerebellar development.': ['relatively frequent switching'],
#  'Lipid phenotyping of lung epithelial lining fluid in healthy human volunteers.': ['lipid phenotyping'],
#  'Three Major Efforts to Phenotype Asthma: Severe Asthma Research Program, Asthma Disease Endotyping for Personalized Therapeutics, and Unbiased Biomarkers for the Prediction of Respiratory Disease Outcome.': ['three major efforts'],
#  'Results and Implications of Routine HIV Testing in the Inpatient Setting: A Descriptive Analysis.': ['results'],
#  'Identification of Organ-Enriched Protein Biomarkers of Acute Liver Injury by Targeted Quantitative Proteomics of Blood in Acetaminophen- and Carbon-Tetrachloride-Treated Mouse Models and Acetaminophen Overdose Patients.': [],
#  'Differentiating bipolar disorder from borderline personality disorder: Diagnostic accuracy of the difficulty in emotion regulation scale and personality inventory for DSM-5.': [],
#  'Phase 1b trial of nintedanib in combination with bevacizumab in patients with advanced solid tumors.': ['phase'],
#  'Comparative genome analysis provides novel insight into the interaction of Aquimarina sp. AD1, BL5 and AD10 with their macroalgal host.': [],
#  'In vitro accuracy and inter-observer reliability of CT angiography in detecting intracranial aneurysm enlargement.': [],
#  'Medical student wellbeing - a consensus statement from Australia and New Zealand.': ['medical student'],
#  'Neurophysiological, neuropsychological, and cognitive effects of 30 days of isolation.': ['neurophysiological neuropsychological and cognitive effects'],
#  "The genome of the giant Nomura's jellyfish sheds light on the early evolution of active predation.": [],
#  'Influences of Age, Sex, and Moderate Alcohol Drinking on the Intrinsic Functional Architecture of Adolescent Brains.': [],
#  'Transient CNS responses to repeated binge ethanol treatment.': [],
#  'Cabazitaxel overcomes cisplatin resistance in germ cell tumour cells.': ['cabazitaxel overcomes cisplatin resistance'],
#  'Concomitants of alcoholism: differential effects of thiamine deficiency, liver damage, and food deprivation on the rat brain in vivo.': ['concomitants'],
#  'Brain metabolite levels in recently sober individuals with alcohol use disorder: Relation to drinking variables and relapse.': [],
#  'Circuit-theory applications to connectivity science and conservation.': ['circuit theory applications'],
#  'Five fraction accelerated partial breast irradiation using noninvasive image-guided breast brachytherapy: Feasibility and acute toxicity.': [],
#  'A Systematic Review of the Risks and Benefits of Venous Thromboembolism Prophylaxis in Traumatic Brain Injury.': ['a systematic review'],
#  'Chronic Hypoxia Enhances beta-Oxidation-Dependent Electron Transport via Electron Transferring Flavoproteins.': [],
#  'Polarization of Human Macrophages by Interleukin-4 Does Not Require ATP-Citrate Lyase.': [],
#  'Strong and specific associations between cardiovascular risk factors and white matter micro- and macrostructure in healthy aging.': ['strong and specific associations'],
#  'TMEM126B deficiency reduces mitochondrial SDH oxidation by LPS, attenuating HIF-1alpha stabilization and IL-1beta expression.': [],
#  'Integrative omics analyses broaden treatment targets in human cancer.': [],
#  'Comprehensive Characterization of Cancer Driver Genes and Mutations.': ['comprehensive characterization'],
#  'Pathogenic Germline Variants in 10,389 Adult Cancers.': ['pathogenic germline variants'],
#  'Perspective on Oncogenic Processes at the End of the Beginning of Cancer Genomics.': [],
#  'Drosophila Histone Demethylase KDM5 Regulates Social Behavior through Immune Control and Gut Microbiota Maintenance.': [],
#  'Diverse tumour susceptibility in Collaborative Cross mice: identification of a new mouse model for human gastric tumourigenesis.': ['diverse tumour susceptibility'],
#  'No difference in 4-nitroquinoline induced tumorigenesis between germ-free and colonized mice.': ['no difference'],
#  'Exploiting regulatory heterogeneity to systematically identify enhancers with high accuracy.': [],
#  'A feasibility study of breast cancer genetic risk assessment in a federally qualified health center.': ['a feasibility study'],
#  'Descriptive characteristics of prostate cancer in patients with a history of primary male breast cancer - a SEER analysis.': ['descriptive characteristics'],
#  'Literature-based automated discovery of tumor suppressor p53 phosphorylation and inhibition by NEK2.': [],
#  'FARS2 deficiency; new cases, review of clinical, biochemical, and molecular spectra, and variants interpretation based on structural, functional, and evolutionary significance.': ['fars2 deficiency'],
#  'A high-throughput protocol for isolating cell-free circulating tumor DNA from peripheral blood.': ['a high throughput protocol'],
#  'Dietary Nutrients Involved in One-Carbon Metabolism and Colonic Mucosa-Associated Gut Microbiome in Individuals with an Endoscopically Normal Colon.': ['dietary nutrients'],
#  'Transdermal lidocaine as treatment for chronic subjective tinnitus: A pilot study.': ['transdermal lidocaine',
#   'a pilot study'],
#  'Consensus guidelines for the use of ultrasound for diving research.': ['consensus guidelines'],
#  'Variation of bone acquisition during growth hormone treatment in children can be explained by proteomic biomarkers, bone formation markers, body composition and nutritional factors.': [],
#  '[Application of DNA metabarcoding in species identification of Chinese herbal medicines].': ['application'],
#  'Comprehensive benchmarking and ensemble approaches for metagenomic classifiers.': ['comprehensive benchmarking and ensemble approaches'],
#  'The development of large-scale de-identified biomedical databases in the age of genomics-principles and challenges.': [],
#  'The role of alternative Polyadenylation in regulation of rhythmic gene expression.': ['the role'],
#  'Gene expression profiles at different stages for formation of pearl sac and pearl in the pearl oyster Pinctada fucata.': [],
#  'Limits of long-term selection against Neandertal introgression.': ['limits'],
#  '"A Gay Man and a Doctor are Just like, a Recipe for Destruction": How Racism and Homonegativity in Healthcare Settings Influence PrEP Uptake Among Young Black MSM.': [],
#  'Lessons from Outside and Within: Exploring Advancements in Methodology for Naturopathic Medicine Clinical Research.': ['lessons'],
#  'Consultations with Naturopaths and Western Herbalists: Prevalence of Use and Characteristics of Users in Australia.': ['consultations'],
#  'The Bioavailability of Various Oral Forms of Folate Supplementation in Healthy Populations and Animal Models: A Systematic Review.': ['the bioavailability'],
#  'Associations Between Cancer Screening Behavior and Complementary Medicine Use: Results of a National Cross-Sectional Survey of 9151 Australian Women.': [],
#  "Investigation into complementary and integrative medicine practitioners' clinical experience of intestinal permeability: A cross-sectional survey.": [],
#  'How should we treat uncomplicated subacute type B aortic dissection in octogenarians?': [],
#  'Benefits of Outdoor Sports for Society. A Systematic Literature Review and Reflections on Evidence.': [],
#  'Antimicrobial susceptibility patterns of blood culture isolates from foals in Switzerland.': [],
#  'The role of genetics and genomics in clinical psychiatry.': ['the role'],
#  'A Fosmid Pool-Based Next Generation Sequencing Approach to Haplotype-Resolve Whole Genomes.': [],
#  '[Beyond actinic keratoses: Field cancerization of the skin].': [],
#  'Cardiac R2* values are independent of the image analysis approach employed.': [],
#  'A mutation in TGFB3 associated with a syndrome of low muscle mass, growth retardation, distal arthrogryposis and clinical features overlapping with Marfan and Loeys-Dietz syndrome.': ['a mutation'],
#  'A High-Quality De novo Genome Assembly from a Single Mosquito Using PacBio Sequencing.': ['a high quality de novo genome assembly'],
#  'Studies of the chloride transport in the gastric mucosa of the frog.': ['studies'],
#  'Water flow through frog gastric mucosa.': [],
#  'Survival benefit of first-generation epidermal growth factor receptor-tyrosine kinase inhibitors in female with advanced lung cancer.': ['survival benefit'],
#  'Raising awareness, screening and prevention of chronic kidney disease: It takes more than a village.': [],
#  'JBrowse: a dynamic web platform for genome visualization and analysis.': [],
#  'Non-invasive imaging techniques for the differentiation of acute and chronic thrombosis.': ['non invasive imaging techniques'],
#  'Targeting Mechanosensitive Transcription Factors in Atherosclerosis.': [],
#  'Endothelin-1 increases CHSY-1 expression in aortic endothelial cells via transactivation of transforming growth factor beta type I receptor induced by type B receptor endothelin-1.': [],
#  'In vivo quantification of mechanical properties of caudal fins in adult zebrafish.': [],
#  'Influenece of the CPRmeter on angular position of elbows and generated forces during cardiopulmonary resuscitation.': ['influenece'],
#  'Dynamics of actinotrichia regeneration in the adult zebrafish fin.': ['dynamics'],
#  'Increased CD4(+) T cell lineage commitment determined by CpG methylation correlates with better prognosis in urinary bladder cancer patients.': [],
#  'Running with injury: A study of UK novice and recreational runners and factors associated with running related injury.': [],
#  'Optimal-Transport Analysis of Single-Cell Gene Expression Identifies Developmental Trajectories in Reprogramming.': [],
#  'Hypofractionated versus standard radiation therapy in combination with temozolomide for glioblastoma in the elderly: a meta-analysis.': [],
#  'Long-term anatomic and functional results of laparoscopic sacrocolpopexy: a prospective study.': [],
#  'Characterizing the Major Structural Variant Alleles of the Human Genome.': [],
#  'Establishing Cerebral Organoids as Models of Human-Specific Brain Evolution.': [],
#  'The role of the operating department practitioner on board Role 2 Afloat.': ['the role'],
#  'A systematic review of 3251 emergency department thoracotomies: is it time for a national database?': [],
#  'Integrating Family Planning and HIV Services at the Community Level: Formative Assessment with Village Health Teams in Uganda.': [],
#  'Development and validation of a noncompetitive electrochemiluminescence-based immunoassay (ECLIA) for specific determination of insulin lispro (Humalog(R)) in human serum to support pharmacokinetic assessments.': [],
#  'The Evolution of Oncology Companion Diagnostics from Signal Transduction to Immuno-Oncology.': ['the evolution'],
#  'DNA Commission of the International Society for Forensic Genetics: Recommendations on the validation of software programs performing biostatistical calculations for forensic genetics applications.': ['dna commission'],
#  'Clonal Deletion of Tumor-Specific T Cells by Interferon-gamma Confers Therapeutic Resistance to Combination Immune Checkpoint Blockade.': ['clonal deletion'],
#  'Comparison between broadband and monochromatic photopic negative response in full-field electroretinogram in controls and subjects with primary open-angle glaucoma.': ['comparison'],
#  'Exonuclease Domain-Containing 1 Enhances MIWI2 piRNA Biogenesis via Its Interaction with TDRD12.': [],
#  'Randomized controlled multicentre study comparing short dental implants (6 mm) versus longer dental implants (11-15 mm) in combination with sinus floor elevation procedures: 5-Year data.': ['randomized controlled multicentre study',
#   'dental implants',
#   '5-year data'],
#  'Number of implants placed for complete-arch fixed prostheses: A systematic review and meta-analysis.': ['number'],
#  'An integrative study on biologically recovered polyhydroxyalkanoates (PHAs) and simultaneous assessment of gut microbiome in yellow mealworm.': ['an integrative study'],
#  'Perspectives on Genetic Testing and Return of Results from the First Cohort of Presymptomatically Tested Individuals At Risk of Huntington Disease.': ['perspectives'],
#  'Enhancing Autonomy in Biobank Decisions: Too Much of a Good Thing?': [],
#  'The Therapeutic "Mis"conception: An Examination of its Normative Assumptions and a Call for its Revision.': ['the therapeutic mis"conception an examination'],
#  'Helium CT: Monte Carlo simulation results for an ideal source and detector with comparison to proton CT.': [],
#  'Validation of the radiobiology toolkit TOPAS-nBio in simple DNA geometries.': [],
#  'MEG Assessment of Expressive Language in Children Evaluated for Epilepsy Surgery.': [],
#  'Incarcerating Pregnant and Parenting Women, the New Witch Hunt: A Policy Analysis.': [],
#  'Drug consumption rooms in Catalonia: A comprehensive evaluation of social, health and harm reduction benefits.': [],
#  'Multiancestry Genome-Wide Association Study of Lipid Levels Incorporating Gene-Alcohol Interactions.': ['multiancestry genome wide association study'],
#  'Cosmetic benefit of a biomimetic lamellar cream formulation on barrier function or the appearance of fine lines and wrinkles in randomized proof-of-concept clinical studies.': ['cosmetic benefit'],
#  'Breastfeeding prevalence among six-week-old infants at University Hospital of the West Indies.': [],
#  'The value of maintaining normokalaemia and enabling RAASi therapy in chronic kidney disease.': ['the value'],
#  'Cohort versus patient level simulation for the economic evaluation of single versus combination immuno-oncology therapies in metastatic melanoma.': ['cohort'],
#  'Serum potassium and clinical outcomes in heart failure patients: results of risk calculations in 21 334 patients in the UK.': [],
#  'Cost-effectiveness of fluocinolone acetonide implant (ILUVIEN(R)) in UK patients with chronic diabetic macular oedema considered insufficiently responsive to available therapies.': ['cost effectiveness',
#   'iluvien(r'],
#  'Characterizing genetic variants for clinical action.': [],
#  'Studies on coccidioides immitis. II. Physiological studies on in vitro spherulation.': [],
#  'Studies on Coccidioides immitis. I. A simple medium for in vitro spherulation.': [],
#  'In vitro conversion of Histoplasma capsulatum.': [],
#  'Disease Progression After Lateral and Medial Unicondylar Knee Arthroplasty.': ['disease progression'],
#  'Impact of insurance type on eligibility for advanced heart failure therapies and survival.': ['impact'],
#  'Medical Child Abuse: An Unusual "Source" of Vaginal Bleeding.': [],
#  'Quantitative Early Auxin Root Proteomics Identifies GAUT10, a Galacturonosyltransferase, as a Novel Regulator of Root Meristem Maintenance.': ['a galacturonosyltransferase'],
#  'Spatial and temporal studies of metabolic activity: contrasting biochemical kinetics in tissues and pathways during fasted and fed states.': ['spatial and temporal studies'],
#  'Transcranial optical imaging reveals a pathway for optimizing the delivery of immunotherapeutics to the brain.': [],
#  'Recurrent Noncoding Mutations in Skin Cancers: UV Damage Susceptibility or Repair Inhibition as Primary Driver?': [],
#  'Cholesterol increases protein levels of the E3 ligase MARCH6 and thereby stimulates protein degradation.': [],
#  'Murine Models of Intraperitoneal Perfusion for Disseminated Colorectal Cancer.': ['murine models'],
#  'Hypoxia Promotes Immune Evasion by Triggering beta-Glucan Masking on the Candida albicans Cell Surface via Mitochondrial and cAMP-Protein Kinase A Signaling.': [],
#  'SMN deficiency in severe models of spinal muscular atrophy causes widespread intron retention and DNA damage.': [],
#  'Rescue of gene-expression changes in an induced mouse model of spinal muscular atrophy by an antisense oligonucleotide that promotes inclusion of SMN2 exon 7.': [],
#  'Testing the effects of four urbanization filters on forest plant taxonomic, functional, and phylogenetic diversity.': [],
#  'Novel phenotype-disease matching tool for rare genetic diseases.': ['novel phenotype disease'],
#  'The Roles of Compensatory Evolution and Constraint in Aminoacyl tRNA Synthetase Evolution.': ['the roles'],
#  'Increased frequency of de novo copy number variants in congenital heart disease by integrative analysis of single nucleotide polymorphism array and exome sequence data.': ['increased frequency'],
#  'Analysis of chromosomal structural variation in patients with congenital left-sided cardiac lesions.': ['analysis'],
#  'The use of alteration analysis in supercritical fluid chromatography to monitor changes in a series of chromatograms.': ['the use'],
#  'Spinal Intradural Escherichia coli Abscess Masquerading as a Neoplasm in a Pediatric Patient with History of Neonatal E. coli Meningitis: A Case Report and Literature Review.': ['meningitis'],
#  'Acquired, Comitant, Non-Accommodative Esotropia (ANAET): Evaluation, Treatment, and Prognosis.': [],
#  'Scaffold proteins LACK and TRACK as potential drug targets in kinetoplastid parasites: Development of inhibitors.': [],
#  'DAtA: database of Arabidopsis thaliana annotation.': ['data database'],
#  'Genome-wide mapping with biallelic markers in Arabidopsis thaliana.': ['genome wide mapping'],
#  'Randomised placebo-controlled trial of combination ACE inhibitor and beta-blocker therapy to prevent cardiomyopathy in children with Duchenne muscular dystrophy? (DMD Heart Protection Study): a protocol study.': ['randomised placebo controlled trial'],
#  'Target (MexB)- and Efflux-Based Mechanisms Decreasing the Effectiveness of the Efflux Pump Inhibitor D13-9001 in Pseudomonas aeruginosa PAO1: Uncovering a New Role for MexMN-OprM in Efflux of beta-Lactams and a Novel Regulatory Circuit (MmnRS) Controlling MexMN Expression.': ['target'],
#  'Charcot Marie Tooth disease type 2S with late onset diaphragmatic weakness: An atypical case.': [],
#  'Negative relationships between species richness and temporal variability are common but weak in natural systems.': [],
#  'Chronic pain has a strong impact on quality of life in facioscapulohumeral muscular dystrophy.': [],
#  'Accumulation of autophagosomes confers cytotoxicity.': [],
#  'Prevalence and impact of obesity in people with haemophilia: Review of literature and expert discussion around implementing weight management guidelines.': ['prevalence'],
#  'Dynamics of an experimental microbial invasion.': ['dynamics'],
#  'Fluorescence in situ hybridization and optical mapping to correct scaffold arrangement in the tomato genome.': ['fluorescence'],
#  "Blood-Derived DNA Methylation Signatures of Crohn's Disease and Severity of Intestinal Inflammation.": [],
#  'Restoration of pyrethroid susceptibility in a highly resistant Aedes aegypti population.': [],
#  "A double-blind placebo-controlled cross-over clinical trial of DONepezil In Posterior cortical atrophy due to underlying Alzheimer's Disease: DONIPAD study.": [],
#  'Antibodies to Peptides in Semiconserved Domains of RIFINs and STEVORs Correlate with Malaria Exposure.': [],
#  'Barriers and enablers to implementing a virtual tertiary-regional Telemedicine Rounding and Consultation (TRAC) model of inpatient pediatric care using the Theoretical Domains Framework (TDF) approach: a study protocol.': [],
#  "Exploring residents' interest and career aspirations in global surgery.": [],
#  'Perioperative self-reflection among surgical residents.': ['perioperative self reflection'],
#  'Do female surgeons learn or teach differently?': [],
#  'A taxonomy of perioperative surgical learning: Trending resident skill acquisition.': ['a taxonomy'],
#  'Effects of vertebroplasty on endplate subsidence in elderly female spines.': ['effects'],
#  'Optimized GC-MS metabolomics for the analysis of kidney tissue metabolites.': ['optimized gc ms metabolomics'],
#  'Limited genetic variability of Cytauxzoon felis apical membrane antigen-1 (ama1) from domestic cats and bobcats.': ['limited genetic variability'],
#  "Prospective study of the sensitivity of the Wood's lamp for common eye abnormalities.": ['prospective study'],
#  'Prevalence and correlates of psychological distress among 13-14 year old adolescent girls in North Karnataka, South India: a cross-sectional study.': ['prevalence'],
#  'Serum levels of insulin-like growth factor-1 and brain-derived neurotrophic factor as potential recovery biomarkers in stroke.': [],
#  'Gemcitabine Induces Microvesicle Particle Release in a Platelet-Activating Factor-Receptor-Dependent Manner via Modulation of the MAPK Pathway in Pancreatic Cancer Cells.': [],
#  'Associations of Mitochondrial and Nuclear Mitochondrial Variants and Genes with Seven Metabolic Traits.': ['associations'],
#  'HLA-DQA1 & DQB1 variants associated with hepatitis B virus-related chronic hepatitis, cirrhosis & hepatocellular carcinoma.': ['hla dqa1 dqb1 variants'],
#  'Intraosseous lipoma of the maxillary tuberosity: A rare entity with diagnostic challenge.': ['intraosseous lipoma'],
#  'Efficacy of topically administered fluralaner or imidacloprid/moxidectin on dogs with generalised demodicosis.': ['efficacy'],
#  'Good Cell Culture Practice for stem cells and stem-cell-derived models.': [],
#  'Multidrug resistant Mannheimia haemolytica isolated from high-risk beef stocker cattle after antimicrobial metaphylaxis and treatment for bovine respiratory disease.': [],
#  'Construction and evaluation of type III secretion system mutants of the catfish pathogen Edwardsiella piscicida.': ['construction'],
#  'Covalent Structure and Bioactivity of the Type AII Lantibiotic Salivaricin A2.': ['covalent structure'],
#  'Synonymous mutation in TP53 results in a cryptic splice site affecting its DNA-binding site in an adolescent with two primary sarcomas.': [],
#  'Allele-Specific Methylation of SPDEF: A Novel Moderator of Psychosocial Stress and Substance Abuse.': [],
#  'Transcriptome sequencing in pediatric acute lymphoblastic leukemia identifies fusion genes associated with distinct DNA methylation profiles.': ['transcriptome sequencing'],
#  'Ramucirumab and Paclitaxel Administered Every 2 Weeks (mRAINBOW Regimen) in Advanced Gastroesophageal Adenocarcinoma.': [],
#  'Current synthetic pharmacotherapy for treatment-resistant colorectal cancer: when urgent action is required.': ['current synthetic pharmacotherapy'],
#  'Sexual Assault Examination of the Unconscious Patient: A Legal, Ethical and Professional Grey-area for the Forensic Physician.': [],
#  'Parent and Provider Experience and Shared Understanding After a Family-Centered Nighttime Communication Intervention.': ['parent and provider experience'],
#  'A Platform for Generation of Chamber-Specific Cardiac Tissues and Disease Modeling.': ['a platform'],
#  'The ENTPD1 promoter polymorphism -860 A > G (rs3814159) is associated with increased gene transcription, protein expression, CD39/NTPDase1 enzymatic activity, and thromboembolism risk.': ['the entpd1 promoter polymorphism'],
#  'The impact of the UGT1A1*60 allele on bilirubin serum concentrations.': ['the impact'],
#  'Genome-wide survey in African Americans demonstrates potential epistasis of fitness in the human genome.': [],
#  'Gene expression analyses of mouse aortic endothelium in response to atherogenic stimuli.': ['gene expression analyses'],
#  'Mechanisms of silver nanoparticles-induced cytotoxicity and apoptosis in rat tracheal epithelial cells.': [],
#  'Investigating the impact of tumour motion on TomoTherapy stereotactic ablative body radiotherapy (SABR) deliveries on 3-dimensional and 4-dimensional computed tomography.': [],
#  'Hepatoprotective effect of alpha-mangostin against lipopolysaccharide/d-galactosamine-induced acute liver failure in mice.': [],
#  'Protective Effects of Sesquiterpenoids from the Root of Panax ginseng on Fulminant Liver Injury Induced by Lipopolysaccharide/d-Galactosamine.': ['protective effects'],
#  'Mouse Idh3a mutations cause retinal degeneration and reduced mitochondrial function.': [],
#  'Patient, Caregiver, and Taxpayer Knowledge of Palliative Care and Views on a Model of Community-Based Palliative Care.': ['patient caregiver'],
#  'The goya mouse mutant reveals distinct newly identified roles for MAP3K1 in the development and survival of cochlear sensory hair cells.': [],
#  'Clustering analysis of proteins from microbial genomes at multiple levels of resolution.': [],
#  'Update on Genomic Databases and Resources at the National Center for Biotechnology Information.': [],
#  'Carbon dots stabilized silver-lipid nano hybrids for sensitive label free DNA detection.': [],
#  'Array atomic force microscopy for real-time multiparametric analysis.': ['array atomic force microscopy'],
#  'Water-soluble MoS2 quantum dots as effective fluorescence probe for the determination of bilirubin in human fluids.': ['water soluble mos2 quantum dots'],
#  'Inhibition of monocyte-like cell extravasation protects from neurodegeneration in DBA/2J glaucoma.': ['inhibition'],
#  'Light-absorbing impurities in snow of the Indian Western Himalayas: impact on snow albedo, radiative forcing, and enhanced melting.': ['light absorbing impurities'],
#  'Decisional Balance and Contemplation Ladder to Support Interventions for HIV Pre-Exposure Prophylaxis Uptake and Persistence.': [],
#  'Methods for high-dimensional analysis of cells dissociated from cryopreserved synovial tissue': ['methods'],
#  'Early Epstein-Barr Virus Genomic Diversity and Convergence toward the B95.8 Genome in Primary Infection.': ['early epstein barr virus genomic diversity'],
#  'Acquiring nutrients from tree leaves: effects of leaf maturity and development type on a generalist caterpillar.': [],
#  'Evolvix BEST Names for semantic reproducibility across code2brain interfaces.': ['evolvix best names'],
#  'Mimicking biological membranes with programmable glycan ligands self-assembled from amphiphilic Janus glycodendrimers.': [],
#  'Rich and cold: diversity, distribution and drivers of fungal communities in patterned-ground ecosystems of the North American Arctic.': ['rich and cold diversity distribution'],
#  'Regulated aggregative multicellularity in a close unicellular relative of metazoa.': ['regulated aggregative multicellularity'],
#  'The Embase UK filter: validation of a geographic search filter to retrieve research about the UK from OVID Embase.': ['the embase'],
#  'The effect of linguistic background on rapid number naming: implications for native versus non-native English speakers on sideline-focused concussion assessments.': ['the effect'],
#  'Gender- and region-specific changes in estrogen signaling in aging rat brain mitochondria.': ['gender- and region specific changes'],
#  'Recombinant Listeria promotes tumor rejection by CD8(+) T cell-dependent remodeling of the tumor microenvironment.': [],
#  'Frequency and predictors of health services use by Native Hawaiians and Pacific Islanders: evidence from the U.S. National Health Interview Survey.': [],
#  'Genome sequencing identifies multiple deleterious variants in autism patients with more severe phenotypes.': [],
#  'Whole genome pyrosequencing of rare hepatitis C virus genotypes enhances subtype classification and identification of naturally occurring drug resistance variants.': [],
#  'Thyroid and reproductive hormones in relation to pesticide use in an agricultural population in Southern Brazil.': ['thyroid'],
#  'Characterisation and anti-biofilm activity of glycerol monolaurate nanocapsules against Pseudomonas aeruginosa.': ['characterisation'],
#  'Cortical and spinal excitability changes after repetitive transcranial magnetic stimulation combined to physiotherapy in stroke spastic patients.': ['cortical and spinal excitability changes'],
#  'DLL4 and Jagged1 are angiogenic targets of orphan nuclear receptor TR3/Nur77.': [],
#  'Identifying Selection Signatures for Backfat Thickness in Yorkshire Pigs Highlights New Regions Affecting Fat Metabolism.': [],
#  'Elevated Circulating CD4(+)CD25(-)Foxp3(+) Regulatory T Cells in Patients with Nonsmall Cell Lung Cancer.': ['elevated circulating cd4(+)cd25(-)foxp3(+ regulatory t cells'],
#  'Changes in Nanoscale Chain Assembly in Sweet Potato Starch Lamellae by Downregulation of Biosynthesis Enzymes.': ['changes'],
#  'Structure of the germline genome of Tetrahymena thermophila and relationship to the massively rearranged somatic genome.': ['structure'],
#  'Diet during Pregnancy and Infancy and the Infant Intestinal Microbiome.': ['diet'],
#  'An Analysis of the Epidemic of Klebsiella pneumoniae Carbapenemase-Producing K. pneumoniae: Convergence of Two Evolutionary Mechanisms Creates the "Perfect Storm".': [],
#  'Community characteristics of the gut microbiomes of competitive cyclists.': ['community characteristics'],
#  'Frankenstein or a Submarine Alkaline Vent: Who is Responsible for Abiogenesis?: Part 2: As life is now, so it must have been in the beginning.': ['frankenstein'],
#  'Frankenstein or a Submarine Alkaline Vent: Who Is Responsible for Abiogenesis?: Part 1: What is life-that it might create itself?': ['frankenstein'],
#  'Honey bee neurogenomic responses to affiliative and agonistic social interactions.': [],
#  'Cross-species systems analysis of evolutionary toolkits of neurogenomic response to social challenge.': ['cross species systems analysis'],
#  'Neuromolecular responses to social challenge: common mechanisms across mouse, stickleback fish, and honey bee.': ['neuromolecular responses'],
#  'A distant downstream enhancer directs essential expression of Tbx18 in urogenital tissues.': [],
#  'Deep vertebrate roots for mammalian zinc finger transcription factor subfamilies.': ['deep vertebrate roots'],
#  'Contemporary (2009-2014) clinical outcomes after femoropopliteal bypass surgery for chronic limb threatening ischemia are inferior to those reported in the UK Bypass versus Angioplasty for Severe Ischaemia of the Leg (BASIL) trial (1999-2004).': [],
#  'Survival prediction in patients with chronic limb-threatening ischemia who undergo infrainguinal revascularization.': ['survival prediction'],
#  'Publication of UK NICE Clinical Guidelines 168 has not significantly changed the management of leg ulcers in primary care: An analysis of The Health Improvement Network database.': [],
#  'Obesity and lower limb venous disease - The epidemic of phlebesity.': ['obesity'],
#  'The impact of 2013 UK NICE guidelines on the management of varicose veins at the Heart of England NHS Foundation Trust, Birmingham, UK.': ['birmingham'],
#  'A review of randomised controlled trials comparing ultrasound-guided foam sclerotherapy with endothermal ablation for the treatment of great saphenous varicose veins.': ['a review'],
#  'Vertical flow constructed wetlands for decentralized wastewater treatment in Jordan: Optimization of total nitrogen removal.': [],
#  'The Scalability of Wet Ball Milling for The Production of Nanosuspensions.': ['the scalability'],
#  'Modelling seasonal dynamics, population stability, and pest control in Aedes japonicus japonicus (Diptera: Culicidae).': [],
#  'smartPearls((R)) for dermal bioavailability enhancement - Long-term stabilization of suspensions by viscoelasticity.': [],
#  'Effects of a long-term home-based exercise training programme using minimal equipment vs. usual care in COPD patients: a study protocol for two multicentre randomised controlled trials (HOMEX-1 and HOMEX-2 trials).': ['effects'],
#  'Long-term effects of the fungicide pyrimethanil on aquatic primary producers in macrophyte-dominated outdoor mesocosms in two European ecoregions.': [],
#  'Particulate matter emissions of four types of one cigarette brand with and without additives: a laser spectrometric particulate matter analysis of secondhand smoke.': ['particulate matter emissions'],
#  'Patient care and paternalism: dilemmas of family practice.': ['patient care'],
#  'Standardized residency training in China: the new internal medicine curriculum.': ['standardized residency training'],
#  'A Randomized Controlled Trial using iTClamp, Direct Pressure, and Balloon Catheter Tamponade to Control Neck Hemorrhage in a Perfused Human Cadaver Model.': [],
#  'Eco-friendly synthesized spherical ZnO materials: Effect of the core-shell to solid morphology transition on antimicrobial activity.': ['eco friendly synthesized spherical zno materials effect'],
#  'SERIAL transmit - parallel receive (STxPRx) MR imaging produces acceptable proton image uniformity without compromising field of view or SAR guidelines for human neuroimaging at 9.4 Tesla.': [],
#  'Feasibility of 39-potassium MR imaging of a human brain at 9.4 Tesla.': ['feasibility'],
#  'Decreased serum TRAIL is associated with increased mortality in smokers with comorbid emphysema and coronary artery disease.': [],
#  'Computational modelling of internally cooled wet (ICW) electrodes for radiofrequency ablation: impact of rehydration, thermal convection and electrical conductivity.': ['computational modelling'],
#  "Beyond aphasia: Altered EEG connectivity in Broca's patients during working memory task.": [],
#  'Corticospinal and transcallosal modulation of unilateral and bilateral contractions of lower limbs.': ['corticospinal and transcallosal modulation'],
#  'Interventions to improve vaccine acceptance among rheumatoid arthritis patients: a systematic review.': ['interventions'],
#  'Spore Germination Requires Ferrichrome Biosynthesis and the Siderophore Transporter Str1 in Schizosaccharomyces pombe.': [],
#  'Loss of hepatic DEPTOR alters the metabolic transition to fasting.': [],
#  'Heme Assimilation in Schizosaccharomyces pombe Requires Cell-surface-anchored Protein Shu1 and Vacuolar Transporter Abc3.': [],
#  'Loss of UCP2 impairs cold-induced non-shivering thermogenesis by promoting a shift toward glucose utilization in brown adipose tissue.': [],
#  '[Relationship of distribution frequency of HLA antigen/antibody and PIRCHE score with DSA production and AMR occurrence].': ['relationship'],
#  'Personalized oncogenomic analysis of metastatic adenoid cystic carcinoma: using whole-genome sequencing to inform clinical decision-making.': ['personalized oncogenomic analysis'],
#  'Application of genomics to identify therapeutic targets in recurrent pediatric papillary thyroid carcinoma.': [],
#  'The epidemiology of HIV and other sexually transmitted infections in African, Caribbean and Black men in Toronto, Canada.': ['the epidemiology'],
#  'Integrated epigenomic profiling reveals endogenous retrovirus reactivation in renal cell carcinoma.': [],
#  'Spatio-temporal spillover risk of yellow fever in Brazil.': [],
#  'Stable isotope labeling methods for DNA.': ['stable isotope labeling methods'],
#  'Protein Synthesis in Coupled and Uncoupled Cell-Free Prokaryotic Gene Expression Systems.': ['protein synthesis'],
#  'TLR4, TRIF, and MyD88 are essential for myelopoiesis and CD11c(+) adipose tissue macrophage production in obese mice.': [],
#  'A study of pedestrian compliance with traffic signals for exclusive and concurrent phasing.': ['a study'],
#  'Polymorphism discovery in high-throughput resequenced microarray-enriched human genomic loci.': ['polymorphism discovery'],
#  'Establishment of a rapid and footprint-free protocol for differentiation of human embryonic stem cells into pancreatic endocrine cells with synthetic mRNAs encoding transcription factors.': ['establishment'],
#  'Artificial neural network models for prediction of daily fine particulate matter concentrations in Algiers.': ['artificial neural network models'],
#  'Forecasting PM10 in Algiers: efficacy of multilayer perceptron networks.': [],
#  'A Common Type 2 Diabetes Risk Variant Potentiates Activity of an Evolutionarily Conserved Islet Stretch Enhancer and Increases C2CD4A and C2CD4B Expression.': [],
#  'Everolimus rescues multiple cellular defects in laminopathy-patient fibroblasts.': [],
#  'Patient organ doses from megavoltage computed tomography delivery with a helical tomotherapy unit using a general treatment planning system.': [],
#  'Focal traumatic brain injury induces neuroplastic molecular responses in lumbar spinal cord.': [],
#  'Lateral thoracoaxillar dermal-fat flap for breast conserving surgery: the changes of the indication and long-term results.': ['lateral thoracoaxillar dermal fat flap',
#   'long term results'],
#  'On the feasibility of transperineal 3D ultrasound image guidance for robotic radical prostatectomy.': [],
#  'Dominance of international high-risk clones in carbapenemase-producing Pseudomonas aeruginosa: Multicentric molecular epidemiology report from India.': ['dominance'],
#  'Microenvironment-Mediated Mechanisms of Resistance to HER2 Inhibitors Differ between HER2+ Breast Cancer Subtypes.': [],
#  'The Library of Integrated Network-Based Cellular Signatures NIH Program: System-Level Cataloging of Human Cells Response to Perturbations.': ['the library'],
#  'Early Experience with Laparoscopic Frey Procedure for Chronic Pancreatitis: a Case Series and Review of Literature.': ['early experience'],
#  'Investigation of Optimal Afferent Feedback Modality for Inducing Neural Plasticity with A Self-Paced Brain-Computer Interface.': ['investigation'],
#  'Pathophysiological central nervous system changes in a porcine model of acetaminophen-induced acute liver failure.': [],
#  'Early weaning completely eliminates porcine cytomegalovirus from a newly established pig donor facility for xenotransplantation.': ['early weaning completely eliminates'],
#  'Porcine endogenous retroviruses: Quantification of the copy number in cell lines, pig breeds, and organs.': ['porcine endogenous retroviruses quantification'],
#  'The normal trachea is cleaned by MUC5B mucin bundles from the submucosal glands coated with the MUC5AC mucin.': [],
#  'Unusual retinopathy in a child with severe combined immune deficiency.': ['unusual retinopathy'],
#  'The Munich MIDY Pig Biobank - A unique resource for studying organ crosstalk in diabetes.': [],
#  'The dNTP triphosphohydrolase activity of SAMHD1 persists during S-phase when the enzyme is phosphorylated at T592.': ['the dntp triphosphohydrolase activity'],
#  'Cryo-EM structure of Mcm2-7 double hexamer on DNA suggests a lagging-strand DNA extrusion model.': ['cryo'],
#  'Structural and mechanistic insights into Mcm2-7 double-hexamer assembly and function.': ['structural and mechanistic insights'],
#  'Development of antibodies to and PCR detection of Ehrlichia spp. in dogs following natural tick exposure.': ['development'],
#  'Domain within the helicase subunit Mcm4 integrates multiple kinase signals to control DNA replication initiation and fork progression.': [],
#  'A cluster randomised controlled trial of an intervention to increase the implementation of school physical activity policies and guidelines: study protocol for the physically active children in education (PACE) study.': [],
#  'Agreement between telehealth and face-to-face assessment of intellectual ability in children with specific learning disorder.': ['agreement'],
#  'Typology of new psychoactive substance use among the general Australian population.': ['typology'],
#  'Implant Survival and Patient-Reported Outcomes After Total Hip Arthroplasty in Young Patients.': [],
#  'Dietary intake of energy-dense, nutrient-poor and nutrient-dense food sources in children with cystic fibrosis.': ['dietary intake'],
#  'Health-related quality of life burden in severe asthma.': ['health related quality'],
#  'Multidimensional assessment of severe asthma: A systematic review and meta-analysis.': [],
#  'Genomic profiling in advanced stage non-small-cell lung cancer patients with platinum-based chemotherapy identifies germline variants with prognostic value in SMYD2.': [],
#  'Multitrait genome association analysis identifies new susceptibility genes for human anthropometric variation in the GCAT cohort.': [],
#  'Large-scale screening of circulating microRNAs in individuals with HIV-1 mono-infections reveals specific liver damage signatures.': [],
#  'GCAT|Genomes for life: a prospective cohort study of the genomes of Catalonia.': ['gcat|genomes',
#   'a prospective cohort study'],
#  'Gene expression changes in blood RNA after swimming in a chlorinated pool.': ['gene expression changes'],
#  'T cells in IgA nephropathy: role in pathogenesis, clinical significance and potential therapeutic target.': ['t cells',
#   'nephropathy role'],
#  'The integration of inflammaging in age-related diseases.': ['the integration'],
#  'Naturally occurring xanthone and benzophenone derivatives exert significant anti-proliferative and proapoptotic effects in vitro on synovial fibroblasts and macrophages from rheumatoid arthritis patients.': [],
#  'Heterogeneity of the cytokinome in undifferentiated arthritis progressing to rheumatoid arthritis and its change in the course of therapy. Move toward personalized medicine.': ['heterogeneity'],
#  'Influence of oxygen concentration on T cell proliferation and susceptibility to apoptosis in healthy men and women.': ['influence'],
#  'Inhibitory Effects of Danshen components on CYP2C8 and CYP2J2.': ['inhibitory effects'],
#  '[Screen astragalosides from Huangqi injections by LC-TOF-MS-based mass defect filtering approach].': ['screen astragalosides'],
#  'Clinical tolerability and pharmacokinetics of Erigerontis hydroxybenzene injection: results of a randomized phase I study in healthy Chinese volunteers.': ['clinical tolerability'],
#  'In silico target fishing for the potential bioactive components contained in Huanglian Jiedu Tang (HLJDD) and elucidating molecular mechanisms for the treatment of sepsis.': [],
#  'No Effect of Polystyrene Microplastics on Foraging Activity and Survival in a Post-larvae Coral-Reef Fish, Acanthurus triostegus.': ['no effect'],
#  'Evaluation of microplastic ingestion by tropical fish from Moorea Island, French Polynesia.': ['evaluation'],
#  'Tooth movement rate and anchorage lost during canine retraction: A maxillary and mandibular comparison.': [],
#  'Nox4 genetic inhibition in experimental hypertension and metabolic syndrome.': ['nox4 genetic inhibition'],
#  'Fibulocalcaneal Impingement in a Growing Child With Otherwise Asymptomatic Talocalcaneal Coalition.': ['fibulocalcaneal impingement'],
#  'A Wars2 Mutant Mouse Model Displays OXPHOS Deficiencies and Activation of Tissue-Specific Stress Response Pathways.': [],
#  'A mouse model for inherited renal fibrosis associated with endoplasmic reticulum stress.': ['a mouse model'],
#  'The Relationship Between Tobacco Smoke Exposure and Airflow Obstruction in US Children: Analysis of the National Health and Nutrition Examination Survey (2007-2012).': [],
#  'Trunk peak torque, muscle activation pattern and sudden loading compensation in adolescent athletes with back pain.': ['trunk peak torque muscle activation pattern'],
#  'Effectiveness of an interactive telerehabilitation system with home-based exercise training in patients after total hip or knee replacement: study protocol for a multicenter, superiority, no-blinded randomized controlled trial.': ['effectiveness',
#   'no blinded randomized controlled trial'],
#  'Fishing for leadership: The role diversification plays in facilitating change agents.': [],
#  'High Plasma sRAGE (Soluble Receptor for Advanced Glycation End Products) Is Associated With Slower Carotid Intima-Media Thickness Progression and Lower Risk for First-Time Coronary Events and Mortality.': [],
#  'Prevention of Cardiovascular Disease and Cancer Mortality by Achieving Healthy Dietary Goals for the Swedish Population: A Macro-Simulation Modelling Study.': ['prevention'],
#  'Physical activity may compensate for prolonged TV time regarding pulse rate-a cross-sectional study.': [],
#  'Conceptualizing multiple drug use in patients with comorbidity and multimorbidity: proposal for standard definitions beyond the term polypharmacy.': [],
#  'The Therapeutic Impact of New Migraine Discoveries.': ['the therapeutic impact'],
#  'Migraine, Neurogenic Inflammation, Drug Development - Pharmacochemical Aspects.': ['migraine neurogenic inflammation drug development pharmacochemical aspects'],
# ...
#  'Localised cutaneous microvascular adaptation to exercise training in humans.': ['localised cutaneous microvascular adaptation'],
#  'Biopsychosocial Distress in Young Adult Oncology Patients: Examining Sex Differences in Sources of High Distress and Requests for Assistance.': ['biopsychosocial distress'],
#  'Work-life integration in neuropsychology: a review of the existing literature and preliminary recommendations.': [],
#  'Emerging applications of genome-editing technology to examine functionality of GWAS-associated variants for complex traits.': ['emerging applications'],
#  'Proteolytic shedding of the prion protein via activation of metallopeptidase ADAM10 reduces cellular binding and toxicity of amyloid-beta oligomers.': [],
#  'Extracellular and Luminal pH Regulation by Vacuolar H+-ATPase Isoform Expression and Targeting to the Plasma Membrane and Endosomes.': ['extracellular and luminal ph regulation'],
#  'Comparative genome analyses of novel Mangrovimonas-like strains isolated from estuarine mangrove sediments reveal xylan and arabinan utilization genes.': [],
#  'Association between Two Common Missense Substitutions, Thr6Lys and Val81Ile, in MC3R Gene and Childhood Obesity: A Meta-Analysis.': ['association'],
#  'Clinical versus patient-reported measures of depression in bariatric surgery.': [],
#  'A Defective Pentose Phosphate Pathway Reduces Inflammatory Macrophage Responses during Hypercholesterolemia.': [],
#  'Myeloid Kdm6b deficiency results in advanced atherosclerosis.': [],
#  'Vaccine-Induced Protection from Homologous Tier 2 SHIV Challenge in Nonhuman Primates Depends on Serum-Neutralizing Antibody Titers.': [],
#  'Molecular Diversity and Specializations among the Cells of the Adult Mouse Brain.': ['molecular diversity'],
#  'A guide to genome-wide association analysis and post-analytic interrogation.': ['a guide'],
#  'Sensory neuropathy with bone destruction due to a mutation in the membrane-shaping atlastin GTPase 3.': ['sensory neuropathy'],
#  'Proper development of the outer longitudinal smooth muscle of the mouse pylorus requires Nkx2-5 and Gata3.': [],
#  'Multiple spotty lesions of the spinal cord in a Chinese patient with human T-lymphotropic virus type 1-associated myelopathy/tropical spastic paraparesis.': [],
#  'Simian Immunodeficiency Virus Targeting of CXCR3(+) CD4(+) T Cells in Secondary Lymphoid Organs Is Associated with Robust CXCL10 Expression in Monocyte/Macrophage Subsets.': [],
#  'Effects of host restriction factors and the HTLV-1 subtype on susceptibility to HTLV-1-associated myelopathy/tropical spastic paraparesis.': ['effects'],
#  'Menin mediates Tat-induced neuronal apoptosis in brain frontal cortex of SIV-infected macaques and in Tat-treated cells.': ['menin mediates tat'],
#  'Depletion of Nesprin-2 is associated with an embryonic lethal phenotype in mice.': [],
#  'The Chara Genome: Secondary Complexity and Implications for Plant Terrestrialization.': ['the chara genome secondary complexity'],
#  'Multiple Roots of Fruiting Body Formation in Amoebozoa.': ['multiple roots'],
#  'Transcriptomic profiling of Alexandrium fundyense during physical interaction with or exposure to chemical signals from the parasite Amoebophrya.': ['transcriptomic profiling'],
#  'The Physarum polycephalum Genome Reveals Extensive Use of Prokaryotic Two-Component and Metazoan-Type Tyrosine Kinase Signaling.': [],
#  'The butterfly plant arms-race escalated by gene and genome duplications.': ['the butterfly plant arms race'],
#  'Genome size shifts: karyotype evolution in Crepis section Neglectoides (Asteraceae).': ['genome size shifts karyotype evolution'],
#  'Evaluation of Recipients of Positive and Negative Secondary Findings Evaluations in a Hybrid CLIA-Research Sequencing Pilot.': ['evaluation'],
#  'Assessing the spectrum of germline variation in Fanconi anemia genes among patients with head and neck carcinoma before age 50.': [],
#  'Somatic mutation profiles of clear cell endometrial tumors revealed by whole exome and targeted gene sequencing.': ['somatic mutation profiles'],
#  'Clinical and molecular phenotyping of a child with Hermansky-Pudlak syndrome-7, an uncommon genetic type of HPS.': ['clinical and molecular phenotyping'],
#  'Clinical Application of Genomic Profiling With Circulating Tumor DNA for Management of Advanced Non-Small-cell Lung Cancer in Asia.': ['clinical application'],
#  'Evolution of chloroplast retrograde signaling facilitates green plant adaptation to land.': [],
#  'Divergent gene expression levels between diploid and autotetraploid Tolmiea relative to the total transcriptome, the cell, and biomass.': ['divergent gene expression levels'],
#  'Plastid phylogenomic analysis of green plants: A billion years of evolutionary history.': [],
#  'Origin and evolution of the nuclear auxin response system.': ['origin'],
#  'Awake craniotomy for excision of arteriovenous malformations? A qualitative comparison study with stereotactic radiosurgery.': [],
#  'Cognitive Outcomes of Patients with Traumatic Bifrontal Contusions.': ['cognitive outcomes'],
#  'Identification of an algal xylan synthase indicates that there is functional orthology between algal and plant cell wall biosynthesis.': [],
#  'Targeting promiscuous heterodimerization overcomes innate resistance to ERBB2 dimerization inhibitors in breast cancer.': [],
#  'Pre-clinical endodontic education outcomes between artificial versus extracted natural teeth: a systematic review.': [],
#  'The Proliferative and Apoptotic Landscape of Basal-like Breast Cancer.': ['the proliferative and apoptotic landscape'],
#  'Longitudinal analysis of Voice Handicap Index in early glottic cancer patients treated with transoral laser microsurgery: age, gender, stage and time dependence.': [],
#  'Comparison of the firefighter candidate physical ability test to weight lifting exercises using electromyography.': ['comparison'],
#  'Recruitment tolerance to increased temperature present across multiple kelp clades.': ['recruitment tolerance'],
#  'Using a birth cohort to study brain health and preclinical dementia: recruitment and participation rates in Insight 46.': [],
#  'Efficacy and safety of alemtuzumab in Korean multiple sclerosis patients.': ['efficacy'],
#  'Evaluation of pulmonary toxicity of benzalkonium chloride and triethylene glycol mixtures using in vitro and in vivo systems.': ['evaluation'],
#  'Association between premature ovarian insufficiency, early menopause, socioeconomic status in a nationally representative sample from Korea.': [],
#  'Factors predicting remission in thymectomized patients with acetylcholine receptor antibody-positive myasthenia gravis.': ['factors'],
#  "Alzheimer's Disease Model System Using Drosophila.": ["alzheimer 's disease model system"],
#  'Preparation and evaluation of beta-glucan hydrogel prepared by the radiation technique for drug carrier applications.': ['preparation'],
#  'Insights into genetics, human biology and disease gleaned from family based genomic studies.': [],
#  'Transethnic insight into the genetics of glycaemic traits: fine-mapping results from the Population Architecture using Genomics and Epidemiology (PAGE) consortium.': ['transethnic insight'],
#  'Regression of solid breast tumours in mice by Newcastle disease virus is associated with production of apoptosis related-cytokines.': [],
#  'T-Cell Exhaustion in Chronic Infections: Reversing the State of Exhaustion and Reinvigorating Optimal Protective Immune Responses.': ['t cell exhaustion'],
#  'Aberrant monocyte responses predict and characterize dengue virus infection in individuals with severe disease.': [],
#  'Prevalence of pathogenic/likely pathogenic variants in the 24 cancer genes of the ACMG Secondary Findings v2.0 list in a large cancer cohort and ethnicity-matched controls.': ['prevalence',
#   'v2.0 list'],
#  'Untangling Flavobacterium johnsoniae Gliding Motility and Protein Secretion.': [],
#  'Compound heterozygous alterations in intraflagellar transport protein CLUAP1 in a child with a novel Joubert and oral-facial-digital overlap syndrome.': ['compound heterozygous alterations'],
#  'Neutralization of Bactericidal Activity Related to Antimicrobial Carryover in Broiler Carcass Rinse Samples.': ['neutralization'],
#  'Hypothalamic mechanisms associated with corticotropin-releasing factor-induced anorexia in chicks.': ['hypothalamic mechanisms'],
#  'Alpha-melanocyte stimulating hormone-induced anorexia in Japanese quail (Coturnix japonica) likely involves the ventromedial hypothalamus and paraventricular nucleus of the hypothalamus.': [],
#  'Central injection of a synthetic chicken partial leptin peptide does not affect food intake in chicks.': [],
#  'Differential expression of appetite-regulating genes in avian models of anorexia and obesity.': ['differential expression'],
#  'A high fat diet enhances the sensitivity of chick adipose tissue to the effects of centrally injected neuropeptide Y on gene expression of adipogenesis-associated factors.': [],
#  'The central anorexigenic mechanism of amylin in Japanese quail (Coturnix japonica) involves pro-opiomelanocortin, calcitonin receptor, and the arcuate nucleus of the hypothalamus.': [],
#  'Broad spectrum triazoles for invasive mould infections in adults: Which drug and when?': ['broad spectrum triazoles'],
#  'Rationale, design and baseline characteristics of the effect of ticagrelor on health outcomes in diabetes mellitus patients Intervention study.': ['rationale design'],
#  'Rare mould infections caused by Mucorales, Lomentospora prolificans and Fusarium, in San Diego, CA: the role of antifungal combination therapy.': [],
#  'Activated Clotting Time to Guide Heparin Dosing in Non-ST-Segment-Elevation Acute Coronary Syndrome Patients Undergoing Percutaneous Coronary Intervention and Treated With IIb/IIIa Inhibitors: Impact on Ischemic and Bleeding Outcomes: Insights From the TAO Trial.': ['activated clotting time',
#   'non st segment elevation acute coronary syndrome patients'],
#  'Smarcal1-Mediated Fork Reversal Triggers Mre11-Dependent Degradation of Nascent DNA in the Absence of Brca2 and Stable Rad51 Nucleofilaments.': [],
#  'Moonlighting at replication forks - a new life for homologous recombination proteins BRCA1, BRCA2 and RAD51.': ['moonlighting at replication forks',
#   'brca1 brca2'],
#  'The pseudo GTPase CENP-M drives human kinetochore assembly.': [],
#  'Comparative assessment of efficacy and safety potential of multifarious lipid based Tacrolimus loaded nanoformulations.': ['comparative assessment'],
#  'Development of strategy for simultaneous enhanced production of alkaline xylanase-pectinase enzymes by a bacterial isolate in short submerged fermentation cycle.': ['development'],
#  'Electroanatomical Remodeling of the Atria in Obesity: Impact of Adjacent Epicardial Fat.': ['electroanatomical remodeling'],
#  'Clinical trial in healthy malaria-naive adults to evaluate the safety, tolerability, immunogenicity and efficacy of MuStDO5, a five-gene, sporozoite/hepatic stage Plasmodium falciparum DNA vaccine combined with escalating dose human GM-CSF DNA.': ['clinical trial',
#   'hepatic stage plasmodium falciparum dna vaccine'],
#  'Analysis of 1508 Plasma Samples by Capillary-Flow Data-Independent Acquisition Profiles Proteomics of Weight Loss and Maintenance.': ['analysis'],
#  'Plasma Proteomics for Epidemiology: Increasing Throughput With Standard-Flow Rates.': ['plasma proteomics'],
#  'Miles to go (mtgo) encodes FNDC3 proteins that interact with the chaperonin subunit CCT3 and are required for NMJ branching and growth in Drosophila.': [],
#  'Cell-specific deletion of C1qa identifies microglia as the dominant source of C1q in mouse brain.': ['cell specific deletion'],
#  'Deficiency in the mouse mitochondrial adenine nucleotide translocator isoform 2 gene is associated with cardiac noncompaction.': [],
#  'An Integrated Genome-wide CRISPRa Approach to Functionalize lncRNAs in Drug Resistance.': ['an integrated genome wide crispra approach'],
#  'Fatty acid synthase mediates EGFR palmitoylation in EGFR mutated non-small cell lung cancer.': [],
#  'Mapping Molecular Datasets Back to the Brain Regions They are Extracted from: Remembering the Native Countries of Hypothalamic Expatriates and Refugees.': [],
#  'Ontogeny of white matter, toll-like receptor expression, and motor skills in the neonatal ferret.': ['ontogeny'],
#  'Genomic and molecular characterization of preterm birth.': ['genomic and molecular characterization'],
#  'Rare variants in neuronal excitability genes influence risk for bipolar disorder.': [],
#  'Peri-arterial specification of vascular mural cells from naive mesenchyme requires Notch signaling.': [],
#  'Immune responses in cardiac repair and regeneration: a comparative point of view.': ['immune responses'],
#  'In vivo analysis of cardiomyocyte proliferation during trabeculation.': [],
#  'Hyperprolactinemia-inducing antipsychotics increase breast cancer risk by activating JAK-STAT5 in precancerous lesions.': [],
#  'Essential role for centromeric factors following p53 loss and oncogenic transformation.': ['essential role'],
#  'Biophysical models reveal the relative importance of transporter proteins and impermeant anions in chloride homeostasis.': [],
#  'Reproducibility of Molecular Phenotypes after Long-Term Differentiation to Human iPSC-Derived Neurons: A Multi-Site Omics Study.': [],
#  'Neuronal Chloride Regulation via KCC2 Is Modulated through a GABAB Receptor Protein Complex.': [],
#  'Impact of UV-B radiation on the photosystem II activity, pro-/antioxidant balance and expression of light-activated genes in Arabidopsis thaliana hy4 mutants grown under light of different spectral composition.': ['impact',
#   'hy4 mutants'],
#  'Long-term impact of cement plant emissions on the elemental composition of both soils and pine stands and on the formation of Scots pine seeds.': [],
#  'Effects of 24-epibrassinolide and green light on plastid gene transcription and cytokinin content of barley leaves.': ['effects'],
#  'Effects of copper deficiency and copper toxicity on organogenesis and some physiological and biochemical responses of Scots pine (Pinus sylvestris L.) seedlings grown in hydroculture.': [],
#  'Blue light alters miR167 expression and microRNA-targeted auxin response factor genes in Arabidopsis thaliana plants.': [],
#  'Effects of zinc on Scots pine (Pinus sylvestris L.) seedlings grown in hydroculture.': [],
#  'Mutations in MAST1 Cause Mega-Corpus-Callosum Syndrome with Cerebellar Hypoplasia and Cortical Malformations.': [],
#  'Diversity and regulatory impact of copy number variation in the primate Macaca fascicularis.': ['diversity'],
#  'Inflammatory myopathy in a patient with Aicardi-Goutieres syndrome.': ['inflammatory myopathy'],
#  'Identification of a RAI1-associated disease network through integration of exome sequencing, transcriptomics, and 3D genomics.': ['identification'],
#  'Cartilage-Targeted IGF-1 Treatment to Promote Longitudinal Bone Growth.': [],
#  'In-line monitoring of Ibuprofen during and after tablet compression using near-infrared spectroscopy.': [],
#  'HCV Broadly Neutralizing Antibodies Use a CDRH3 Disulfide Motif to Recognize an E2 Glycoprotein Site that Can Be Targeted for Vaccine Design.': [],
#  'Modeling double strand break susceptibility to interrogate structural variation in cancer.': [],
#  'The experience among patients with multiple dental loss as a consequence of treatment for head and neck cancer: A qualitative study.': ['the experience'],
#  'Breaking point: the genesis and impact of structural variation in tumours.': ['breaking point'],
#  'The circadian dynamics of small nucleolar RNA in the mouse liver.': ['the circadian dynamics'],
#  'Lost in space? Generalising subtree prune and regraft to spaces of phylogenetic networks.': [],
#  'Changes in the demographics of intravenous drug users with mycotic common femoral artery pseudoaneurysm as a consequence of self-injection does not influence outcome following emergency ligation.': [],
#  'On the quirks of maximum parsimony and likelihood on phylogenetic networks.': []}

# %% [markdown]
# # Distributional distances
#
# If we want to compare different corpora, we need a distance or divergence that compares the two distributions.
#
# We will use the:
#
# + Kullback-Leibler (KL) divergence
# + $\chi^2$ divergence
# + Kolmogorov-Smirnov (KS) distance
# + Wasserstein distance
#
# ### Kullback-Leibler and $x^2$ divergences ###
#
# KL and $\chi^2$ divergences are members of the broader <a "href=https://en.wikipedia.org/wiki/F-divergence" target="_blank">$f$-divergence</a> family, a function of $D_f (P || Q)$ that calculates the difference between two probability distributions P and Q. The KL $f(t)$ is $ t \text{ log } t $, while the $\chi^2$ is $t^2-1$. KL comes from information and $\chi^2$ from measure theory. As such, the KL divergence computes the relative entropy between two distributions--how they differ in bits, while the $\chi^2$ whether the same statistical inferences can be drawn from them both.
#
# Specifically, given two discrete probability distributions $P$ and $Q$, the Kullback-Leibler divergence from $Q$ to $P$ is defined as:
#
# $D_{\mathrm{KL}}(P\|Q) = \sum_i P(i) \, \log\frac{P(i)}{Q(i)}$.
#
# The [scipy.stats.entropy()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.entropy.html) function does the calculation for you, which takes in two arrays of probabilities and computes the KL divergence. Note that the KL divergence is in general not commutative, i.e. $D_{\mathrm{KL}}(P\|Q) \neq D_{\mathrm{KL}}(Q\|P)$ .
#
# Also note that the KL divernce is the sum of elementwise divergences. Scipy provides [scipy.special.kl_div()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.special.kl_div.html#scipy-special-kl-div) which calculates elementwise divergences for you.
#
# The $\chi^2$ Divergence is defined as:
#
# $D_{\mathrm{\chi^2}}(P\|Q) = \sum_i \left(\frac{P(i)}{Q(i)}-1\right)^2$.
#
# This is also noncommutative, and the code can be drawn directly from scipy.
#
# ### Kolmogorov-Smirnov ###
#
# The two-sample Kolmogovorov-Smirnov test statistic calculates the distance between the cumulative distribution function of the two distributions to be compared, and, along with the $x^2$ divergence, is among the most common approaches two calculating a distance in statistics. It can be interpreted as a test of whether two distributions are drawn from the same underlying distribution. As with the others, the code is readily available in scipy.
#
# ### Wasserstein Distance ###
#
# When this is computed on a Euclidian metric structure (e.g., numbers of words), this is also known as the earth mover’s distance, because it can be seen as the minimum amount of "work" required to transform $P$ into $Q$, where "work" is measured as the amount of distribution weight that must be moved, multiplied by the distance it has to be moved.
#
# ### Computing ###
#
# To do this we will need to create the arrays, lets compare the Whitehouse releases with the Kennedy releases. First we have to download them and load them into a DataFrame.

# %%
kenReleases = getGithubFiles('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Kennedy', maxFiles = 10)
kenReleases[:5]

# %% [markdown]
# Then we can tokenize, stem and remove stop words, like we did for the Whitehouse press releases

# %%
kenReleases['tokenized_text'] = kenReleases['text'].apply(lambda x: word_tokenize(x))
kenReleases['normalized_tokens'] = kenReleases['tokenized_text'].apply(lambda x: normalizeTokens(x))

# %% [markdown]
# Now we need to compare the two collection of words, remove those not found in both, and assign the remaining ones indices.

# %%
whWords = set(whReleases['normalized_tokens'].sum())
kenWords = set(kenReleases['normalized_tokens'].sum())

#Change & to | if you want to keep all words
overlapWords = whWords & kenWords

overlapWordsDict = {word: index for index, word in enumerate(overlapWords)}
overlapWordsDict['student']

# %% [markdown]
# Now we can count the occurrences of each word in the corpora and create our arrays. Note that we don't have to use numpy arrays as we do here. We could just use a list, but the arrays are faster in numpy so we encourage you to get in the habit of using them.

# %%
def makeProbsArray(dfColumn, overlapDict):
    words = dfColumn.sum()
    countList = [0] * len(overlapDict)
    for word in words:
        try:
            countList[overlapDict[word]] += 1
        except KeyError:
            #The word is not common so we skip it
            pass
    countArray = np.array(countList)
    return countArray / countArray.sum()

whProbArray = makeProbsArray(whReleases['normalized_tokens'], overlapWordsDict)
kenProbArray = makeProbsArray(kenReleases['normalized_tokens'], overlapWordsDict)
kenProbArray.sum()
#There is a little bit of a floating point math error
#but it's too small to see with print and too small matter here

# %% [markdown]
# We can now compute the KL divergence. Pay attention to the asymmetry. Use [the Jensen–Shannon divergence](https://en.wikipedia.org/wiki/Jensen%E2%80%93Shannon_divergence), which is the average KL divergence between each distribution and the average of both distributions (i.e., the midpoint), if you want symmetry.

# %%
wh_kenDivergence = scipy.stats.entropy(whProbArray, kenProbArray)
print (wh_kenDivergence)
ken_whDivergence = scipy.stats.entropy(kenProbArray, whProbArray)
print (ken_whDivergence)

# %% [markdown]
# Then, we can do the elementwise calculation and see which words best distinguish the two corpora.

# %%
wh_kenDivergence_ew = scipy.special.kl_div(whProbArray, kenProbArray)
kl_df = pandas.DataFrame(list(overlapWordsDict.keys()), columns = ['word'], index = list(overlapWordsDict.values()))
kl_df = kl_df.sort_index()
kl_df['elementwise divergence'] = wh_kenDivergence_ew
kl_df[:10]

# %%
kl_df.sort_values(by='elementwise divergence', ascending=False)[:10]

# %% [markdown]
# Now we will apply what we learned today
# First, let's transform every text into normalized tokens. Note that in this first step, no stopword is removed.
# We'll use only the first 11 movies: you are welcome to try more.

# %%
corpora = []
for index, row in movie_df.iterrows():
    if len(corpora) > 10:
        break
    corpora.append(row['Tokenized Texts'])

# %% [markdown]
# Then, let's separate the normalized tokens into stopwords and non-stopwords.

# %%
corpora_s = []
corpora_nons = []
for corpus in corpora:
    s = []
    nons = []
    doc = nlp(' '.join(corpus))
    for word in doc:
        if word.is_stop:
            s.append(word.text)
        else:
            nons.append(word.text)
    corpora_s.append(s)
    corpora_nons.append(nons)

# %% [markdown]
# Define some covenient funtions for calculating divergence and distances.

# %%
def kl_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = scipy.stats.entropy(p, q)
    return D_kl

def chi2_divergence(X,Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    return scipy.stats.chisquare(p, q).statistic

def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)

# %% [markdown]
# Now we will calculate the KL divergence for each pair of corpora, turn the results into a matrix, and visualize the matrix as a heatmap. Recall that $D_{\mathrm{KL}}(P\|Q)$ measures the amount of information loss when $Q$ is used to approximate $P$. Here, the rows are the $P$s used for calculating KL divergences, and the columns are the $Q$s. So, each cell measures the amount of information loss when the word distribution of the column text is used to approximate the word distribution of the row text. Because the KL divergence is directional, such that the divergence of $P$ from $Q$ is different from the same of $Q$ from $P$, the matrix is assymetric and contains unique information above and below the diagonal. The same is true for the $\chi^2$ divergence.

# %%
len(corpora)

# %%
fileids = list(movie_df['Movie Name'])[0:11]

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# To reveal more patterns, let's do a multidimensional scaling of the matrix.

# %%
mds = sklearn.manifold.MDS()
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
for i, txt in enumerate(fileids):
    ax.annotate(txt, (x[i],y[i]))

# %% [markdown]
# A co-respondent's course and The Chain Gang are away from the others - any guesses why?
#
# We may just want to focus on the distrbution of stopwords or non-stopwords. Let's do the analysis again first for stopwords and then for non-stopwords.

# %%
L = []
for p in corpora_s:
    l = []
    for q in corpora_s:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# Now we compute the same for the assymmetric $\chi^2$ Divergence.

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='Chi2'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# For the KS distance:

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KS'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# And finally for the Wasserstein or "earth mover's" Distance.

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='Wasserstein'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# You can see that decade X is highly divergent and this makes reading the plot somewhat difficult. Let's fix this by taking the log of each cell, which will reduce the distance of decode X from other texts as an outlier.

# %%
ax = sns.heatmap(div.apply(np.log).replace([np.inf, -np.inf], np.nan))
plt.show()

# %% [markdown]
# We only tried 11 movies, and from the same time period, so our signals might not be too interesting. What about different time periods?
#
# An interesting experiment to maybe get some clearer signals: documents by decade in the Davies Corpus Of Historial American English (COHA) and see if we can detect patterns between them.
#
# If we want to rerun this on a new data set of our own composition, we can be a bit more efficient with our coding. Let's use the Shakespeare texts from last week as example:

# %%
shakespeare_df = lucem_illud_2020.loadTextDirectory('../data/Shakespeare')

# %% [markdown]
# Now we stem and remove stopwords

# %%
shakespeare_df['tokenized_text'] = shakespeare_df['text'].apply(lambda x: word_tokenize(x))
shakespeare_df['normalized_tokens'] = shakespeare_df['tokenized_text'].apply(lambda x: normalizeTokens(x))

# %% [markdown]
# Create the corpus file and generate the heatmap:

# %%
measure = 'KS' #"KL", "Chi2", "KS", "Wasserstein"
num_of_texts = 10 #The bigger this number the slower it will run, you can also try selecting your own plays
fileids_sp = list(shakespeare_df[:num_of_texts].index)
corpora_sp = list(shakespeare_df[:num_of_texts]['normalized_tokens'])
L = []
for p in corpora_sp:
    l = []
    for q in corpora_sp:
        l.append(Divergence(p,q, difference=measure))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids_sp, index = fileids_sp)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# What are "The Passionate Pilgrim" and "The Phoenix and the Turtle"? Little known poems by Shakespeare that are unsurprisingly hard to classify, as they are so different from everything else he wrote.

# %% [markdown]
# ## <span style="color:red">*Exercise 6*</span>
#
# <span style="color:red">Construct cells immediately below this that calculate the KL and $\chi^2$ divergences, and the KS and Wasserstein distances between four separate corpora, plot these with heatmaps, and then array them in two dimensions with multidimensional scaling as above. What does this reveal about relations between the corpora? Which analysis (and divergence or distribution) distinguishes the authors or documents better?
#
# <span style="color:red">**Stretch**: Calculate the <a "href=https://en.wikipedia.org/wiki/Jensen–Shannon_divergence" target="_blank">Jensen-Shannon Divergence</a> between your four corpora. What is the relationship between the KL and JS divergences?</span>

# %%
df.head()
# Out:
#         pmid                                              title  \
# 20  30474576  The current practice and care of paediatric pa...
# 21  30449211  Current pharmacological treatment guidelines f...
# 24  29580902  Early life trauma: An exploratory study of eff...
# 41  30917518  Telomerase Impinges on the Cellular Response t...
# 55  29118206  Social Origins of Developmental Risk for Menta...
#
#                                              abstract  \
# 20  BACKGROUND: Literature is lacking to guide sta...
# 21  INTRODUCTION: Psoriasis is a common chronic sk...
# 24  BACKGROUND: In animals, adverse early experien...
# 41  Telomerase has cellular functions beyond telom...
# 55  Adversity in early childhood exerts an endurin...
#
#                                                 major  \
# 20  ['CHD', 'paediatric cardiac catheterisation', ...
# 21  ['Psoriasis', 'arthritis', 'biologics', 'guide...
# 24  ['*Early childhood trauma', '*Gene expression'...
# 41  ['autophagy', 'mitochondria', 'oxidative stres...
# 55  ['*EEG', '*foster care', '*limbic', '*neglect'...
#
#                                                  mesh  \
# 20  ['*Cardiac Care Facilities', 'Cardiac Catheter...
# 21  ['Antirheumatic Agents/administration & dosage...
# 24  ['Adult', '*Adverse Childhood Experiences', 'F...
# 41  ['*Autophagy', 'Cell Line', 'Fibroblasts/metab...
# 55  ['Adult', 'Child', 'Child Abuse/*psychology', ...
#
#                                         cleaned_title  \
# 20  the current practice and care of paediatric pa...
# 21  current pharmacological treatment guidelines f...
# 24  early life trauma: an exploratory study of eff...
# 41  telomerase impinges on the cellular response t...
# 55  social origins of developmental risk for menta...
#
#                                       tokenized_title  word_counts  \
# 20  [the, current, practice, and, care, of, paedia...           11
# 21  [current, pharmacological, treatment, guidelin...            9
# 24  [early, life, trauma, an, exploratory, study, ...           22
# 41  [telomerase, impinges, on, the, cellular, resp...           16
# 55  [social, origins, of, developmental, risk, for...           10
#
#                                     normalized_tokens  \
# 20  [current, practice, care, paediatric, patient,...
# 21  [current, pharmacological, treatment, guidelin...
# 24  [early, life, trauma, exploratory, study, effe...
# 41  [telomerase, impinge, cellular, response, oxid...
# 55  [social, origin, developmental, risk, mental, ...
#
#     normalized_tokens_count                              normalized_tokens_POS
# 20                        8  [(the, DT), (current, JJ), (practice, NN), (an...
# 21                        7  [(current, JJ), (pharmacological, JJ), (treatm...
# 24                       15  [(early, JJ), (life, NN), (trauma, NN), (:, :)...
# 41                       11  [(telomerase, NNP), (impinges, NNS), (on, IN),...
# 55                        7  [(social, JJ), (origins, NNS), (of, IN), (deve...

# %%
paper_1 = set(df['normalized_tokens'].iloc[1])
paper_2 = set(df['normalized_tokens'].iloc[3])

#Change & to | if you want to keep all words
overlapWords = paper_1 | paper_2

overlapWordsDict = {word: index for index, word in enumerate(overlapWords)}
overlapWordsDict
# Out:
# {'impinge': 0,
#  'current': 1,
#  'pharmacological': 2,
#  'telomerase': 3,
#  'regulation': 4,
#  'cellular': 5,
#  'arthritis': 6,
#  'psoriatic': 7,
#  'autophagy': 8,
#  'treatment': 9,
#  'psoriasis': 10,
#  'guideline': 11,
#  'stress': 12,
#  'ros': 13,
#  'response': 14,
#  'oxidative': 15,
#  'mitochondrial': 16,
#  'mediate': 17}

# %%
def makeProbsArray(dfColumn, overlapDict):
    words = dfColumn.sum()
    countList = [0] * len(overlapDict)
    for word in words:
        try:
            countList[overlapDict[word]] += 1
        except KeyError:
            #The word is not common so we skip it
            pass
    countArray = np.array(countList)
    return countArray / countArray.sum()

# %%
#prob arrays
b1ProbArray = makeProbsArray(df[:1]['normalized_tokens'], overlapWordsDict)
b2ProbArray = makeProbsArray(df[1:2]['normalized_tokens'], overlapWordsDict)
b2ProbArray
# Out:
# array([0.        , 0.14285714, 0.14285714, 0.        , 0.        ,
#        0.        , 0.14285714, 0.14285714, 0.        , 0.14285714,
#        0.14285714, 0.14285714, 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        ])

# %%
#KL Divergence
b1_b2Divergence = scipy.stats.entropy(b1ProbArray, b2ProbArray)
print (b1_b2Divergence)
b2_b1Divergence = scipy.stats.entropy(b2ProbArray, b1ProbArray)
print (b2_b1Divergence)
# Out:
# 1.9459101490553132
# inf

# %%
#Jensen Shannon
from scipy.spatial import distance

js_b1_b2Divergence = distance.jensenshannon(b1ProbArray, b2ProbArray)
print (js_b1_b2Divergence)
js_b2_b1Divergence = distance.jensenshannon(b2ProbArray, b1ProbArray)
print (js_b2_b1Divergence)
# Out:
# 0.6912669133961694
# 0.6912669133961694

# %%
# Element wise calculations
b1b2Divergence_ew = scipy.special.kl_div(b1ProbArray, b2ProbArray)
kl_df = pandas.DataFrame(list(overlapWordsDict.keys()), columns = ['word'], index = list(overlapWordsDict.values()))
kl_df = kl_df.sort_index()
kl_df['elementwise divergence'] = b1b2Divergence_ew
kl_df.sort_values(by='elementwise divergence', ascending=False)[:10]
# Out:
#                word  elementwise divergence
# 1           current                1.088767
# 9         treatment                0.142857
# 2   pharmacological                0.142857
# 6         arthritis                0.142857
# 7         psoriatic                0.142857
# 10        psoriasis                0.142857
# 11        guideline                0.142857
# 12           stress                0.000000
# 16    mitochondrial                0.000000
# 15        oxidative                0.000000

# %%
def plot_heatmap(measure, corpora_sp, fileids_sp):
    #measure = "KL", "Chi2", "KS", "Wasserstein"
    L = []
    for p in corpora_sp:
        l = []
        for q in corpora_sp:
            l.append(Divergence(p,q, difference=measure))
        L.append(l)
    M = np.array(L)
    fig = plt.figure()
    div = pandas.DataFrame(M, columns = fileids_sp, index = fileids_sp)
    ax = sns.heatmap(div)
    plt.show()

# %%
def mds(measure, corpora_sp, fileids):
    L = []
    for p in corpora_sp:
        l = []
        for q in corpora_sp:
            l.append(Divergence(p,q, difference=measure))
        L.append(l)
    M = np.array(L)
    mds = sklearn.manifold.MDS()
    pos = mds.fit(M).embedding_
    x = pos[:,0]
    y = pos[:,1]
    fig, ax = plt.subplots(figsize = (6,6))
    plt.plot(x, y, ' ')
    for i, txt in enumerate(fileids):
        ax.annotate(txt, (x[i],y[i]))

# %%
fileids = list(df[:10]['title'])
corpora = list(df[:10]['normalized_tokens'])

# %%
def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)

# %%
plot_heatmap('KS', corpora, fileids)

# %%
def kl_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = scipy.stats.entropy(p, q)
    return D_kl

# %%
plot_heatmap('KL', corpora, fileids)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)

# %%
from scipy.spatial import distance

def js_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = distance.jensenshannon(p, q)
    return D_kl

def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)
    elif difference == 'JS':
        return js_divergence(P, Q)

# %%
plot_heatmap('JS', corpora, fileids)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/scipy/spatial/distance.py:1288: RuntimeWarning: invalid value encountered in true_divide
#   p = p / np.sum(p, axis=0)
